# %%
# basic imports
import os, random
import numpy as np
import datetime as dt
import time
from scipy.fftpack import fft, ifft
from abc import ABC, abstractmethod
import matplotlib.pyplot as plt

# warnings
import warnings

warnings.filterwarnings('ignore')

# tensorflow
import tensorflow as tf

tf.keras.backend.clear_session()

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import Layer, Add

# %%
print(f" TensorFlow version is {tf.__version__}")
#print(f"Keras version is {tf.keras.__version__}")
print(tf.config.list_physical_devices())
# Out:
#  TensorFlow version is 2.15.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class Linear(Layer):
    """Define Linear layers"""

    def __init__(self, in_features, out_features):
        super(Linear, self).__init__()

        self.in_dims = in_features
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'
        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        return tf.matmul(inputs, self.w) + self.b


class StableLinear(Layer):
    """Define Stable Linear layers"""

    def __init__(self, in_features, out_features):
        super(StableLinear, self).__init__()

        self.epsilon = 0.01
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'

        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        w = self.weight_constraint(self.w)
        return tf.matmul(inputs, w) + self.b

    #@tf.function
    def weight_constraint(self, weight):
        delta = 1 - 2 * self.epsilon
        RtR = tf.matmul(tf.transpose(weight), weight)
        norm = tf.norm(RtR)

        #if norm > delta: RtR = delta ** (1 / 2) * RtR / (norm ** (1 / 2))
        RtR_new = tf.sqrt(delta) * RtR / tf.sqrt(norm)
        RtR_update = tf.minimum(RtR_new, RtR)
        #def f2(): return RtR
        #RtR = tf.cond(tf.greater(norm, delta), f1, f2)
        A = RtR_update + tf.eye(RtR.shape[0]) * self.epsilon
        return -A


class NaisNet(Model):
    """ Building NAIS_Net network using keras """

    def __init__(self, layers):
        super(NaisNet, self).__init__()

        self.layer1 = Linear(layers[0], layers[1])

        self.layer2 = StableLinear(layers[1], layers[2])
        self.layer2_input = Linear(layers[0], layers[2])

        self.layer3 = StableLinear(layers[2], layers[3])
        self.layer3_input = Linear(layers[0], layers[3])

        self.layer4 = StableLinear(layers[3], layers[4])
        self.layer4_input = Linear(layers[0], layers[4])

        self.layer5 = Linear(layers[4], layers[5])

    # Building block for the NAIS-Net
    #@tf.function
    def call(self, x):
        """Process stages in the block"""

        u = x

        output = self.layer1(u)  # layer 1
        output = tf.sin(output)

        X1 = output
        output = self.layer2(output)  # layer 2
        output = Add()([self.layer2_input(u), output])
        output = tf.sin(output)
        output = Add()([X1, output])

        X2 = output
        output = self.layer3(output)  # layer 3
        output = Add()([self.layer3_input(u), output])
        output = tf.sin(output)
        output = Add()([X2, output])

        X3 = output
        output = self.layer4(output)  # layer 4
        output = Add()([self.layer4_input(u), output])
        output = tf.sin(output)
        output = Add()([X3, output])

        output = self.layer5(output)  # layer 5

        return output


class FBSNN(ABC):
    """Forward-Backward SDEs using NAIS-Net """

    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):    # , layer_phi

        self.Xi = Xi  # initial point

        self.T = T  # terminal time
        self.M = M  # number of trajectories
        self.N = N  # number of time snapshots
        self.D = D  # number of dimensions
        self.H = H  # Hurst exponent (0,1)
        self.eta = eta  # parameter for control volatility
        self.pho = tf.Variable(pho, dtype=tf.float32) # correlation betwen two independent Wiener process
        self.epsilon_t = 0.09 # forward variance curve epsilon(t) - constant
        self.r = tf.Variable(r, dtype=tf.float32)  # interest rate
           
        # Initialize NN
        self.model = NaisNet(layers)
        #self.model_phi = NaisNet(layer_phi)

        # Record the loss
        self.training_loss = []
        self.iteration = []
        self.Y0_iter = []
        self.Du0_iter = []

    @tf.function
    def net_u(self, t, X):  # M x 1, M x D

        y = self.model(tf.concat([t, X], 1))  # M x [1+D]
        u = tf.expand_dims(y[:, 0], axis=-1)  # M x 1
        #phi = self.model_phi(tf.concat([t, X], 1)) # M x D
        phi = y[:, 1:] # M x D
        Du = tf.gradients(u, X)[0]  # M x D

        return u, phi, Du

    @tf.function
    def Dg_tf(self, X):  # M x D
        return tf.gradients(self.g_tf(X), X)[0]  # M x D

    #@tf.function
    def loss_function(self, t, W, B, Var, Xi):

        loss = 0
        X_list = []
        Y_list = []
        Tilde_Z_list = []
        Z_list = []
        Du_list = []


        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        B0 = B[:, 0, :]
        Var0 = Var[:, 0, :]

        X0 = tf.tile(Xi, [self.M, 1])  # M x D
        Y0, phi0, du0 = self.net_u(t0, X0)  # M x 1, M x D, M x D
        Z0 = self.Z_tf(Var0,du0) # M x D
        Tilde_Z0 = self.Z_tilde_tf(Var0, phi0, du0) # M x D

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)
        Tilde_Z_list.append(Tilde_Z0)
        Du_list.append(du0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]
            B1 = B[:, n + 1, :]
            Var1 = Var[:, n + 1, :]
            BM = self.pho * (W1 - W0) + tf.sqrt(1 - self.pho**2) * (B1 - B0)
            X1 = X0 +self.mu_tf(t0, X0, Y0, du0) * (t1 - t0)  - Var0 * 0.5 * (t1 - t0) + tf.sqrt(Var0) * BM

            Y1_tilde = Y0 + self.F_tf(t0, X0, Y0, Z0, Tilde_Z0) * (t1 - t0) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Z0, tf.expand_dims(B1 - B0, -1))), axis=1, 
                keepdims=True) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Tilde_Z0, tf.expand_dims(W1 - W0, -1))), axis=1, keepdims=True)
            
            Y1, phi1, du1 = self.net_u(t1, X1)
            Z1 = self.Z_tf(Var1,du1) # M x D
            Tilde_Z1 = self.Z_tilde_tf(Var1, phi1, du1) # M x D


            loss += tf.reduce_sum(tf.pow(Y1 - Y1_tilde, 2))

            t0 = t1
            W0 = W1
            B0 = B1
            Var0 = Var1
            du0 = du1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            Tilde_Z0 = Tilde_Z1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)
            Tilde_Z_list.append(Tilde_Z0)
            Du_list.append(du0)
        
        # 0.02 is the penalty parameters for the terminal conditions
        loss +=  0.02 * tf.reduce_sum(tf.pow(Y1 - self.g_tf(X1), 2))
        loss +=  0.02 * tf.reduce_sum(tf.pow(du1 - self.Dg_tf(X1), 2))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)
        Tilde_Z = tf.stack(Tilde_Z_list, axis=1)
        Du_t = tf.stack(Du_list, axis=1)
        #Y0 = tf.reduce_mean(Y, axis=0)

        return loss, X, Y, Y[0, 0, 0], Du_t

    def Z_tf(self, Var, Du):  # M x D
        return tf.sqrt((1 - self.pho**2) * Var) * Du

    def Z_tilde_tf(self, Var, phi, Du): # M x D
        return self.pho * tf.sqrt(Var) * Du + phi

    # Volterra process Using hybrid scheme
    def volterra(self):
        T = self.T
        M = self.M
        N = self.N
        D = self.D
        delta_t = T / N
        alpha = self.H - 0.5
        
        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D
        Dt[:, 1:, :] = delta_t
        DW[:, 1:, :] = np.sqrt(delta_t) * np.random.normal(size=(M, N, D))
        
        t_series = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W_process = np.cumsum(DW, axis=1)  # M x (N+1) x D

        sigma = (2*alpha + 1)**0.5
        #kernal function
        def g_kernel(k):
            y = (k**(alpha+1) - (k-1)**(alpha+1)) / (alpha+1)
            b = np.power(y, 1/alpha)
            return np.power((b) * delta_t, alpha)

        #t_series, W_process = self.fetch_minibatch()

        tilde_X = np.zeros((M, N+1, D))
        tilde_X[:, 0 , :]= W_process[:, 0 , :]

        WN_tj_minus_1_1 = np.roll(W_process, shift=-1, axis=1) - W_process

        for m in range(M):
            for d in range(D):
                # first column for toeplitz matrix 
                WN_j = WN_tj_minus_1_1[m, :-1, d]
                sigma_col = np.zeros((N)) 
                sigma_col[0] = np.power(delta_t/2, alpha) * sigma
                # 
                for k in range(1, N):
                    g_b_star_k = g_kernel(k+1)
                    sigma_col[k] = sigma * g_b_star_k

                # FFT and dot
                WN_j_fft = fft(WN_j)
                sigma_fft = fft(sigma_col)
                convolved = ifft(WN_j_fft * sigma_fft) 

                # capture real value 
                tilde_X[m, 1:, d] = np.real(convolved)
        
        return t_series, W_process, tilde_X

    # Variace process
    def variance(self):

        t, W_s, D_hat_w = self.volterra()# M x (N+1) x D

        var = self.epsilon_t * np.exp(self.eta* D_hat_w -  0.5 * self.eta**2 * np.power(t, 2*self.H))

        return W_s, var

    #@tf.function
    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W = np.cumsum(DW, axis=1)  # M x (N+1) x D

        return t, W

    @tf.function
    def train_step(self, optimizers, t, w, b, var, Xi):
        # Optimizers
        optimizer = optimizers

        with tf.GradientTape() as tape:
            loss_value, X_pred, Y_pred, Y0_pred, Du0_pred = self.loss_function(t, w, b, var, Xi)

        grads = tape.gradient(loss_value, self.model.trainable_weights)
        #optimizer.apply(grads, self.model.trainable_weights)
        optimizer.apply_gradients(zip(grads, self.model.trainable_weights))


        return loss_value, Y0_pred, Du0_pred

    #@tf.function
    def train(self, N_Iter, learning_rate):

        loss_temp = np.array([])
        Y0_pred_temp = np.array([])
        Du0_pred_temp = np.array([])

        # Optimizers
        self.optimizer = Adam(learning_rate=learning_rate)

        start_time = time.time()
        ini_time = time.time()

        for it in range(N_Iter):

            t_batch, B_batch = self.fetch_minibatch()  # M x (N+1) x 1, M x (N+1) x D
            W_batch, Var_batch = self.variance() # M x (N+1) x D, M x (N+1) x D
            t_batch = tf.convert_to_tensor(t_batch, dtype=tf.float32)
            B_batch = tf.convert_to_tensor(B_batch, dtype=tf.float32)
            W_batch = tf.convert_to_tensor(W_batch, dtype=tf.float32)
            Var_batch = tf.convert_to_tensor(Var_batch, dtype=tf.float32)
            self.Xi = tf.convert_to_tensor(self.Xi, dtype=tf.float32)

            loss_value, Y0_pred, Du0_pred = self.train_step(self.optimizer, t_batch, W_batch, B_batch, Var_batch, self.Xi)

            if it % 100 == 0:
                elapsed = time.time() - start_time
                total_time = time.time() - ini_time
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Total Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_pred, elapsed, total_time, learning_rate))
                start_time = time.time()

            loss_temp = np.append(loss_temp, loss_value.numpy())
            Y0_pred_temp = np.append(Y0_pred_temp, Y0_pred.numpy())

            Du0 = tf.reduce_mean(Du0_pred, axis=0)
            Du0_pred_temp = np.append(Du0_pred_temp, Du0.numpy()[0, 0])

            if it % 100 == 0:
                self.training_loss.append(loss_temp.mean())
                self.Y0_iter.append(Y0_pred_temp[-100:].mean())
                self.Du0_iter.append(Du0_pred_temp[-100:].mean())
                self.iteration.append(it)
  
            graph = np.stack((self.iteration, self.training_loss))
            Y0_iter = np.stack((self.iteration, self.Y0_iter))
            Du0_iter = np.stack((self.iteration, self.Du0_iter))

        return graph,Y0_iter, Du0_iter

    def predict(self, Xi_star, t_star, W_star, B_star, Var_star):
        t_star = tf.convert_to_tensor(t_star, dtype=tf.float32)
        W_star = tf.convert_to_tensor(W_star, dtype=tf.float32)
        Xi_star = tf.convert_to_tensor(Xi_star, dtype=tf.float32)
        B_star = tf.convert_to_tensor(B_star, dtype=tf.float32)
        Var_star = tf.convert_to_tensor(Var_star, dtype=tf.float32)        

        loss, X_star, Y_star, Y0_pred, delta_star = self.loss_function(t_star, W_star, B_star, Var_star, Xi_star)

        return X_star, Y_star, delta_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        pass  # M x1

    @abstractmethod
    def g_tf(self, X):  # M x D
        pass  # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return tf.zeros([M, D])  # M x D
    ###########################################################################

# %%
class RoughBergomiModel(FBSNN):
    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):
        super().__init__(Xi, T, M, N, D, H, eta, pho, r, layers)

    def g_tf(self, X):  # M x D
        K = tf.tile(np.array([90.0], dtype=np.float32)[None, :], [self.M, 1])
        X = tf.reduce_mean(tf.exp(X + self.r * self.T), axis=1, keepdims = True)
        return tf.maximum(K - X, 0) # M x 1  

    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        return super().mu_tf(t, X, Y, Du)  # M x D

    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        return self.r * Y # M x1

    ###########################################################################

# %%
T = 1.0  # terminal time
M = 100  # number of trajectories
N = 50  # number of time snapshots
D = 20  # number of dimensions
H = 0.07  # Hurst exponent (0,1)
eta = 1.9  # parameter for control volatility
pho = -0.9  # correlation betwen two independent Wiener process
r = 0.05  # interest rate

Xi = np.array([np.log(100.0), np.log(50.0)] * int(D / 2))[None, :]

layers = [D+1] + 4 * [256] + [1+D]

model = RoughBergomiModel(Xi, T, M, N, D, H, eta, pho, r, layers)
graph, Y0_iter, delta_iter = model.train(2*10**4, 1e-3)
# Out:
# It: 0, Loss: 6.972e+07, Y0: -0.280, Time: 29.64, Total Time: 29.64, Learning Rate: 1.000e-03
# It: 100, Loss: 2.545e+04, Y0: -1.387, Time: 77.96, Total Time: 107.60, Learning Rate: 1.000e-03
# It: 200, Loss: 5.723e+04, Y0: -1.165, Time: 76.58, Total Time: 184.18, Learning Rate: 1.000e-03
# It: 300, Loss: 7.310e+04, Y0: -1.013, Time: 73.27, Total Time: 257.45, Learning Rate: 1.000e-03
# It: 400, Loss: 3.524e+04, Y0: -0.814, Time: 73.24, Total Time: 330.69, Learning Rate: 1.000e-03
# It: 500, Loss: 4.228e+04, Y0: -0.542, Time: 73.97, Total Time: 404.66, Learning Rate: 1.000e-03
# It: 600, Loss: 5.015e+04, Y0: -0.322, Time: 75.45, Total Time: 480.11, Learning Rate: 1.000e-03
# It: 700, Loss: 5.848e+04, Y0: -0.148, Time: 73.40, Total Time: 553.51, Learning Rate: 1.000e-03
# It: 800, Loss: 4.617e+04, Y0: 0.038, Time: 72.15, Total Time: 625.66, Learning Rate: 1.000e-03
# It: 900, Loss: 4.982e+04, Y0: 0.263, Time: 72.21, Total Time: 697.88, Learning Rate: 1.000e-03
# It: 1000, Loss: 2.257e+04, Y0: 0.466, Time: 72.29, Total Time: 770.16, Learning Rate: 1.000e-03
# It: 1100, Loss: 4.581e+04, Y0: 0.683, Time: 72.57, Total Time: 842.73, Learning Rate: 1.000e-03
# It: 1200, Loss: 3.180e+04, Y0: 0.879, Time: 73.62, Total Time: 916.35, Learning Rate: 1.000e-03
# It: 1300, Loss: 1.783e+04, Y0: 1.041, Time: 72.51, Total Time: 988.86, Learning Rate: 1.000e-03
# It: 1400, Loss: 3.033e+04, Y0: 1.224, Time: 72.16, Total Time: 1061.01, Learning Rate: 1.000e-03
# It: 1500, Loss: 1.963e+04, Y0: 1.417, Time: 73.01, Total Time: 1134.03, Learning Rate: 1.000e-03
# It: 1600, Loss: 2.428e+04, Y0: 1.616, Time: 72.41, Total Time: 1206.43, Learning Rate: 1.000e-03
# It: 1700, Loss: 4.817e+04, Y0: 1.858, Time: 72.52, Total Time: 1278.96, Learning Rate: 1.000e-03
# It: 1800, Loss: 3.929e+04, Y0: 2.093, Time: 75.49, Total Time: 1354.45, Learning Rate: 1.000e-03
# It: 1900, Loss: 1.619e+04, Y0: 2.353, Time: 75.14, Total Time: 1429.59, Learning Rate: 1.000e-03
# It: 2000, Loss: 1.185e+04, Y0: 2.648, Time: 75.86, Total Time: 1505.44, Learning Rate: 1.000e-03
# It: 2100, Loss: 1.757e+04, Y0: 2.905, Time: 73.17, Total Time: 1578.61, Learning Rate: 1.000e-03
# It: 2200, Loss: 1.712e+04, Y0: 3.151, Time: 72.43, Total Time: 1651.04, Learning Rate: 1.000e-03
# It: 2300, Loss: 9.087e+03, Y0: 3.388, Time: 72.34, Total Time: 1723.38, Learning Rate: 1.000e-03
# It: 2400, Loss: 1.699e+04, Y0: 3.583, Time: 72.78, Total Time: 1796.16, Learning Rate: 1.000e-03
# It: 2500, Loss: 8.455e+03, Y0: 3.876, Time: 73.28, Total Time: 1869.44, Learning Rate: 1.000e-03
# It: 2600, Loss: 1.561e+04, Y0: 4.078, Time: 72.06, Total Time: 1941.50, Learning Rate: 1.000e-03
# It: 2700, Loss: 1.122e+04, Y0: 4.337, Time: 72.40, Total Time: 2013.90, Learning Rate: 1.000e-03
# It: 2800, Loss: 8.285e+03, Y0: 4.587, Time: 72.37, Total Time: 2086.27, Learning Rate: 1.000e-03
# It: 2900, Loss: 1.197e+04, Y0: 4.816, Time: 72.09, Total Time: 2158.36, Learning Rate: 1.000e-03
# It: 3000, Loss: 2.780e+04, Y0: 5.079, Time: 73.05, Total Time: 2231.41, Learning Rate: 1.000e-03
# It: 3100, Loss: 2.440e+04, Y0: 5.273, Time: 72.74, Total Time: 2304.15, Learning Rate: 1.000e-03
# It: 3200, Loss: 1.294e+04, Y0: 5.527, Time: 72.43, Total Time: 2376.59, Learning Rate: 1.000e-03
# It: 3300, Loss: 1.480e+04, Y0: 5.768, Time: 71.76, Total Time: 2448.34, Learning Rate: 1.000e-03
# It: 3400, Loss: 8.106e+03, Y0: 6.036, Time: 71.90, Total Time: 2520.25, Learning Rate: 1.000e-03
# It: 3500, Loss: 1.139e+04, Y0: 6.257, Time: 73.13, Total Time: 2593.38, Learning Rate: 1.000e-03
# It: 3600, Loss: 6.864e+03, Y0: 6.511, Time: 72.61, Total Time: 2665.99, Learning Rate: 1.000e-03
# It: 3700, Loss: 1.402e+04, Y0: 6.816, Time: 71.61, Total Time: 2737.60, Learning Rate: 1.000e-03
# It: 3800, Loss: 1.294e+04, Y0: 7.106, Time: 72.61, Total Time: 2810.20, Learning Rate: 1.000e-03
# It: 3900, Loss: 5.755e+03, Y0: 7.431, Time: 71.87, Total Time: 2882.07, Learning Rate: 1.000e-03
# It: 4000, Loss: 1.551e+04, Y0: 7.701, Time: 71.42, Total Time: 2953.49, Learning Rate: 1.000e-03
# It: 4100, Loss: 1.411e+04, Y0: 7.951, Time: 71.29, Total Time: 3024.78, Learning Rate: 1.000e-03
# It: 4200, Loss: 1.028e+04, Y0: 8.227, Time: 71.13, Total Time: 3095.91, Learning Rate: 1.000e-03
# It: 4300, Loss: 8.733e+03, Y0: 8.514, Time: 73.02, Total Time: 3168.93, Learning Rate: 1.000e-03
# It: 4400, Loss: 1.863e+04, Y0: 8.761, Time: 72.01, Total Time: 3240.94, Learning Rate: 1.000e-03
# It: 4500, Loss: 7.059e+03, Y0: 9.025, Time: 72.71, Total Time: 3313.65, Learning Rate: 1.000e-03
# It: 4600, Loss: 1.278e+04, Y0: 9.293, Time: 71.64, Total Time: 3385.29, Learning Rate: 1.000e-03
# It: 4700, Loss: 6.076e+03, Y0: 9.563, Time: 72.07, Total Time: 3457.36, Learning Rate: 1.000e-03
# It: 4800, Loss: 8.478e+03, Y0: 9.849, Time: 71.66, Total Time: 3529.02, Learning Rate: 1.000e-03
# It: 4900, Loss: 1.165e+04, Y0: 10.142, Time: 71.42, Total Time: 3600.44, Learning Rate: 1.000e-03
# It: 5000, Loss: 8.290e+03, Y0: 10.392, Time: 71.37, Total Time: 3671.81, Learning Rate: 1.000e-03
# It: 5100, Loss: 1.129e+04, Y0: 10.623, Time: 71.61, Total Time: 3743.42, Learning Rate: 1.000e-03
# It: 5200, Loss: 7.428e+03, Y0: 10.795, Time: 71.55, Total Time: 3814.97, Learning Rate: 1.000e-03
# It: 5300, Loss: 8.398e+03, Y0: 10.974, Time: 71.67, Total Time: 3886.64, Learning Rate: 1.000e-03
# It: 5400, Loss: 9.463e+03, Y0: 11.248, Time: 71.08, Total Time: 3957.73, Learning Rate: 1.000e-03
# It: 5500, Loss: 8.697e+03, Y0: 11.388, Time: 70.61, Total Time: 4028.34, Learning Rate: 1.000e-03
# It: 5600, Loss: 1.511e+04, Y0: 11.565, Time: 73.23, Total Time: 4101.57, Learning Rate: 1.000e-03
# It: 5700, Loss: 1.012e+04, Y0: 11.753, Time: 73.25, Total Time: 4174.82, Learning Rate: 1.000e-03
# It: 5800, Loss: 7.188e+03, Y0: 11.906, Time: 72.13, Total Time: 4246.95, Learning Rate: 1.000e-03
# It: 5900, Loss: 5.273e+03, Y0: 12.018, Time: 70.91, Total Time: 4317.86, Learning Rate: 1.000e-03
# It: 6000, Loss: 6.549e+03, Y0: 12.122, Time: 71.15, Total Time: 4389.01, Learning Rate: 1.000e-03
# It: 6100, Loss: 3.951e+03, Y0: 12.226, Time: 71.12, Total Time: 4460.13, Learning Rate: 1.000e-03
# It: 6200, Loss: 6.353e+03, Y0: 12.321, Time: 72.06, Total Time: 4532.19, Learning Rate: 1.000e-03
# It: 6300, Loss: 7.788e+03, Y0: 12.445, Time: 71.95, Total Time: 4604.14, Learning Rate: 1.000e-03
# It: 6400, Loss: 6.373e+03, Y0: 12.508, Time: 72.22, Total Time: 4676.36, Learning Rate: 1.000e-03
# It: 6500, Loss: 5.019e+03, Y0: 12.602, Time: 71.77, Total Time: 4748.13, Learning Rate: 1.000e-03
# It: 6600, Loss: 7.851e+03, Y0: 12.696, Time: 72.19, Total Time: 4820.33, Learning Rate: 1.000e-03
# It: 6700, Loss: 8.346e+03, Y0: 12.665, Time: 72.08, Total Time: 4892.40, Learning Rate: 1.000e-03
# It: 6800, Loss: 4.192e+03, Y0: 12.789, Time: 71.98, Total Time: 4964.38, Learning Rate: 1.000e-03
# It: 6900, Loss: 1.366e+04, Y0: 12.873, Time: 71.92, Total Time: 5036.30, Learning Rate: 1.000e-03
# It: 7000, Loss: 8.476e+03, Y0: 12.894, Time: 72.16, Total Time: 5108.46, Learning Rate: 1.000e-03
# It: 7100, Loss: 6.456e+03, Y0: 12.897, Time: 73.14, Total Time: 5181.60, Learning Rate: 1.000e-03
# It: 7200, Loss: 8.200e+03, Y0: 12.915, Time: 74.03, Total Time: 5255.63, Learning Rate: 1.000e-03
# It: 7300, Loss: 7.012e+03, Y0: 13.029, Time: 74.21, Total Time: 5329.84, Learning Rate: 1.000e-03
# It: 7400, Loss: 8.734e+03, Y0: 13.121, Time: 73.61, Total Time: 5403.46, Learning Rate: 1.000e-03
# It: 7500, Loss: 4.607e+03, Y0: 13.138, Time: 74.15, Total Time: 5477.61, Learning Rate: 1.000e-03
# It: 7600, Loss: 6.689e+03, Y0: 13.247, Time: 73.34, Total Time: 5550.94, Learning Rate: 1.000e-03
# It: 7700, Loss: 7.124e+03, Y0: 13.231, Time: 73.49, Total Time: 5624.44, Learning Rate: 1.000e-03
# It: 7800, Loss: 5.634e+03, Y0: 13.267, Time: 73.52, Total Time: 5697.95, Learning Rate: 1.000e-03
# It: 7900, Loss: 5.257e+03, Y0: 13.319, Time: 74.37, Total Time: 5772.33, Learning Rate: 1.000e-03
# It: 8000, Loss: 3.775e+03, Y0: 13.339, Time: 74.45, Total Time: 5846.77, Learning Rate: 1.000e-03
# It: 8100, Loss: 5.456e+03, Y0: 13.330, Time: 73.01, Total Time: 5919.79, Learning Rate: 1.000e-03
# It: 8200, Loss: 7.320e+07, Y0: 4.529, Time: 72.72, Total Time: 5992.50, Learning Rate: 1.000e-03
# It: 8300, Loss: 1.105e+07, Y0: 5.446, Time: 72.49, Total Time: 6065.00, Learning Rate: 1.000e-03
# It: 8400, Loss: 1.442e+07, Y0: 4.536, Time: 72.36, Total Time: 6137.36, Learning Rate: 1.000e-03
# It: 8500, Loss: 2.912e+05, Y0: 6.554, Time: 72.29, Total Time: 6209.65, Learning Rate: 1.000e-03
# It: 8600, Loss: 1.166e+05, Y0: 6.700, Time: 72.48, Total Time: 6282.13, Learning Rate: 1.000e-03
# It: 8700, Loss: 4.643e+04, Y0: 6.870, Time: 71.74, Total Time: 6353.87, Learning Rate: 1.000e-03
# It: 8800, Loss: 4.189e+04, Y0: 6.944, Time: 71.86, Total Time: 6425.74, Learning Rate: 1.000e-03
# It: 8900, Loss: 3.548e+04, Y0: 7.139, Time: 71.57, Total Time: 6497.31, Learning Rate: 1.000e-03
# It: 9000, Loss: 4.891e+04, Y0: 7.239, Time: 71.95, Total Time: 6569.26, Learning Rate: 1.000e-03
# It: 9100, Loss: 5.388e+04, Y0: 7.342, Time: 72.31, Total Time: 6641.57, Learning Rate: 1.000e-03
# It: 9200, Loss: 3.419e+04, Y0: 7.516, Time: 72.22, Total Time: 6713.79, Learning Rate: 1.000e-03
# It: 9300, Loss: 3.326e+04, Y0: 7.679, Time: 72.26, Total Time: 6786.05, Learning Rate: 1.000e-03
# It: 9400, Loss: 3.798e+04, Y0: 7.837, Time: 71.98, Total Time: 6858.03, Learning Rate: 1.000e-03
# It: 9500, Loss: 2.504e+04, Y0: 7.944, Time: 71.77, Total Time: 6929.80, Learning Rate: 1.000e-03
# It: 9600, Loss: 4.042e+04, Y0: 8.060, Time: 72.22, Total Time: 7002.02, Learning Rate: 1.000e-03
# It: 9700, Loss: 4.241e+04, Y0: 8.208, Time: 71.62, Total Time: 7073.64, Learning Rate: 1.000e-03
# It: 9800, Loss: 2.656e+04, Y0: 8.267, Time: 71.59, Total Time: 7145.23, Learning Rate: 1.000e-03
# It: 9900, Loss: 3.402e+04, Y0: 8.340, Time: 71.66, Total Time: 7216.89, Learning Rate: 1.000e-03
# It: 10000, Loss: 3.040e+04, Y0: 8.465, Time: 71.81, Total Time: 7288.70, Learning Rate: 1.000e-03
# It: 10100, Loss: 3.531e+04, Y0: 8.668, Time: 72.12, Total Time: 7360.82, Learning Rate: 1.000e-03
# It: 10200, Loss: 2.954e+04, Y0: 8.758, Time: 71.77, Total Time: 7432.59, Learning Rate: 1.000e-03
# It: 10300, Loss: 3.138e+04, Y0: 8.844, Time: 72.36, Total Time: 7504.95, Learning Rate: 1.000e-03
# It: 10400, Loss: 2.754e+04, Y0: 8.882, Time: 74.72, Total Time: 7579.67, Learning Rate: 1.000e-03
# It: 10500, Loss: 2.331e+04, Y0: 9.009, Time: 75.26, Total Time: 7654.93, Learning Rate: 1.000e-03
# It: 10600, Loss: 2.460e+04, Y0: 9.141, Time: 73.86, Total Time: 7728.79, Learning Rate: 1.000e-03
# It: 10700, Loss: 2.462e+04, Y0: 9.265, Time: 72.13, Total Time: 7800.92, Learning Rate: 1.000e-03
# It: 10800, Loss: 3.166e+04, Y0: 9.383, Time: 72.08, Total Time: 7873.01, Learning Rate: 1.000e-03
# It: 10900, Loss: 2.769e+04, Y0: 9.436, Time: 73.12, Total Time: 7946.13, Learning Rate: 1.000e-03
# It: 11000, Loss: 2.744e+04, Y0: 9.557, Time: 72.93, Total Time: 8019.06, Learning Rate: 1.000e-03
# It: 11100, Loss: 3.146e+04, Y0: 9.666, Time: 73.06, Total Time: 8092.12, Learning Rate: 1.000e-03
# It: 11200, Loss: 3.390e+04, Y0: 9.878, Time: 72.70, Total Time: 8164.82, Learning Rate: 1.000e-03
# It: 11300, Loss: 2.777e+04, Y0: 9.814, Time: 72.67, Total Time: 8237.49, Learning Rate: 1.000e-03
# It: 11400, Loss: 3.613e+04, Y0: 9.918, Time: 72.27, Total Time: 8309.76, Learning Rate: 1.000e-03
# It: 11500, Loss: 2.800e+04, Y0: 9.975, Time: 72.77, Total Time: 8382.53, Learning Rate: 1.000e-03
# It: 11600, Loss: 3.408e+04, Y0: 10.050, Time: 72.83, Total Time: 8455.36, Learning Rate: 1.000e-03
# It: 11700, Loss: 2.495e+04, Y0: 10.203, Time: 72.63, Total Time: 8527.99, Learning Rate: 1.000e-03
# It: 11800, Loss: 2.060e+04, Y0: 10.189, Time: 73.03, Total Time: 8601.02, Learning Rate: 1.000e-03
# It: 11900, Loss: 2.123e+04, Y0: 10.365, Time: 72.55, Total Time: 8673.57, Learning Rate: 1.000e-03
# It: 12000, Loss: 1.384e+04, Y0: 10.446, Time: 72.72, Total Time: 8746.30, Learning Rate: 1.000e-03
# It: 12100, Loss: 2.567e+04, Y0: 10.555, Time: 72.59, Total Time: 8818.89, Learning Rate: 1.000e-03
# It: 12200, Loss: 2.521e+04, Y0: 10.670, Time: 73.57, Total Time: 8892.46, Learning Rate: 1.000e-03
# It: 12300, Loss: 1.828e+04, Y0: 10.774, Time: 72.59, Total Time: 8965.05, Learning Rate: 1.000e-03
# It: 12400, Loss: 5.384e+04, Y0: 11.057, Time: 72.96, Total Time: 9038.01, Learning Rate: 1.000e-03
# It: 12500, Loss: 1.968e+04, Y0: 11.030, Time: 72.85, Total Time: 9110.86, Learning Rate: 1.000e-03
# It: 12600, Loss: 2.145e+04, Y0: 11.033, Time: 73.03, Total Time: 9183.89, Learning Rate: 1.000e-03
# It: 12700, Loss: 2.099e+04, Y0: 11.089, Time: 72.94, Total Time: 9256.83, Learning Rate: 1.000e-03
# It: 12800, Loss: 2.399e+04, Y0: 11.116, Time: 72.85, Total Time: 9329.68, Learning Rate: 1.000e-03
# It: 12900, Loss: 2.190e+04, Y0: 11.296, Time: 72.84, Total Time: 9402.52, Learning Rate: 1.000e-03
# It: 13000, Loss: 2.896e+04, Y0: 11.438, Time: 72.60, Total Time: 9475.12, Learning Rate: 1.000e-03
# It: 13100, Loss: 4.769e+04, Y0: 11.485, Time: 72.46, Total Time: 9547.58, Learning Rate: 1.000e-03
# It: 13200, Loss: 1.780e+04, Y0: 11.490, Time: 72.84, Total Time: 9620.42, Learning Rate: 1.000e-03
# It: 13300, Loss: 2.268e+04, Y0: 11.694, Time: 72.48, Total Time: 9692.90, Learning Rate: 1.000e-03
# It: 13400, Loss: 4.417e+04, Y0: 11.702, Time: 72.91, Total Time: 9765.81, Learning Rate: 1.000e-03
# It: 13500, Loss: 2.334e+04, Y0: 11.774, Time: 72.81, Total Time: 9838.62, Learning Rate: 1.000e-03
# It: 13600, Loss: 2.016e+04, Y0: 11.996, Time: 72.53, Total Time: 9911.14, Learning Rate: 1.000e-03
# It: 13700, Loss: 1.348e+04, Y0: 12.071, Time: 72.40, Total Time: 9983.55, Learning Rate: 1.000e-03
# It: 13800, Loss: 1.737e+04, Y0: 12.111, Time: 72.46, Total Time: 10056.00, Learning Rate: 1.000e-03
# It: 13900, Loss: 1.878e+04, Y0: 12.204, Time: 72.22, Total Time: 10128.22, Learning Rate: 1.000e-03
# It: 14000, Loss: 9.665e+03, Y0: 12.310, Time: 72.51, Total Time: 10200.73, Learning Rate: 1.000e-03
# It: 14100, Loss: 1.192e+04, Y0: 12.402, Time: 72.22, Total Time: 10272.95, Learning Rate: 1.000e-03
# It: 14200, Loss: 1.717e+04, Y0: 12.438, Time: 72.93, Total Time: 10345.88, Learning Rate: 1.000e-03
# It: 14300, Loss: 1.565e+04, Y0: 12.585, Time: 73.23, Total Time: 10419.11, Learning Rate: 1.000e-03
# It: 14400, Loss: 1.528e+04, Y0: 12.689, Time: 73.03, Total Time: 10492.14, Learning Rate: 1.000e-03
# It: 14500, Loss: 1.525e+04, Y0: 12.708, Time: 73.31, Total Time: 10565.45, Learning Rate: 1.000e-03
# It: 14600, Loss: 1.121e+04, Y0: 12.757, Time: 73.04, Total Time: 10638.49, Learning Rate: 1.000e-03
# It: 14700, Loss: 1.338e+04, Y0: 12.884, Time: 73.49, Total Time: 10711.98, Learning Rate: 1.000e-03
# It: 14800, Loss: 1.107e+04, Y0: 12.930, Time: 73.28, Total Time: 10785.25, Learning Rate: 1.000e-03
# It: 14900, Loss: 1.653e+04, Y0: 12.979, Time: 72.44, Total Time: 10857.69, Learning Rate: 1.000e-03
# It: 15000, Loss: 1.352e+04, Y0: 13.006, Time: 71.65, Total Time: 10929.34, Learning Rate: 1.000e-03
# It: 15100, Loss: 1.649e+04, Y0: 13.116, Time: 72.19, Total Time: 11001.54, Learning Rate: 1.000e-03
# It: 15200, Loss: 1.264e+04, Y0: 13.170, Time: 72.92, Total Time: 11074.45, Learning Rate: 1.000e-03
# It: 15300, Loss: 9.982e+03, Y0: 13.167, Time: 71.52, Total Time: 11145.97, Learning Rate: 1.000e-03
# It: 15400, Loss: 1.665e+04, Y0: 13.222, Time: 71.25, Total Time: 11217.22, Learning Rate: 1.000e-03
# It: 15500, Loss: 1.497e+04, Y0: 13.286, Time: 71.23, Total Time: 11288.45, Learning Rate: 1.000e-03
# It: 15600, Loss: 1.065e+04, Y0: 13.354, Time: 71.27, Total Time: 11359.71, Learning Rate: 1.000e-03
# It: 15700, Loss: 8.548e+03, Y0: 13.410, Time: 70.47, Total Time: 11430.18, Learning Rate: 1.000e-03
# It: 15800, Loss: 8.833e+03, Y0: 13.566, Time: 71.66, Total Time: 11501.84, Learning Rate: 1.000e-03
# It: 15900, Loss: 9.566e+03, Y0: 13.637, Time: 71.90, Total Time: 11573.75, Learning Rate: 1.000e-03
# It: 16000, Loss: 1.116e+04, Y0: 13.688, Time: 72.11, Total Time: 11645.86, Learning Rate: 1.000e-03
# It: 16100, Loss: 9.328e+03, Y0: 13.782, Time: 70.57, Total Time: 11716.43, Learning Rate: 1.000e-03
# It: 16200, Loss: 1.645e+04, Y0: 13.703, Time: 71.29, Total Time: 11787.72, Learning Rate: 1.000e-03
# It: 16300, Loss: 8.979e+03, Y0: 13.756, Time: 72.06, Total Time: 11859.78, Learning Rate: 1.000e-03
# It: 16400, Loss: 5.720e+03, Y0: 13.802, Time: 70.95, Total Time: 11930.73, Learning Rate: 1.000e-03
# It: 16500, Loss: 1.078e+04, Y0: 13.884, Time: 70.96, Total Time: 12001.69, Learning Rate: 1.000e-03
# It: 16600, Loss: 1.025e+04, Y0: 13.860, Time: 71.00, Total Time: 12072.69, Learning Rate: 1.000e-03
# It: 16700, Loss: 9.317e+06, Y0: 14.371, Time: 71.02, Total Time: 12143.72, Learning Rate: 1.000e-03
# It: 16800, Loss: 1.389e+07, Y0: 11.694, Time: 71.77, Total Time: 12215.49, Learning Rate: 1.000e-03
# It: 16900, Loss: 8.567e+06, Y0: 12.954, Time: 72.20, Total Time: 12287.68, Learning Rate: 1.000e-03
# It: 17000, Loss: 7.077e+06, Y0: 13.176, Time: 71.07, Total Time: 12358.75, Learning Rate: 1.000e-03
# It: 17100, Loss: 1.587e+06, Y0: 13.697, Time: 70.81, Total Time: 12429.56, Learning Rate: 1.000e-03
# It: 17200, Loss: 3.390e+06, Y0: 14.020, Time: 72.13, Total Time: 12501.69, Learning Rate: 1.000e-03
# It: 17300, Loss: 2.483e+06, Y0: 13.651, Time: 71.07, Total Time: 12572.76, Learning Rate: 1.000e-03
# It: 17400, Loss: 1.228e+06, Y0: 13.733, Time: 71.32, Total Time: 12644.08, Learning Rate: 1.000e-03
# It: 17500, Loss: 9.972e+06, Y0: 14.838, Time: 72.79, Total Time: 12716.87, Learning Rate: 1.000e-03
# It: 17600, Loss: 5.285e+08, Y0: 13.905, Time: 73.13, Total Time: 12790.01, Learning Rate: 1.000e-03
# It: 17700, Loss: 3.362e+08, Y0: 13.317, Time: 73.40, Total Time: 12863.41, Learning Rate: 1.000e-03
# It: 17800, Loss: 2.167e+08, Y0: 13.324, Time: 74.43, Total Time: 12937.84, Learning Rate: 1.000e-03
# It: 17900, Loss: 5.116e+07, Y0: 14.201, Time: 74.59, Total Time: 13012.42, Learning Rate: 1.000e-03
# It: 18000, Loss: 1.176e+07, Y0: 13.046, Time: 73.82, Total Time: 13086.24, Learning Rate: 1.000e-03
# It: 18100, Loss: 2.204e+07, Y0: 14.288, Time: 73.44, Total Time: 13159.68, Learning Rate: 1.000e-03
# It: 18200, Loss: 3.430e+07, Y0: 13.745, Time: 72.40, Total Time: 13232.08, Learning Rate: 1.000e-03
# It: 18300, Loss: 1.349e+07, Y0: 13.940, Time: 72.35, Total Time: 13304.43, Learning Rate: 1.000e-03
# It: 18400, Loss: 1.948e+07, Y0: 13.772, Time: 72.25, Total Time: 13376.69, Learning Rate: 1.000e-03
# It: 18500, Loss: 1.184e+07, Y0: 14.134, Time: 71.85, Total Time: 13448.53, Learning Rate: 1.000e-03
# It: 18600, Loss: 2.638e+07, Y0: 13.839, Time: 72.14, Total Time: 13520.68, Learning Rate: 1.000e-03
# It: 18700, Loss: 1.734e+07, Y0: 14.440, Time: 71.69, Total Time: 13592.36, Learning Rate: 1.000e-03
# It: 18800, Loss: 1.901e+07, Y0: 14.145, Time: 71.64, Total Time: 13664.00, Learning Rate: 1.000e-03
# It: 18900, Loss: 1.511e+07, Y0: 14.316, Time: 71.56, Total Time: 13735.56, Learning Rate: 1.000e-03
# It: 19000, Loss: 1.198e+07, Y0: 14.424, Time: 72.02, Total Time: 13807.58, Learning Rate: 1.000e-03
# It: 19100, Loss: 7.561e+06, Y0: 14.157, Time: 72.23, Total Time: 13879.81, Learning Rate: 1.000e-03
# It: 19200, Loss: 6.106e+06, Y0: 14.245, Time: 72.67, Total Time: 13952.48, Learning Rate: 1.000e-03
# It: 19300, Loss: 5.935e+06, Y0: 14.119, Time: 72.84, Total Time: 14025.32, Learning Rate: 1.000e-03
# It: 19400, Loss: 4.757e+06, Y0: 14.010, Time: 73.92, Total Time: 14099.24, Learning Rate: 1.000e-03
# It: 19500, Loss: 3.161e+06, Y0: 14.221, Time: 74.15, Total Time: 14173.40, Learning Rate: 1.000e-03
# It: 19600, Loss: 4.621e+06, Y0: 14.134, Time: 73.24, Total Time: 14246.64, Learning Rate: 1.000e-03
# It: 19700, Loss: 4.689e+06, Y0: 13.948, Time: 72.80, Total Time: 14319.44, Learning Rate: 1.000e-03
# It: 19800, Loss: 2.576e+06, Y0: 14.108, Time: 73.01, Total Time: 14392.46, Learning Rate: 1.000e-03
# It: 19900, Loss: 2.075e+06, Y0: 14.101, Time: 73.08, Total Time: 14465.54, Learning Rate: 1.000e-03

# %%
np.random.seed(42)
t_test, B_test = model.fetch_minibatch()
W_test, Var_test = model.variance()

X_pred, Y_pred, delta_pred = model.predict(Xi, t_test, W_test, B_test, Var_test)
#Y0_test = 4.9550

# %%
D = 20
plt.figure()
plt.plot(graph[0], graph[1])
plt.xlabel('Iterations')
plt.ylabel('Value')
plt.yscale("log")
plt.title('Evolution of the training loss')
plt.savefig(str(D) + 'train-loss' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(Y0_iter[0], Y0_iter[1], label='Learned $Y_0$')
#plt.axhline(Y0_test, color='r', label='Exact $Y_0$')
plt.xlabel('Iterations')
plt.ylabel('Y Initial Value')
#plt.yscale("log")
plt.title('Evolution of the Y Initial')
plt.savefig(str(D) + ' Initial' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(delta_iter[0], delta_iter[1], label='Learned $Delta_T$')
plt.xlabel('Iterations')
plt.ylabel('Delta Value')
#plt.yscale("log")
plt.title('Evolution of the Delta')
plt.savefig(str(D) + 'Delta' + 'RoughBergomiModel')

# %%
tf.experimental.numpy.experimental_enable_numpy_behavior()

# %%
samples = 5
plt.figure()
plt.plot(t_test[0:1, :, 0].T, Y_pred[0:1, :, 0].T, 'b', label='Learned $u(t,X_t)$')

plt.plot(t_test[1:samples, :, 0].T, Y_pred[1:samples, :, 0].T, 'b')

plt.xlabel('$t$')
plt.ylabel('$Y_t = u(t,X_t)$')
plt.title(str(D) + '-dimensional RoughBergomiModel')
plt.legend()
plt.savefig(str(D) +'-dimensional RoughBergomiModel' + 'traces')

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (0.9.0)

# %%
#. Monte Carlo Simulation 
T_mc = 1.0  # terminal time
M_mc = 10000  # number of trajectories
N_mc = 50  # number of time snapshots
D_mc = 20  # number of dimensions
H_mc = 0.07  # Hurst exponent (0,1)
eta_mc = 1.9  # parameter for control volatility
pho_mc = -0.9  # correlation betwen two independent Wiener process
r_mc = 0.05  # interest rate

layers_mc = [D_mc+1] + 4 * [256] + [1+D_mc]

Xi_mc = np.array([np.log(100.0), np.log(50.0)] * int(D_mc/2) )[None, :]
model_mc = RoughBergomiModel(Xi_mc, T_mc, M_mc, N_mc, D_mc, H_mc, eta_mc, pho_mc, r_mc, layers_mc)

np.random.seed(42)
t_mc_test, B_mc_test = model_mc.fetch_minibatch()
W_mc_test, Var_mc_test = model_mc.variance()

def MC_simulation(t, W, B, Var, Xi):

    X_list = []

    t0 = t[:, 0, :]
    W0 = W[:, 0, :]
    B0 = B[:, 0, :]
    Var0 = Var[:, 0, :]

    X0 = tf.tile(Xi, [M_mc, 1])  # M x D
    X_list.append(X0)

    for n in range(0, N_mc):
        t1 = t[:, n + 1, :]
        W1 = W[:, n + 1, :]
        B1 = B[:, n + 1, :]
        Var1 = Var[:, n + 1, :]

        BM = pho_mc * (W1 - W0) + np.sqrt(1 - np.square(pho_mc)) * (B1 - B0)
        X1 = X0 - Var0 * 0.5 * (t1 - t0)+ np.sqrt(Var0) * BM

        t0 = t1
        W0 = W1
        B0 = B1
        Var0 = Var1
        X0 = X1
        
        X_list.append(X0)
       
    X = tf.stack(X_list, axis=1)
    return X

X_mc = MC_simulation(t_mc_test, W_mc_test, B_mc_test, Var_mc_test, Xi_mc)
K_mc = np.tile(np.array([90.0], dtype=np.float32)[None, :], [M_mc, 1])
S_T_mc = np.mean(np.exp(X_mc[:, -1, :] + r_mc * T_mc), axis=1, keepdims = True)
put_option_mc = np.mean(np.maximum(K_mc - S_T_mc, 0.0), axis=0) * np.exp(-r_mc * T_mc)

# %%
Y_pred_mean = np.mean(Y_pred, axis=0)
Y_pred_std = np.std(Y_pred, axis=0)
error = Y_pred_mean[0, 0] - put_option_mc
#print('Y0_mean is: {}'.format(Y_pred_mean[0, 0]))
#print('Y0_exact is: {}'.format(Y0_test))
#print('Y0_std is: {}'.format(Y_pred_std[0, 0]))
#print('Relative Error is: {}'.format(error))

# %%
from tabulate import tabulate
table = {'reference value': put_option_mc, 'Y0_mean': Y_pred_mean[0, :].tolist(), 'Y0_std': Y_pred_std[0, :].tolist(), 'relative error': error}
print(tabulate(table, headers='keys', tablefmt='github'))
# Out:
# |   reference value |   Y0_mean |      Y0_std |   relative error |
# |-------------------|-----------|-------------|------------------|
# |           13.9343 |   14.2044 | 1.62125e-05 |         0.270113 |
