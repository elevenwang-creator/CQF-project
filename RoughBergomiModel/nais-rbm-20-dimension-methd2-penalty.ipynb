# %%
# basic imports
import os, random
import numpy as np
import datetime as dt
import time
from scipy.fftpack import fft, ifft
from abc import ABC, abstractmethod
import matplotlib.pyplot as plt

# warnings
import warnings

warnings.filterwarnings('ignore')

# tensorflow
import tensorflow as tf

tf.keras.backend.clear_session()

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam, AdamW, RMSprop
from tensorflow.keras.layers import Layer, Add
# Out:
# 2024-08-19 11:13:26.109012: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-19 11:13:26.109106: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-19 11:13:26.244789: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print(f" TensorFlow version is {tf.__version__}")
#print(f"Keras version is {tf.keras.__version__}")
print(tf.config.list_physical_devices())
# Out:
#  TensorFlow version is 2.15.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class Linear(Layer):
    """Define Linear layers"""

    def __init__(self, in_features, out_features):
        super(Linear, self).__init__()

        self.in_dims = in_features
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'
        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        return tf.matmul(inputs, self.w) + self.b


class StableLinear(Layer):
    """Define Stable Linear layers"""

    def __init__(self, in_features, out_features):
        super(StableLinear, self).__init__()

        self.epsilon = 0.01
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'

        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        w = self.weight_constraint(self.w)
        return tf.matmul(inputs, w) + self.b

    #@tf.function
    def weight_constraint(self, weight):
        delta = 1 - 2 * self.epsilon
        RtR = tf.matmul(tf.transpose(weight), weight)
        norm = tf.norm(RtR)

        #if norm > delta: RtR = delta ** (1 / 2) * RtR / (norm ** (1 / 2))
        RtR_new = tf.sqrt(delta) * RtR / tf.sqrt(norm)
        RtR_update = tf.minimum(RtR_new, RtR)
        #def f2(): return RtR
        #RtR = tf.cond(tf.greater(norm, delta), f1, f2)
        A = RtR_update + tf.eye(RtR.shape[0]) * self.epsilon
        return -A


class NaisNet(Model):
    """ Building NAIS_Net network using keras """

    def __init__(self, layers):
        super(NaisNet, self).__init__()

        self.layer1 = Linear(layers[0], layers[1])

        self.layer2 = StableLinear(layers[1], layers[2])
        self.layer2_input = Linear(layers[0], layers[2])

        self.layer3 = StableLinear(layers[2], layers[3])
        self.layer3_input = Linear(layers[0], layers[3])

        self.layer4 = StableLinear(layers[3], layers[4])
        self.layer4_input = Linear(layers[0], layers[4])

        self.layer5 = Linear(layers[4], layers[5])
        self.layer6 = Linear(layers[4], layers[6])

    # Building block for the NAIS-Net
    #@tf.function
    def call(self, x):
        """Process stages in the block"""

        u = x

        output = self.layer1(u)  # layer 1
        output = tf.sin(output)

        X1 = output
        output = self.layer2(output)  # layer 2
        output = Add()([self.layer2_input(u), output])
        output = tf.sin(output)
        output = Add()([X1, output])

        X2 = output
        output = self.layer3(output)  # layer 3
        output = Add()([self.layer3_input(u), output])
        output = tf.sin(output)
        output = Add()([X2, output])

        X3 = output
        output = self.layer4(output)  # layer 4
        output = Add()([self.layer4_input(u), output])
        output = tf.sin(output)
        output = Add()([X3, output])

        output1 = self.layer5(output)  # layer 5
        output2 = self.layer6(output)
        return output1, output2


class FBSNN(ABC):
    """Forward-Backward SDEs using NAIS-Net """

    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):    # , layer_phi

        self.Xi = Xi  # initial point

        self.T = T  # terminal time
        self.M = M  # number of trajectories
        self.N = N  # number of time snapshots
        self.D = D  # number of dimensions
        self.H = H  # Hurst exponent (0,1)
        self.eta = eta  # parameter for control volatility
        self.pho = tf.cast(pho, dtype=tf.float32) # correlation betwen two independent Wiener process
        self.epsilon_t = 0.09 # forward variance curve epsilon(t) - constant
        self.r = tf.cast(r, dtype=tf.float32)  # interest rate
           
        # Initialize NN
        #self.phi_input_shape = tf.cast(layers[0], dtype=tf.int32)
        #self.phi_output_shape= tf.cast(self.D, dtype=tf.int32)
        #self.phi_weight, self.phi_bias = self.init_wb([self.phi_input_shape, self.phi_output_shape])
        self.model = NaisNet(layers)
        #self.model_phi = NaisNet(layer_phi)

        # Record the loss
        self.training_loss = []
        self.iteration = []
        self.Y0_iter = []
        self.Du0_iter = []

    #def init_wb(self,size):
    #    xavier_stddev = tf.cast(tf.sqrt(tf.divide(2, tf.add(size[0], size[1]))),dtype=tf.float32)
    #    weight = tf.Variable(tf.random.truncated_normal([self.phi_input_shape, self.phi_output_shape],
    #                                           stddev=xavier_stddev), trainable=True, dtype=tf.float32)
        #weitht = self.xavier_init([self.phi_input_shape, self.phi_output_shape]) 
    #    bias = tf.Variable(tf.zeros([1, self.phi_output_shape]), dtype=tf.float32) 
    #    return  weight, bias
    
    #def phi_tf(self,inputs):
    #    return tf.matmul(inputs, self.phi_weight) + self.phi_bias
    
    @tf.function
    def net_u(self, t, X):  # M x 1, M x D

        u, phi = self.model(tf.concat([t, X], 1))  # M x [1+D]
        #u = tf.expand_dims(y[:, 0], axis=-1)  # M x 1
        #phi = self.model_phi(tf.concat([t, X], 1)) # M x D
        #phi = self.phi_tf(tf.concat([t,X], 1))
        #phi = y[:, 1:] # M x D
        Du = tf.gradients(u, X)[0]  # M x D

        return u, phi, Du

    @tf.function
    def Dg_tf(self, X):  # M x D
        return tf.gradients(self.g_tf(X), X)[0]  # M x D

    #@tf.function
    def loss_function(self, t, W, B, Var, Xi):

        loss = 0
        X_list = []
        Y_list = []
        Tilde_Z_list = []
        Z_list = []
        Du_list = []


        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        B0 = B[:, 0, :]
        Var0 = Var[:, 0, :]

        X0 = tf.tile(Xi, [self.M, 1])  # M x D
        Y0, phi0, du0 = self.net_u(t0, X0)  # M x 1, M x D, M x D
        Z0 = self.Z_tf(Var0,du0) # M x D
        Tilde_Z0 = self.Z_tilde_tf(Var0, phi0, du0) # M x D

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)
        Tilde_Z_list.append(Tilde_Z0)
        Du_list.append(du0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]
            B1 = B[:, n + 1, :]
            Var1 = Var[:, n + 1, :]
            BM = self.pho * (W1 - W0) + tf.sqrt(1 - self.pho**2) * (B1 - B0)
            X1 = X0 +self.mu_tf(t0, X0, Y0, du0) * (t1 - t0)  - Var0 * 0.5 * (t1 - t0) + tf.sqrt(Var0) * BM

            Y1_tilde = Y0 + self.F_tf(t0, X0, Y0, Z0, Tilde_Z0) * (t1 - t0) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Z0, tf.expand_dims(B1 - B0, -1))), axis=1, 
                keepdims=True) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Tilde_Z0, tf.expand_dims(W1 - W0, -1))), axis=1, keepdims=True)
            
            Y1, phi1, du1 = self.net_u(t1, X1)
            Z1 = self.Z_tf(Var1,du1) # M x D
            Tilde_Z1 = self.Z_tilde_tf(Var1, phi1, du1) # M x D


            loss += tf.reduce_sum(tf.pow(Y1 - Y1_tilde, 2))

            t0 = t1
            W0 = W1
            B0 = B1
            Var0 = Var1
            du0 = du1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            Tilde_Z0 = Tilde_Z1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)
            Tilde_Z_list.append(Tilde_Z0)
            Du_list.append(du0)
        
        # 0.02 is the penalty parameters for the terminal conditions
        loss += 0.02 * tf.reduce_sum(tf.pow(Y1 - self.g_tf(X1), 2))
        loss += 0.02 * tf.reduce_sum(tf.pow(du1 - self.Dg_tf(X1), 2))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)
        Tilde_Z = tf.stack(Tilde_Z_list, axis=1)
        Du_t = tf.stack(Du_list, axis=1)
        #Y0 = tf.reduce_mean(Y, axis=0)

        return loss, X, Y, Y[0, 0, 0], Du_t

    def Z_tf(self, Var, Du):  # M x D
        return tf.sqrt((1 - self.pho**2) * Var) * Du

    def Z_tilde_tf(self, Var, phi, Du): # M x D
        return self.pho * tf.sqrt(Var) * Du + phi

    # Volterra process Using hybrid scheme
    def volterra(self):
        T = self.T
        M = self.M
        N = self.N
        D = self.D
        delta_t = T / N
        alpha = self.H - 0.5
        
        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D
        Dt[:, 1:, :] = delta_t
        DW[:, 1:, :] = np.sqrt(delta_t) * np.random.normal(size=(M, N, D))
        
        t_series = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W_process = np.cumsum(DW, axis=1)  # M x (N+1) x D

        sigma = (2*alpha + 1)**0.5
        #kernal function
        def g_kernel(k):
            y = (k**(alpha+1) - (k-1)**(alpha+1)) / (alpha+1)
            b = np.power(y, 1/alpha)
            return np.power((b) * delta_t, alpha)

        #t_series, W_process = self.fetch_minibatch()

        tilde_X = np.zeros((M, N+1, D))
        tilde_X[:, 0 , :]= W_process[:, 0 , :]

        WN_tj_minus_1_1 = np.roll(W_process, shift=-1, axis=1) - W_process

        for m in range(M):
            for d in range(D):
                # first column for toeplitz matrix 
                WN_j = WN_tj_minus_1_1[m, :-1, d]
                sigma_col = np.zeros((N)) 
                sigma_col[0] = np.power(delta_t/2, alpha) * sigma
                # 
                for k in range(1, N):
                    g_b_star_k = g_kernel(k+1)
                    sigma_col[k] = sigma * g_b_star_k

                # FFT and dot
                WN_j_fft = fft(WN_j)
                sigma_fft = fft(sigma_col)
                convolved = ifft(WN_j_fft * sigma_fft) 

                # capture real value 
                tilde_X[m, 1:, d] = np.real(convolved)
        
        return t_series, W_process, tilde_X

    # Variace process
    def variance(self):

        t, W_s, D_hat_w = self.volterra()# M x (N+1) x D

        var = self.epsilon_t * np.exp(self.eta* D_hat_w -  0.5 * self.eta**2 * np.power(t, 2*self.H))

        return W_s, var

    #@tf.function
    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W = np.cumsum(DW, axis=1)  # M x (N+1) x D

        return t, W

    @tf.function
    def train_step(self, optimizers, t, w, b, var, Xi):
        # Optimizers
        optimizer = optimizers

        with tf.GradientTape() as tape:
            loss_value, X_pred, Y_pred, Y0_pred, Du0_pred = self.loss_function(t, w, b, var, Xi)

        grads = tape.gradient(loss_value, self.model.trainable_weights)
        #optimizer.apply(grads, self.model.trainable_weights)
        optimizer.apply_gradients(zip(grads, self.model.trainable_weights))


        return loss_value, Y0_pred, Du0_pred

    #@tf.function
    def train(self, N_Iter, learning_rate):

        loss_temp = np.array([])
        Y0_pred_temp = np.array([])
        Du0_pred_temp = np.array([])

        # Optimizers
        #self.optimizer = AdamW(learning_rate=learning_rate, weight_decay=0.001)
        self.optimizer = Adam(learning_rate=learning_rate)

        start_time = time.time()
        ini_time = time.time()

        for it in range(N_Iter):

            t_batch, B_batch = self.fetch_minibatch()  # M x (N+1) x 1, M x (N+1) x D
            W_batch, Var_batch = self.variance() # M x (N+1) x D, M x (N+1) x D
            t_batch = tf.convert_to_tensor(t_batch, dtype=tf.float32)
            B_batch = tf.convert_to_tensor(B_batch, dtype=tf.float32)
            W_batch = tf.convert_to_tensor(W_batch, dtype=tf.float32)
            Var_batch = tf.convert_to_tensor(Var_batch, dtype=tf.float32)
            self.Xi = tf.convert_to_tensor(self.Xi, dtype=tf.float32)

            loss_value, Y0_pred, Du0_pred = self.train_step(self.optimizer, t_batch, W_batch, B_batch, Var_batch, self.Xi)

            if it % 100 == 0:
                elapsed = time.time() - start_time
                total_time = time.time() - ini_time
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Total Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_pred, elapsed, total_time, learning_rate))
                start_time = time.time()

            loss_temp = np.append(loss_temp, loss_value.numpy())
            Y0_pred_temp = np.append(Y0_pred_temp, Y0_pred.numpy())

            Du0 = tf.reduce_mean(Du0_pred, axis=0)
            Du0_pred_temp = np.append(Du0_pred_temp, Du0.numpy()[0, 0])

            if it % 100 == 0:
                self.training_loss.append(loss_temp.mean())
                self.Y0_iter.append(Y0_pred_temp[-100:].mean())
                self.Du0_iter.append(Du0_pred_temp[-100:].mean())
                self.iteration.append(it)
  
            graph = np.stack((self.iteration, self.training_loss))
            Y0_iter = np.stack((self.iteration, self.Y0_iter))
            Du0_iter = np.stack((self.iteration, self.Du0_iter))

        return graph,Y0_iter, Du0_iter

    def predict(self, Xi_star, t_star, W_star, B_star, Var_star):
        t_star = tf.convert_to_tensor(t_star, dtype=tf.float32)
        W_star = tf.convert_to_tensor(W_star, dtype=tf.float32)
        Xi_star = tf.convert_to_tensor(Xi_star, dtype=tf.float32)
        B_star = tf.convert_to_tensor(B_star, dtype=tf.float32)
        Var_star = tf.convert_to_tensor(Var_star, dtype=tf.float32)        

        loss, X_star, Y_star, Y0_pred, delta_star = self.loss_function(t_star, W_star, B_star, Var_star, Xi_star)

        return X_star, Y_star, delta_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        pass  # M x1

    @abstractmethod
    def g_tf(self, X):  # M x D
        pass  # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return tf.zeros([M, D])  # M x D
    ###########################################################################

# %%
class RoughBergomiModel(FBSNN):
    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):
        super().__init__(Xi, T, M, N, D, H, eta, pho, r, layers)

    def g_tf(self, X):  # M x D
        K = tf.tile(np.array([90.0], dtype=np.float32)[None, :], [self.M, 1])
        X = tf.reduce_mean(tf.exp(X + self.r * self.T), axis=1, keepdims = True)
        return tf.maximum(K - X, 0) # M x 1  

    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        return super().mu_tf(t, X, Y, Du)  # M x D

    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        return self.r * Y # M x1

    ###########################################################################

# %%
T = 1.0  # terminal time
M = 100  # number of trajectories
N = 50  # number of time snapshots
D = 20  # number of dimensions
H = 0.07  # Hurst exponent (0,1)
eta = 1.9  # parameter for control volatility
pho = -0.9  # correlation betwen two independent Wiener process
r = 0.05  # interest rate

Xi = np.array([np.log(100.0), np.log(50.0)] * int(D / 2))[None, :]

layers = [D+1] + 4 * [256] + [1] + [D]

model = RoughBergomiModel(Xi, T, M, N, D, H, eta, pho, r, layers)
graph, Y0_iter, delta_iter = model.train(2*10**4, 1e-3)
# Out:
# It: 0, Loss: 7.198e+07, Y0: -1.217, Time: 28.65, Total Time: 28.65, Learning Rate: 1.000e-03
# It: 100, Loss: 3.500e+04, Y0: -0.545, Time: 72.04, Total Time: 100.69, Learning Rate: 1.000e-03
# It: 200, Loss: 4.848e+04, Y0: -0.276, Time: 70.90, Total Time: 171.59, Learning Rate: 1.000e-03
# It: 300, Loss: 7.326e+04, Y0: -0.054, Time: 70.27, Total Time: 241.87, Learning Rate: 1.000e-03
# It: 400, Loss: 8.826e+04, Y0: 0.115, Time: 70.55, Total Time: 312.41, Learning Rate: 1.000e-03
# It: 500, Loss: 5.869e+04, Y0: 0.283, Time: 70.54, Total Time: 382.95, Learning Rate: 1.000e-03
# It: 600, Loss: 7.258e+04, Y0: 0.504, Time: 70.42, Total Time: 453.37, Learning Rate: 1.000e-03
# It: 700, Loss: 6.791e+04, Y0: 0.731, Time: 70.54, Total Time: 523.91, Learning Rate: 1.000e-03
# It: 800, Loss: 4.930e+04, Y0: 1.006, Time: 70.18, Total Time: 594.09, Learning Rate: 1.000e-03
# It: 900, Loss: 6.716e+04, Y0: 1.210, Time: 71.12, Total Time: 665.21, Learning Rate: 1.000e-03
# It: 1000, Loss: 3.744e+04, Y0: 1.423, Time: 70.94, Total Time: 736.15, Learning Rate: 1.000e-03
# It: 1100, Loss: 3.625e+04, Y0: 1.699, Time: 70.79, Total Time: 806.95, Learning Rate: 1.000e-03
# It: 1200, Loss: 4.649e+04, Y0: 1.929, Time: 70.60, Total Time: 877.55, Learning Rate: 1.000e-03
# It: 1300, Loss: 2.330e+04, Y0: 2.271, Time: 72.64, Total Time: 950.19, Learning Rate: 1.000e-03
# It: 1400, Loss: 2.721e+04, Y0: 2.590, Time: 72.24, Total Time: 1022.42, Learning Rate: 1.000e-03
# It: 1500, Loss: 3.456e+04, Y0: 2.953, Time: 70.64, Total Time: 1093.07, Learning Rate: 1.000e-03
# It: 1600, Loss: 3.298e+04, Y0: 3.288, Time: 70.03, Total Time: 1163.09, Learning Rate: 1.000e-03
# It: 1700, Loss: 2.200e+04, Y0: 3.612, Time: 70.28, Total Time: 1233.38, Learning Rate: 1.000e-03
# It: 1800, Loss: 1.157e+04, Y0: 3.968, Time: 69.75, Total Time: 1303.13, Learning Rate: 1.000e-03
# It: 1900, Loss: 1.212e+04, Y0: 4.305, Time: 69.62, Total Time: 1372.75, Learning Rate: 1.000e-03
# It: 2000, Loss: 2.256e+04, Y0: 4.618, Time: 69.98, Total Time: 1442.73, Learning Rate: 1.000e-03
# It: 2100, Loss: 1.899e+04, Y0: 4.895, Time: 69.88, Total Time: 1512.62, Learning Rate: 1.000e-03
# It: 2200, Loss: 2.137e+04, Y0: 5.259, Time: 70.14, Total Time: 1582.76, Learning Rate: 1.000e-03
# It: 2300, Loss: 1.428e+04, Y0: 5.619, Time: 70.50, Total Time: 1653.25, Learning Rate: 1.000e-03
# It: 2400, Loss: 2.505e+04, Y0: 5.960, Time: 70.85, Total Time: 1724.10, Learning Rate: 1.000e-03
# It: 2500, Loss: 2.558e+04, Y0: 6.227, Time: 70.88, Total Time: 1794.98, Learning Rate: 1.000e-03
# It: 2600, Loss: 9.681e+03, Y0: 6.511, Time: 70.44, Total Time: 1865.42, Learning Rate: 1.000e-03
# It: 2700, Loss: 1.894e+04, Y0: 6.787, Time: 70.15, Total Time: 1935.57, Learning Rate: 1.000e-03
# It: 2800, Loss: 2.352e+04, Y0: 7.104, Time: 70.69, Total Time: 2006.26, Learning Rate: 1.000e-03
# It: 2900, Loss: 7.222e+03, Y0: 7.453, Time: 71.05, Total Time: 2077.31, Learning Rate: 1.000e-03
# It: 3000, Loss: 9.363e+03, Y0: 7.761, Time: 70.64, Total Time: 2147.95, Learning Rate: 1.000e-03
# It: 3100, Loss: 1.363e+04, Y0: 8.046, Time: 70.67, Total Time: 2218.62, Learning Rate: 1.000e-03
# It: 3200, Loss: 1.280e+04, Y0: 8.410, Time: 70.35, Total Time: 2288.97, Learning Rate: 1.000e-03
# It: 3300, Loss: 1.107e+04, Y0: 8.723, Time: 71.72, Total Time: 2360.69, Learning Rate: 1.000e-03
# It: 3400, Loss: 1.599e+04, Y0: 9.003, Time: 71.30, Total Time: 2431.99, Learning Rate: 1.000e-03
# It: 3500, Loss: 1.478e+04, Y0: 9.227, Time: 70.56, Total Time: 2502.55, Learning Rate: 1.000e-03
# It: 3600, Loss: 1.978e+04, Y0: 9.486, Time: 70.36, Total Time: 2572.92, Learning Rate: 1.000e-03
# It: 3700, Loss: 8.515e+03, Y0: 9.756, Time: 71.20, Total Time: 2644.12, Learning Rate: 1.000e-03
# It: 3800, Loss: 1.426e+04, Y0: 9.974, Time: 70.62, Total Time: 2714.74, Learning Rate: 1.000e-03
# It: 3900, Loss: 5.519e+03, Y0: 10.228, Time: 70.57, Total Time: 2785.31, Learning Rate: 1.000e-03
# It: 4000, Loss: 1.031e+04, Y0: 10.354, Time: 70.70, Total Time: 2856.02, Learning Rate: 1.000e-03
# It: 4100, Loss: 9.163e+03, Y0: 10.544, Time: 70.82, Total Time: 2926.84, Learning Rate: 1.000e-03
# It: 4200, Loss: 7.186e+03, Y0: 10.749, Time: 70.57, Total Time: 2997.41, Learning Rate: 1.000e-03
# It: 4300, Loss: 8.481e+03, Y0: 10.914, Time: 70.57, Total Time: 3067.99, Learning Rate: 1.000e-03
# It: 4400, Loss: 7.634e+03, Y0: 11.077, Time: 70.35, Total Time: 3138.34, Learning Rate: 1.000e-03
# It: 4500, Loss: 1.731e+04, Y0: 11.221, Time: 70.67, Total Time: 3209.01, Learning Rate: 1.000e-03
# It: 4600, Loss: 8.399e+03, Y0: 11.401, Time: 71.05, Total Time: 3280.06, Learning Rate: 1.000e-03
# It: 4700, Loss: 1.271e+04, Y0: 11.535, Time: 70.82, Total Time: 3350.88, Learning Rate: 1.000e-03
# It: 4800, Loss: 8.305e+03, Y0: 11.715, Time: 70.57, Total Time: 3421.45, Learning Rate: 1.000e-03
# It: 4900, Loss: 1.385e+04, Y0: 11.841, Time: 70.20, Total Time: 3491.66, Learning Rate: 1.000e-03
# It: 5000, Loss: 8.763e+03, Y0: 11.990, Time: 69.50, Total Time: 3561.15, Learning Rate: 1.000e-03
# It: 5100, Loss: 6.363e+03, Y0: 12.095, Time: 70.05, Total Time: 3631.20, Learning Rate: 1.000e-03
# It: 5200, Loss: 1.623e+04, Y0: 12.156, Time: 69.44, Total Time: 3700.65, Learning Rate: 1.000e-03
# It: 5300, Loss: 9.497e+03, Y0: 12.245, Time: 69.88, Total Time: 3770.52, Learning Rate: 1.000e-03
# It: 5400, Loss: 7.911e+03, Y0: 12.330, Time: 69.87, Total Time: 3840.39, Learning Rate: 1.000e-03
# It: 5500, Loss: 1.213e+04, Y0: 12.360, Time: 70.10, Total Time: 3910.49, Learning Rate: 1.000e-03
# It: 5600, Loss: 7.111e+03, Y0: 12.439, Time: 70.62, Total Time: 3981.11, Learning Rate: 1.000e-03
# It: 5700, Loss: 1.433e+04, Y0: 12.600, Time: 71.20, Total Time: 4052.31, Learning Rate: 1.000e-03
# It: 5800, Loss: 1.017e+04, Y0: 12.689, Time: 74.13, Total Time: 4126.44, Learning Rate: 1.000e-03
# It: 5900, Loss: 8.582e+03, Y0: 12.869, Time: 70.56, Total Time: 4197.01, Learning Rate: 1.000e-03
# It: 6000, Loss: 1.245e+04, Y0: 12.915, Time: 70.32, Total Time: 4267.33, Learning Rate: 1.000e-03
# It: 6100, Loss: 1.392e+07, Y0: 2.823, Time: 70.04, Total Time: 4337.37, Learning Rate: 1.000e-03
# It: 6200, Loss: 1.342e+07, Y0: 1.733, Time: 70.17, Total Time: 4407.54, Learning Rate: 1.000e-03
# It: 6300, Loss: 6.068e+06, Y0: 3.603, Time: 69.26, Total Time: 4476.80, Learning Rate: 1.000e-03
# It: 6400, Loss: 1.540e+06, Y0: 4.008, Time: 69.59, Total Time: 4546.39, Learning Rate: 1.000e-03
# It: 6500, Loss: 1.518e+05, Y0: 3.710, Time: 69.72, Total Time: 4616.11, Learning Rate: 1.000e-03
# It: 6600, Loss: 7.029e+04, Y0: 3.935, Time: 69.64, Total Time: 4685.75, Learning Rate: 1.000e-03
# It: 6700, Loss: 7.123e+04, Y0: 4.303, Time: 73.45, Total Time: 4759.20, Learning Rate: 1.000e-03
# It: 6800, Loss: 5.878e+04, Y0: 4.555, Time: 73.88, Total Time: 4833.08, Learning Rate: 1.000e-03
# It: 6900, Loss: 3.100e+04, Y0: 4.646, Time: 70.55, Total Time: 4903.62, Learning Rate: 1.000e-03
# It: 7000, Loss: 3.887e+04, Y0: 4.843, Time: 71.61, Total Time: 4975.23, Learning Rate: 1.000e-03
# It: 7100, Loss: 3.337e+04, Y0: 4.879, Time: 72.05, Total Time: 5047.28, Learning Rate: 1.000e-03
# It: 7200, Loss: 3.388e+04, Y0: 5.086, Time: 72.03, Total Time: 5119.32, Learning Rate: 1.000e-03
# It: 7300, Loss: 4.950e+04, Y0: 5.167, Time: 72.09, Total Time: 5191.40, Learning Rate: 1.000e-03
# It: 7400, Loss: 2.573e+04, Y0: 5.244, Time: 71.97, Total Time: 5263.38, Learning Rate: 1.000e-03
# It: 7500, Loss: 3.884e+04, Y0: 5.337, Time: 71.78, Total Time: 5335.16, Learning Rate: 1.000e-03
# It: 7600, Loss: 2.578e+04, Y0: 5.462, Time: 71.65, Total Time: 5406.81, Learning Rate: 1.000e-03
# It: 7700, Loss: 4.624e+04, Y0: 5.612, Time: 72.54, Total Time: 5479.35, Learning Rate: 1.000e-03
# It: 7800, Loss: 3.909e+04, Y0: 5.648, Time: 73.28, Total Time: 5552.63, Learning Rate: 1.000e-03
# It: 7900, Loss: 3.075e+04, Y0: 5.772, Time: 72.39, Total Time: 5625.02, Learning Rate: 1.000e-03
# It: 8000, Loss: 2.906e+04, Y0: 5.959, Time: 72.56, Total Time: 5697.58, Learning Rate: 1.000e-03
# It: 8100, Loss: 2.941e+04, Y0: 6.057, Time: 72.26, Total Time: 5769.84, Learning Rate: 1.000e-03
# It: 8200, Loss: 2.628e+04, Y0: 6.152, Time: 73.13, Total Time: 5842.97, Learning Rate: 1.000e-03
# It: 8300, Loss: 2.824e+04, Y0: 6.275, Time: 73.40, Total Time: 5916.36, Learning Rate: 1.000e-03
# It: 8400, Loss: 4.076e+04, Y0: 6.266, Time: 72.18, Total Time: 5988.55, Learning Rate: 1.000e-03
# It: 8500, Loss: 2.782e+04, Y0: 6.422, Time: 72.66, Total Time: 6061.21, Learning Rate: 1.000e-03
# It: 8600, Loss: 2.878e+04, Y0: 6.636, Time: 72.55, Total Time: 6133.76, Learning Rate: 1.000e-03
# It: 8700, Loss: 3.576e+04, Y0: 6.648, Time: 72.49, Total Time: 6206.25, Learning Rate: 1.000e-03
# It: 8800, Loss: 2.793e+04, Y0: 6.736, Time: 72.08, Total Time: 6278.32, Learning Rate: 1.000e-03
# It: 8900, Loss: 2.848e+04, Y0: 6.909, Time: 72.26, Total Time: 6350.58, Learning Rate: 1.000e-03
# It: 9000, Loss: 3.270e+04, Y0: 6.953, Time: 72.58, Total Time: 6423.16, Learning Rate: 1.000e-03
# It: 9100, Loss: 3.436e+04, Y0: 7.191, Time: 72.28, Total Time: 6495.44, Learning Rate: 1.000e-03
# It: 9200, Loss: 2.270e+04, Y0: 7.238, Time: 71.83, Total Time: 6567.27, Learning Rate: 1.000e-03
# It: 9300, Loss: 2.569e+04, Y0: 7.435, Time: 71.68, Total Time: 6638.95, Learning Rate: 1.000e-03
# It: 9400, Loss: 2.151e+04, Y0: 7.565, Time: 72.31, Total Time: 6711.26, Learning Rate: 1.000e-03
# It: 9500, Loss: 3.502e+04, Y0: 7.597, Time: 71.34, Total Time: 6782.61, Learning Rate: 1.000e-03
# It: 9600, Loss: 1.895e+07, Y0: 8.910, Time: 70.86, Total Time: 6853.47, Learning Rate: 1.000e-03
# It: 9700, Loss: 7.015e+06, Y0: 9.615, Time: 71.32, Total Time: 6924.79, Learning Rate: 1.000e-03
# It: 9800, Loss: 6.225e+06, Y0: 9.099, Time: 71.01, Total Time: 6995.81, Learning Rate: 1.000e-03
# It: 9900, Loss: 4.683e+06, Y0: 8.390, Time: 73.66, Total Time: 7069.47, Learning Rate: 1.000e-03
# It: 10000, Loss: 4.925e+06, Y0: 8.975, Time: 72.02, Total Time: 7141.49, Learning Rate: 1.000e-03
# It: 10100, Loss: 1.023e+06, Y0: 8.200, Time: 72.49, Total Time: 7213.98, Learning Rate: 1.000e-03
# It: 10200, Loss: 1.938e+06, Y0: 8.883, Time: 72.85, Total Time: 7286.83, Learning Rate: 1.000e-03
# It: 10300, Loss: 1.025e+06, Y0: 8.985, Time: 72.50, Total Time: 7359.33, Learning Rate: 1.000e-03
# It: 10400, Loss: 1.452e+06, Y0: 9.230, Time: 71.95, Total Time: 7431.28, Learning Rate: 1.000e-03
# It: 10500, Loss: 5.323e+05, Y0: 9.122, Time: 72.09, Total Time: 7503.37, Learning Rate: 1.000e-03
# It: 10600, Loss: 3.898e+05, Y0: 9.197, Time: 70.83, Total Time: 7574.20, Learning Rate: 1.000e-03
# It: 10700, Loss: 8.031e+04, Y0: 9.343, Time: 71.47, Total Time: 7645.67, Learning Rate: 1.000e-03
# It: 10800, Loss: 3.814e+04, Y0: 9.384, Time: 71.27, Total Time: 7716.94, Learning Rate: 1.000e-03
# It: 10900, Loss: 3.264e+04, Y0: 9.449, Time: 71.06, Total Time: 7788.00, Learning Rate: 1.000e-03
# It: 11000, Loss: 3.336e+04, Y0: 9.529, Time: 70.43, Total Time: 7858.43, Learning Rate: 1.000e-03
# It: 11100, Loss: 2.792e+04, Y0: 9.602, Time: 71.16, Total Time: 7929.59, Learning Rate: 1.000e-03
# It: 11200, Loss: 2.772e+04, Y0: 9.676, Time: 71.51, Total Time: 8001.10, Learning Rate: 1.000e-03
# It: 11300, Loss: 2.393e+04, Y0: 9.766, Time: 71.82, Total Time: 8072.92, Learning Rate: 1.000e-03
# It: 11400, Loss: 1.851e+04, Y0: 9.843, Time: 71.02, Total Time: 8143.95, Learning Rate: 1.000e-03
# It: 11500, Loss: 2.176e+04, Y0: 9.920, Time: 71.06, Total Time: 8215.01, Learning Rate: 1.000e-03
# It: 11600, Loss: 2.803e+04, Y0: 10.014, Time: 70.94, Total Time: 8285.95, Learning Rate: 1.000e-03
# It: 11700, Loss: 2.704e+04, Y0: 10.091, Time: 70.95, Total Time: 8356.90, Learning Rate: 1.000e-03
# It: 11800, Loss: 2.224e+04, Y0: 10.173, Time: 70.94, Total Time: 8427.84, Learning Rate: 1.000e-03
# It: 11900, Loss: 2.164e+04, Y0: 10.253, Time: 70.93, Total Time: 8498.77, Learning Rate: 1.000e-03
# It: 12000, Loss: 2.111e+04, Y0: 10.351, Time: 70.78, Total Time: 8569.55, Learning Rate: 1.000e-03
# It: 12100, Loss: 1.971e+04, Y0: 10.413, Time: 70.98, Total Time: 8640.53, Learning Rate: 1.000e-03
# It: 12200, Loss: 1.873e+04, Y0: 10.493, Time: 71.02, Total Time: 8711.55, Learning Rate: 1.000e-03
# It: 12300, Loss: 1.948e+04, Y0: 10.570, Time: 70.63, Total Time: 8782.18, Learning Rate: 1.000e-03
# It: 12400, Loss: 1.600e+04, Y0: 10.649, Time: 70.77, Total Time: 8852.95, Learning Rate: 1.000e-03
# It: 12500, Loss: 2.371e+04, Y0: 10.739, Time: 70.59, Total Time: 8923.53, Learning Rate: 1.000e-03
# It: 12600, Loss: 2.069e+04, Y0: 10.821, Time: 70.41, Total Time: 8993.95, Learning Rate: 1.000e-03
# It: 12700, Loss: 1.881e+04, Y0: 10.910, Time: 70.75, Total Time: 9064.70, Learning Rate: 1.000e-03
# It: 12800, Loss: 1.868e+04, Y0: 10.986, Time: 70.69, Total Time: 9135.39, Learning Rate: 1.000e-03
# It: 12900, Loss: 2.561e+04, Y0: 11.074, Time: 70.94, Total Time: 9206.33, Learning Rate: 1.000e-03
# It: 13000, Loss: 2.478e+04, Y0: 11.149, Time: 70.79, Total Time: 9277.12, Learning Rate: 1.000e-03
# It: 13100, Loss: 1.687e+04, Y0: 11.201, Time: 70.94, Total Time: 9348.06, Learning Rate: 1.000e-03
# It: 13200, Loss: 1.620e+04, Y0: 11.285, Time: 71.24, Total Time: 9419.30, Learning Rate: 1.000e-03
# It: 13300, Loss: 2.059e+04, Y0: 11.371, Time: 71.54, Total Time: 9490.84, Learning Rate: 1.000e-03
# It: 13400, Loss: 9.697e+05, Y0: 11.652, Time: 71.18, Total Time: 9562.02, Learning Rate: 1.000e-03
# It: 13500, Loss: 4.451e+06, Y0: 10.624, Time: 71.10, Total Time: 9633.12, Learning Rate: 1.000e-03
# It: 13600, Loss: 4.419e+06, Y0: 11.841, Time: 70.09, Total Time: 9703.21, Learning Rate: 1.000e-03
# It: 13700, Loss: 3.777e+06, Y0: 11.696, Time: 70.04, Total Time: 9773.25, Learning Rate: 1.000e-03
# It: 13800, Loss: 8.914e+05, Y0: 11.663, Time: 69.87, Total Time: 9843.12, Learning Rate: 1.000e-03
# It: 13900, Loss: 5.595e+05, Y0: 11.145, Time: 69.77, Total Time: 9912.89, Learning Rate: 1.000e-03
# It: 14000, Loss: 2.726e+05, Y0: 11.481, Time: 69.67, Total Time: 9982.56, Learning Rate: 1.000e-03
# It: 14100, Loss: 7.243e+05, Y0: 11.553, Time: 69.37, Total Time: 10051.93, Learning Rate: 1.000e-03
# It: 14200, Loss: 3.931e+05, Y0: 11.689, Time: 69.72, Total Time: 10121.65, Learning Rate: 1.000e-03
# It: 14300, Loss: 3.383e+05, Y0: 11.793, Time: 70.04, Total Time: 10191.69, Learning Rate: 1.000e-03
# It: 14400, Loss: 3.332e+05, Y0: 12.017, Time: 69.86, Total Time: 10261.55, Learning Rate: 1.000e-03
# It: 14500, Loss: 2.652e+05, Y0: 12.118, Time: 69.86, Total Time: 10331.41, Learning Rate: 1.000e-03
# It: 14600, Loss: 1.787e+05, Y0: 12.263, Time: 69.65, Total Time: 10401.06, Learning Rate: 1.000e-03
# It: 14700, Loss: 1.680e+05, Y0: 12.370, Time: 69.48, Total Time: 10470.54, Learning Rate: 1.000e-03
# It: 14800, Loss: 2.035e+05, Y0: 12.451, Time: 69.83, Total Time: 10540.37, Learning Rate: 1.000e-03
# It: 14900, Loss: 1.247e+05, Y0: 12.546, Time: 70.28, Total Time: 10610.66, Learning Rate: 1.000e-03
# It: 15000, Loss: 9.356e+04, Y0: 12.653, Time: 69.94, Total Time: 10680.60, Learning Rate: 1.000e-03
# It: 15100, Loss: 1.483e+05, Y0: 12.714, Time: 71.50, Total Time: 10752.10, Learning Rate: 1.000e-03
# It: 15200, Loss: 1.149e+05, Y0: 12.796, Time: 71.64, Total Time: 10823.74, Learning Rate: 1.000e-03
# It: 15300, Loss: 1.601e+05, Y0: 12.821, Time: 71.03, Total Time: 10894.78, Learning Rate: 1.000e-03
# It: 15400, Loss: 9.093e+04, Y0: 12.830, Time: 70.56, Total Time: 10965.34, Learning Rate: 1.000e-03
# It: 15500, Loss: 6.581e+04, Y0: 12.896, Time: 70.22, Total Time: 11035.56, Learning Rate: 1.000e-03
# It: 15600, Loss: 6.437e+04, Y0: 12.952, Time: 70.35, Total Time: 11105.90, Learning Rate: 1.000e-03
# It: 15700, Loss: 6.997e+04, Y0: 13.007, Time: 71.52, Total Time: 11177.43, Learning Rate: 1.000e-03
# It: 15800, Loss: 5.794e+04, Y0: 13.071, Time: 71.59, Total Time: 11249.02, Learning Rate: 1.000e-03
# It: 15900, Loss: 5.900e+04, Y0: 13.166, Time: 70.52, Total Time: 11319.53, Learning Rate: 1.000e-03
# It: 16000, Loss: 5.320e+04, Y0: 13.213, Time: 70.32, Total Time: 11389.85, Learning Rate: 1.000e-03
# It: 16100, Loss: 3.728e+04, Y0: 13.280, Time: 70.28, Total Time: 11460.13, Learning Rate: 1.000e-03
# It: 16200, Loss: 5.248e+04, Y0: 13.347, Time: 70.19, Total Time: 11530.32, Learning Rate: 1.000e-03
# It: 16300, Loss: 6.060e+04, Y0: 13.386, Time: 70.04, Total Time: 11600.37, Learning Rate: 1.000e-03
# It: 16400, Loss: 6.174e+04, Y0: 13.433, Time: 70.33, Total Time: 11670.69, Learning Rate: 1.000e-03
# It: 16500, Loss: 6.124e+04, Y0: 13.512, Time: 70.74, Total Time: 11741.43, Learning Rate: 1.000e-03
# It: 16600, Loss: 3.456e+04, Y0: 13.561, Time: 71.63, Total Time: 11813.06, Learning Rate: 1.000e-03
# It: 16700, Loss: 3.249e+04, Y0: 13.639, Time: 71.35, Total Time: 11884.42, Learning Rate: 1.000e-03
# It: 16800, Loss: 3.517e+04, Y0: 13.691, Time: 70.65, Total Time: 11955.07, Learning Rate: 1.000e-03
# It: 16900, Loss: 2.590e+04, Y0: 13.733, Time: 70.48, Total Time: 12025.55, Learning Rate: 1.000e-03
# It: 17000, Loss: 3.945e+04, Y0: 13.801, Time: 69.82, Total Time: 12095.37, Learning Rate: 1.000e-03
# It: 17100, Loss: 3.183e+04, Y0: 13.845, Time: 69.74, Total Time: 12165.10, Learning Rate: 1.000e-03
# It: 17200, Loss: 2.776e+04, Y0: 13.889, Time: 70.11, Total Time: 12235.21, Learning Rate: 1.000e-03
# It: 17300, Loss: 2.380e+04, Y0: 13.943, Time: 71.61, Total Time: 12306.83, Learning Rate: 1.000e-03
# It: 17400, Loss: 2.045e+04, Y0: 14.002, Time: 71.25, Total Time: 12378.08, Learning Rate: 1.000e-03
# It: 17500, Loss: 2.156e+04, Y0: 14.047, Time: 70.67, Total Time: 12448.75, Learning Rate: 1.000e-03
# It: 17600, Loss: 2.089e+04, Y0: 14.084, Time: 69.93, Total Time: 12518.68, Learning Rate: 1.000e-03
# It: 17700, Loss: 1.850e+04, Y0: 14.137, Time: 70.52, Total Time: 12589.20, Learning Rate: 1.000e-03
# It: 17800, Loss: 1.810e+04, Y0: 14.184, Time: 70.81, Total Time: 12660.01, Learning Rate: 1.000e-03
# It: 17900, Loss: 2.902e+04, Y0: 14.220, Time: 71.77, Total Time: 12731.78, Learning Rate: 1.000e-03
# It: 18000, Loss: 1.701e+04, Y0: 14.259, Time: 73.76, Total Time: 12805.55, Learning Rate: 1.000e-03
# It: 18100, Loss: 1.476e+04, Y0: 14.300, Time: 74.49, Total Time: 12880.04, Learning Rate: 1.000e-03
# It: 18200, Loss: 1.708e+04, Y0: 14.336, Time: 71.63, Total Time: 12951.67, Learning Rate: 1.000e-03
# It: 18300, Loss: 1.617e+04, Y0: 14.364, Time: 71.64, Total Time: 13023.31, Learning Rate: 1.000e-03
# It: 18400, Loss: 1.404e+04, Y0: 14.390, Time: 71.65, Total Time: 13094.97, Learning Rate: 1.000e-03
# It: 18500, Loss: 1.041e+04, Y0: 14.417, Time: 72.20, Total Time: 13167.16, Learning Rate: 1.000e-03
# It: 18600, Loss: 1.573e+04, Y0: 14.458, Time: 72.37, Total Time: 13239.53, Learning Rate: 1.000e-03
# It: 18700, Loss: 1.196e+04, Y0: 14.476, Time: 72.13, Total Time: 13311.66, Learning Rate: 1.000e-03
# It: 18800, Loss: 1.208e+04, Y0: 14.496, Time: 71.08, Total Time: 13382.74, Learning Rate: 1.000e-03
# It: 18900, Loss: 8.641e+03, Y0: 14.513, Time: 71.99, Total Time: 13454.73, Learning Rate: 1.000e-03
# It: 19000, Loss: 1.108e+04, Y0: 14.523, Time: 73.07, Total Time: 13527.81, Learning Rate: 1.000e-03
# It: 19100, Loss: 1.018e+04, Y0: 14.541, Time: 70.60, Total Time: 13598.41, Learning Rate: 1.000e-03
# It: 19200, Loss: 1.160e+04, Y0: 14.555, Time: 70.57, Total Time: 13668.97, Learning Rate: 1.000e-03
# It: 19300, Loss: 8.958e+03, Y0: 14.570, Time: 70.48, Total Time: 13739.45, Learning Rate: 1.000e-03
# It: 19400, Loss: 1.166e+04, Y0: 14.588, Time: 70.93, Total Time: 13810.38, Learning Rate: 1.000e-03
# It: 19500, Loss: 7.860e+03, Y0: 14.594, Time: 71.10, Total Time: 13881.49, Learning Rate: 1.000e-03
# It: 19600, Loss: 7.212e+03, Y0: 14.610, Time: 71.05, Total Time: 13952.53, Learning Rate: 1.000e-03
# It: 19700, Loss: 9.083e+03, Y0: 14.614, Time: 71.03, Total Time: 14023.56, Learning Rate: 1.000e-03
# It: 19800, Loss: 9.921e+03, Y0: 14.612, Time: 71.07, Total Time: 14094.63, Learning Rate: 1.000e-03
# It: 19900, Loss: 7.134e+03, Y0: 14.613, Time: 72.33, Total Time: 14166.96, Learning Rate: 1.000e-03

# %%
np.random.seed(42)
t_test, B_test = model.fetch_minibatch()
W_test, Var_test = model.variance()

X_pred, Y_pred, delta_pred = model.predict(Xi, t_test, W_test, B_test, Var_test)
#Y0_test = 4.9550

# %%
D = 20
plt.figure()
plt.plot(graph[0], graph[1])
plt.xlabel('Iterations')
plt.ylabel('Value')
plt.yscale("log")
plt.title('Evolution of the training loss')
plt.savefig(str(D) + 'train-loss' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(Y0_iter[0], Y0_iter[1], label='Learned $Y_0$')
#plt.axhline(Y0_test, color='r', label='Exact $Y_0$')
plt.xlabel('Iterations')
plt.ylabel('Y Initial Value')
#plt.yscale("log")
plt.title('Evolution of the Y Initial')
plt.savefig(str(D) + ' Initial' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(delta_iter[0], delta_iter[1], label='Learned $Delta_T$')
plt.xlabel('Iterations')
plt.ylabel('Delta Value')
#plt.yscale("log")
plt.title('Evolution of the Delta')
plt.savefig(str(D) + 'Delta' + 'RoughBergomiModel')

# %%
tf.experimental.numpy.experimental_enable_numpy_behavior()

# %%
samples = 5
plt.figure()
plt.plot(t_test[0:1, :, 0].T, Y_pred[0:1, :, 0].T, 'b', label='Learned $u(t,X_t)$')

plt.plot(t_test[1:samples, :, 0].T, Y_pred[1:samples, :, 0].T, 'b')

plt.xlabel('$t$')
plt.ylabel('$Y_t = u(t,X_t)$')
plt.title(str(D) + '-dimensional RoughBergomiModel')
plt.legend()
plt.savefig(str(D) +'-dimensional RoughBergomiModel' + 'traces')

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (0.9.0)

# %%
#. Monte Carlo Simulation 
T_mc = 1.0  # terminal time
M_mc = 10000  # number of trajectories
N_mc = 50  # number of time snapshots
D_mc = 20  # number of dimensions
H_mc = 0.07  # Hurst exponent (0,1)
eta_mc = 1.9  # parameter for control volatility
pho_mc = -0.9  # correlation betwen two independent Wiener process
r_mc = 0.05  # interest rate

layers_mc = [D_mc+1] + 4 * [256] + [1] + [D_mc]

Xi_mc = np.array([np.log(100.0), np.log(50.0)] * int(D_mc/2) )[None, :]
model_mc = RoughBergomiModel(Xi_mc, T_mc, M_mc, N_mc, D_mc, H_mc, eta_mc, pho_mc, r_mc, layers_mc)

np.random.seed(42)
t_mc_test, B_mc_test = model_mc.fetch_minibatch()
W_mc_test, Var_mc_test = model_mc.variance()

def MC_simulation(t, W, B, Var, Xi):

    X_list = []

    t0 = t[:, 0, :]
    W0 = W[:, 0, :]
    B0 = B[:, 0, :]
    Var0 = Var[:, 0, :]

    X0 = tf.tile(Xi, [M_mc, 1])  # M x D
    X_list.append(X0)

    for n in range(0, N_mc):
        t1 = t[:, n + 1, :]
        W1 = W[:, n + 1, :]
        B1 = B[:, n + 1, :]
        Var1 = Var[:, n + 1, :]

        BM = pho_mc * (W1 - W0) + np.sqrt(1 - np.square(pho_mc)) * (B1 - B0)
        X1 = X0 - Var0 * 0.5 * (t1 - t0)+ np.sqrt(Var0) * BM

        t0 = t1
        W0 = W1
        B0 = B1
        Var0 = Var1
        X0 = X1
        
        X_list.append(X0)
       
    X = tf.stack(X_list, axis=1)
    return X

X_mc = MC_simulation(t_mc_test, W_mc_test, B_mc_test, Var_mc_test, Xi_mc)
K_mc = np.tile(np.array([90.0], dtype=np.float32)[None, :], [M_mc, 1])
S_T_mc = np.mean(np.exp(X_mc[:, -1, :] + r_mc * T_mc), axis=1, keepdims = True)
put_option_mc = np.mean(np.maximum(K_mc - S_T_mc, 0.0), axis=0) * np.exp(-r_mc * T_mc)

# %%
Y_pred_mean = np.mean(Y_pred, axis=0)
Y_pred_std = np.std(Y_pred, axis=0)
error = Y_pred_mean[0, 0] - put_option_mc
#print('Y0_mean is: {}'.format(Y_pred_mean[0, 0]))
#print('Y0_exact is: {}'.format(Y0_test))
#print('Y0_std is: {}'.format(Y_pred_std[0, 0]))
#print('Relative Error is: {}'.format(error))

# %%
from tabulate import tabulate
table = {'reference value': put_option_mc, 'Y0_mean': Y_pred_mean[0, :].tolist(), 'Y0_std': Y_pred_std[0, :].tolist(), 'relative error': error}
print(tabulate(table, headers='keys', tablefmt='github'))
# Out:
# |   reference value |   Y0_mean |      Y0_std |   relative error |
# |-------------------|-----------|-------------|------------------|
# |           13.9343 |   14.6078 | 1.33514e-05 |         0.673438 |
