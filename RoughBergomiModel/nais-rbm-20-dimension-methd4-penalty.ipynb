# %%
# basic imports
import os, random
import numpy as np
import datetime as dt
import time
from scipy.fftpack import fft, ifft
from abc import ABC, abstractmethod
import matplotlib.pyplot as plt

# warnings
import warnings

warnings.filterwarnings('ignore')

# tensorflow
import tensorflow as tf

tf.keras.backend.clear_session()

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam, AdamW, RMSprop
from tensorflow.keras.layers import Layer, Add

# %%
print(f" TensorFlow version is {tf.__version__}")
#print(f"Keras version is {tf.keras.__version__}")
print(tf.config.list_physical_devices())
# Out:
#  TensorFlow version is 2.15.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:TPU_SYSTEM:0', device_type='TPU_SYSTEM'), PhysicalDevice(name='/physical_device:TPU:0', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:1', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:2', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:3', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:4', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:5', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:6', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:7', device_type='TPU')]

# %%
class Linear(Layer):
    """Define Linear layers"""

    def __init__(self, in_features, out_features):
        super(Linear, self).__init__()

        self.in_dims = in_features
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'
        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        return tf.matmul(inputs, self.w) + self.b


class StableLinear(Layer):
    """Define Stable Linear layers"""

    def __init__(self, in_features, out_features):
        super(StableLinear, self).__init__()

        self.epsilon = 0.01
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'

        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        w = self.weight_constraint(self.w)
        return tf.matmul(inputs, w) + self.b

    #@tf.function
    def weight_constraint(self, weight):
        delta = 1 - 2 * self.epsilon
        RtR = tf.matmul(tf.transpose(weight), weight)
        norm = tf.norm(RtR)

        #if norm > delta: RtR = delta ** (1 / 2) * RtR / (norm ** (1 / 2))
        RtR_new = tf.sqrt(delta) * RtR / tf.sqrt(norm)
        RtR_update = tf.minimum(RtR_new, RtR)
        #def f2(): return RtR
        #RtR = tf.cond(tf.greater(norm, delta), f1, f2)
        A = RtR_update + tf.eye(RtR.shape[0]) * self.epsilon
        return -A


class NaisNet(Model):
    """ Building NAIS_Net network using keras """

    def __init__(self, layers):
        super(NaisNet, self).__init__()

        self.layer1 = Linear(layers[0], layers[1])

        self.layer2 = StableLinear(layers[1], layers[2])
        self.layer2_input = Linear(layers[0], layers[2])

        self.layer3 = StableLinear(layers[2], layers[3])
        self.layer3_input = Linear(layers[0], layers[3])

        self.layer4 = StableLinear(layers[3], layers[4])
        self.layer4_input = Linear(layers[0], layers[4])

        self.layer5 = Linear(layers[4], layers[5])
        self.layer6 = Linear(layers[4], layers[6])

    # Building block for the NAIS-Net
    #@tf.function
    def call(self, x):
        """Process stages in the block"""

        u = x

        output = self.layer1(u)  # layer 1
        output = tf.sin(output)

        X1 = output
        output = self.layer2(output)  # layer 2
        output = Add()([self.layer2_input(u), output])
        output = tf.sin(output)
        output = Add()([X1, output])

        X2 = output
        output = self.layer3(output)  # layer 3
        output = Add()([self.layer3_input(u), output])
        output = tf.sin(output)
        output = Add()([X2, output])

        X3 = output
        output = self.layer4(output)  # layer 4
        output = Add()([self.layer4_input(u), output])
        output = tf.sin(output)
        output = Add()([X3, output])

        output1 = self.layer5(output)  # layer 5
        output2 = self.layer6(output)
        return output1, output2


class FBSNN(ABC):
    """Forward-Backward SDEs using NAIS-Net """

    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):    # , layer_phi

        self.Xi = Xi  # initial point

        self.T = T  # terminal time
        self.M = M  # number of trajectories
        self.N = N  # number of time snapshots
        self.D = D  # number of dimensions
        self.H = H  # Hurst exponent (0,1)
        self.eta = eta  # parameter for control volatility
        self.pho = tf.cast(pho, dtype=tf.float32) # correlation betwen two independent Wiener process
        self.epsilon_t = 0.09 # forward variance curve epsilon(t) - constant
        self.r = tf.cast(r, dtype=tf.float32)  # interest rate

        # Initialize NN
        #self.phi_input_shape = tf.cast(layers[0], dtype=tf.int32)
        #self.phi_output_shape= tf.cast(self.D, dtype=tf.int32)
        #self.phi_weight, self.phi_bias = self.init_wb([self.phi_input_shape, self.phi_output_shape])
        self.model = NaisNet(layers)
        #self.model_phi = NaisNet(layer_phi)

        # Record the loss
        self.training_loss = []
        self.iteration = []
        self.Y0_iter = []
        self.Du0_iter = []

    #def init_wb(self,size):
    #    xavier_stddev = tf.cast(tf.sqrt(tf.divide(2, tf.add(size[0], size[1]))),dtype=tf.float32)
    #    weight = tf.Variable(tf.random.truncated_normal([self.phi_input_shape, self.phi_output_shape],
    #                                           stddev=xavier_stddev), trainable=True, dtype=tf.float32)
        #weitht = self.xavier_init([self.phi_input_shape, self.phi_output_shape])
    #    bias = tf.Variable(tf.zeros([1, self.phi_output_shape]), dtype=tf.float32)
    #    return  weight, bias

    #def phi_tf(self,inputs):
    #    return tf.matmul(inputs, self.phi_weight) + self.phi_bias

    @tf.function
    def net_u(self, t, X):  # M x 1, M x D

        u, phi = self.model(tf.concat([t, X], 1))  # M x [1+D]
        #u = tf.expand_dims(y[:, 0], axis=-1)  # M x 1
        #phi = self.model_phi(tf.concat([t, X], 1)) # M x D
        #phi = self.phi_tf(tf.concat([t,X], 1))
        #phi = y[:, 1:] # M x D
        Du = tf.gradients(u, X)[0]  # M x D

        return u, phi, Du

    @tf.function
    def Dg_tf(self, X):  # M x D
        return tf.gradients(self.g_tf(X), X)[0]  # M x D

    #@tf.function
    def loss_function(self, t, W, B, Var, Xi):

        loss = 0
        X_list = []
        Y_list = []
        Tilde_Z_list = []
        Z_list = []
        Du_list = []


        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        B0 = B[:, 0, :]
        Var0 = Var[:, 0, :]

        X0 = tf.tile(Xi, [self.M, 1])  # M x D
        Y0, phi0, du0 = self.net_u(t0, X0)  # M x 1, M x D, M x D
        Z0 = self.Z_tf(Var0,du0) # M x D
        Tilde_Z0 = self.Z_tilde_tf(Var0, phi0, du0) # M x D

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)
        Tilde_Z_list.append(Tilde_Z0)
        Du_list.append(du0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]
            B1 = B[:, n + 1, :]
            Var1 = Var[:, n + 1, :]
            BM = self.pho * (W1 - W0) + tf.sqrt(1 - self.pho**2) * (B1 - B0)
            X1 = X0 +self.mu_tf(t0, X0, Y0, du0) * (t1 - t0)  - Var0 * 0.5 * (t1 - t0) + tf.sqrt(Var0) * BM

            Y1_tilde = Y0 + self.F_tf(t0, X0, Y0, Z0, Tilde_Z0) * (t1 - t0) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Z0, tf.expand_dims(B1 - B0, -1))), axis=1,
                keepdims=True) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Tilde_Z0, tf.expand_dims(W1 - W0, -1))), axis=1, keepdims=True)

            Y1, phi1, du1 = self.net_u(t1, X1)
            Z1 = self.Z_tf(Var1,du1) # M x D
            Tilde_Z1 = self.Z_tilde_tf(Var1, phi1, du1) # M x D


            loss += tf.reduce_sum(tf.pow(Y1 - Y1_tilde, 2))

            t0 = t1
            W0 = W1
            B0 = B1
            Var0 = Var1
            du0 = du1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            Tilde_Z0 = Tilde_Z1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)
            Tilde_Z_list.append(Tilde_Z0)
            Du_list.append(du0)

        # 0.02 is the penalty parameters for the terminal conditions
        loss += 0.02 * tf.reduce_sum(tf.pow(Y1 - self.g_tf(X1), 2))
        loss += 0.02 * tf.reduce_sum(tf.pow(du1 - self.Dg_tf(X1), 2))
        loss += 0.02 * tf.reduce_sum(tf.pow(Tilde_Z1 - self.Z_tilde_tf(Var1, phi1, self.Dg_tf(X1)), 2))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)
        Tilde_Z = tf.stack(Tilde_Z_list, axis=1)
        Du_t = tf.stack(Du_list, axis=1)
        #Y0 = tf.reduce_mean(Y, axis=0)

        return loss, X, Y, Y[0, 0, 0], Du_t

    def Z_tf(self, Var, Du):  # M x D
        return tf.sqrt((1 - self.pho**2) * Var) * Du

    def Z_tilde_tf(self, Var, phi, Du): # M x D
        return self.pho * tf.sqrt(Var) * Du + phi

    # Volterra process Using hybrid scheme
    def volterra(self):
        T = self.T
        M = self.M
        N = self.N
        D = self.D
        delta_t = T / N
        alpha = self.H - 0.5

        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D
        Dt[:, 1:, :] = delta_t
        DW[:, 1:, :] = np.sqrt(delta_t) * np.random.normal(size=(M, N, D))

        t_series = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W_process = np.cumsum(DW, axis=1)  # M x (N+1) x D

        sigma = (2*alpha + 1)**0.5
        #kernal function
        def g_kernel(k):
            y = (k**(alpha+1) - (k-1)**(alpha+1)) / (alpha+1)
            b = np.power(y, 1/alpha)
            return np.power((b) * delta_t, alpha)

        #t_series, W_process = self.fetch_minibatch()

        tilde_X = np.zeros((M, N+1, D))
        tilde_X[:, 0 , :]= W_process[:, 0 , :]

        WN_tj_minus_1_1 = np.roll(W_process, shift=-1, axis=1) - W_process

        for m in range(M):
            for d in range(D):
                # first column for toeplitz matrix
                WN_j = WN_tj_minus_1_1[m, :-1, d]
                sigma_col = np.zeros((N))
                sigma_col[0] = np.power(delta_t/2, alpha) * sigma
                #
                for k in range(1, N):
                    g_b_star_k = g_kernel(k+1)
                    sigma_col[k] = sigma * g_b_star_k

                # FFT and dot
                WN_j_fft = fft(WN_j)
                sigma_fft = fft(sigma_col)
                convolved = ifft(WN_j_fft * sigma_fft)

                # capture real value
                tilde_X[m, 1:, d] = np.real(convolved)

        return t_series, W_process, tilde_X

    # Variace process
    def variance(self):

        t, W_s, D_hat_w = self.volterra()# M x (N+1) x D

        var = self.epsilon_t * np.exp(self.eta* D_hat_w -  0.5 * self.eta**2 * np.power(t, 2*self.H))

        return W_s, var

    #@tf.function
    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W = np.cumsum(DW, axis=1)  # M x (N+1) x D

        return t, W

    @tf.function
    def train_step(self, optimizers, t, w, b, var, Xi):
        # Optimizers
        optimizer = optimizers

        with tf.GradientTape() as tape:
            loss_value, X_pred, Y_pred, Y0_pred, Du0_pred = self.loss_function(t, w, b, var, Xi)

        grads = tape.gradient(loss_value, self.model.trainable_weights)
        #optimizer.apply(grads, self.model.trainable_weights)
        optimizer.apply_gradients(zip(grads, self.model.trainable_weights))


        return loss_value, Y0_pred, Du0_pred

    #@tf.function
    def train(self, N_Iter, learning_rate):

        loss_temp = np.array([])
        Y0_pred_temp = np.array([])
        Du0_pred_temp = np.array([])

        # Optimizers
        #self.optimizer = AdamW(learning_rate=learning_rate, weight_decay=0.001)
        self.optimizer = Adam(learning_rate=learning_rate)

        start_time = time.time()
        ini_time = time.time()

        for it in range(N_Iter):

            t_batch, B_batch = self.fetch_minibatch()  # M x (N+1) x 1, M x (N+1) x D
            W_batch, Var_batch = self.variance() # M x (N+1) x D, M x (N+1) x D
            t_batch = tf.convert_to_tensor(t_batch, dtype=tf.float32)
            B_batch = tf.convert_to_tensor(B_batch, dtype=tf.float32)
            W_batch = tf.convert_to_tensor(W_batch, dtype=tf.float32)
            Var_batch = tf.convert_to_tensor(Var_batch, dtype=tf.float32)
            self.Xi = tf.convert_to_tensor(self.Xi, dtype=tf.float32)

            loss_value, Y0_pred, Du0_pred = self.train_step(self.optimizer, t_batch, W_batch, B_batch, Var_batch, self.Xi)

            if it % 100 == 0:
                elapsed = time.time() - start_time
                total_time = time.time() - ini_time
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Total Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_pred, elapsed, total_time, learning_rate))
                start_time = time.time()

            loss_temp = np.append(loss_temp, loss_value.numpy())
            Y0_pred_temp = np.append(Y0_pred_temp, Y0_pred.numpy())

            Du0 = tf.reduce_mean(Du0_pred, axis=0, keepdims=True)
            Du0_pred_temp = np.append(Du0_pred_temp, Du0.numpy()[0, 0])

            if it % 100 == 0:
                self.training_loss.append(loss_temp.mean())
                self.Y0_iter.append(Y0_pred_temp[-100:].mean())
                self.Du0_iter.append(Du0_pred_temp[-100:].mean())
                self.iteration.append(it)

            graph = np.stack((self.iteration, self.training_loss))
            Y0_iter = np.stack((self.iteration, self.Y0_iter))
            Du0_iter = np.stack((self.iteration, self.Du0_iter))

        return graph,Y0_iter, Du0_iter

    def predict(self, Xi_star, t_star, W_star, B_star, Var_star):
        t_star = tf.convert_to_tensor(t_star, dtype=tf.float32)
        W_star = tf.convert_to_tensor(W_star, dtype=tf.float32)
        Xi_star = tf.convert_to_tensor(Xi_star, dtype=tf.float32)
        B_star = tf.convert_to_tensor(B_star, dtype=tf.float32)
        Var_star = tf.convert_to_tensor(Var_star, dtype=tf.float32)

        loss, X_star, Y_star, Y0_pred, delta_star = self.loss_function(t_star, W_star, B_star, Var_star, Xi_star)

        return X_star, Y_star, delta_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        pass  # M x1

    @abstractmethod
    def g_tf(self, X):  # M x D
        pass  # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return tf.zeros([M, D])  # M x D
    ###########################################################################

# %%
class RoughBergomiModel(FBSNN):
    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):
        super().__init__(Xi, T, M, N, D, H, eta, pho, r, layers)

    def g_tf(self, X):  # M x D
        K = tf.tile(np.array([90.0], dtype=np.float32)[None, :], [self.M, 1])
        X = tf.reduce_mean(tf.exp(X + self.r * self.T), axis=1, keepdims = True)
        return tf.maximum(K - X, 0) # M x 1

    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        return super().mu_tf(t, X, Y, Du)  # M x D

    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        return self.r * Y # M x1

    ###########################################################################

# %%
T = 1.0  # terminal time
M = 100  # number of trajectories
N = 50  # number of time snapshots
D = 20  # number of dimensions
H = 0.07  # Hurst exponent (0,1)
eta = 1.9  # parameter for control volatility
pho = -0.9  # correlation betwen two independent Wiener process
r = 0.05  # interest rate

Xi = np.array([np.log(100.0), np.log(50.0)] * int(D / 2))[None, :]

layers = [D+1] + 4 * [256] + [1] + [D]

model = RoughBergomiModel(Xi, T, M, N, D, H, eta, pho, r, layers)
graph, Y0_iter, delta_iter = model.train(2*10**4, 1e-3)
# Out:
# It: 0, Loss: 5.251e+07, Y0: 0.112, Time: 29.12, Total Time: 29.12, Learning Rate: 1.000e-03
# It: 100, Loss: 8.185e+04, Y0: -0.860, Time: 42.96, Total Time: 72.08, Learning Rate: 1.000e-03
# It: 200, Loss: 4.443e+04, Y0: -0.818, Time: 42.69, Total Time: 114.77, Learning Rate: 1.000e-03
# It: 300, Loss: 5.232e+04, Y0: -0.644, Time: 41.12, Total Time: 155.89, Learning Rate: 1.000e-03
# It: 400, Loss: 4.388e+04, Y0: -0.499, Time: 38.47, Total Time: 194.35, Learning Rate: 1.000e-03
# It: 500, Loss: 6.098e+04, Y0: -0.312, Time: 38.28, Total Time: 232.63, Learning Rate: 1.000e-03
# It: 600, Loss: 5.382e+04, Y0: -0.062, Time: 38.08, Total Time: 270.71, Learning Rate: 1.000e-03
# It: 700, Loss: 3.927e+04, Y0: 0.095, Time: 38.28, Total Time: 308.99, Learning Rate: 1.000e-03
# It: 800, Loss: 7.582e+04, Y0: 0.314, Time: 38.03, Total Time: 347.03, Learning Rate: 1.000e-03
# It: 900, Loss: 2.732e+04, Y0: 0.497, Time: 38.45, Total Time: 385.47, Learning Rate: 1.000e-03
# It: 1000, Loss: 3.480e+04, Y0: 0.735, Time: 39.64, Total Time: 425.12, Learning Rate: 1.000e-03
# It: 1100, Loss: 1.530e+04, Y0: 0.949, Time: 40.01, Total Time: 465.12, Learning Rate: 1.000e-03
# It: 1200, Loss: 2.865e+04, Y0: 1.197, Time: 39.57, Total Time: 504.69, Learning Rate: 1.000e-03
# It: 1300, Loss: 2.892e+04, Y0: 1.384, Time: 38.19, Total Time: 542.88, Learning Rate: 1.000e-03
# It: 1400, Loss: 3.399e+04, Y0: 1.650, Time: 38.01, Total Time: 580.89, Learning Rate: 1.000e-03
# It: 1500, Loss: 2.077e+04, Y0: 1.951, Time: 38.10, Total Time: 618.99, Learning Rate: 1.000e-03
# It: 1600, Loss: 1.669e+04, Y0: 2.246, Time: 38.21, Total Time: 657.20, Learning Rate: 1.000e-03
# It: 1700, Loss: 1.621e+04, Y0: 2.549, Time: 38.96, Total Time: 696.17, Learning Rate: 1.000e-03
# It: 1800, Loss: 1.689e+04, Y0: 2.861, Time: 38.17, Total Time: 734.34, Learning Rate: 1.000e-03
# It: 1900, Loss: 2.117e+04, Y0: 3.145, Time: 38.02, Total Time: 772.36, Learning Rate: 1.000e-03
# It: 2000, Loss: 1.957e+04, Y0: 3.437, Time: 38.30, Total Time: 810.66, Learning Rate: 1.000e-03
# It: 2100, Loss: 2.695e+04, Y0: 3.722, Time: 39.28, Total Time: 849.94, Learning Rate: 1.000e-03
# It: 2200, Loss: 1.466e+04, Y0: 4.033, Time: 38.15, Total Time: 888.09, Learning Rate: 1.000e-03
# It: 2300, Loss: 1.503e+04, Y0: 4.367, Time: 38.23, Total Time: 926.32, Learning Rate: 1.000e-03
# It: 2400, Loss: 2.919e+04, Y0: 4.651, Time: 38.04, Total Time: 964.36, Learning Rate: 1.000e-03
# It: 2500, Loss: 1.652e+04, Y0: 4.948, Time: 38.80, Total Time: 1003.16, Learning Rate: 1.000e-03
# It: 2600, Loss: 7.415e+03, Y0: 5.243, Time: 38.33, Total Time: 1041.49, Learning Rate: 1.000e-03
# It: 2700, Loss: 2.186e+04, Y0: 5.562, Time: 38.33, Total Time: 1079.82, Learning Rate: 1.000e-03
# It: 2800, Loss: 2.646e+04, Y0: 5.828, Time: 37.99, Total Time: 1117.81, Learning Rate: 1.000e-03
# It: 2900, Loss: 8.486e+03, Y0: 6.179, Time: 38.33, Total Time: 1156.14, Learning Rate: 1.000e-03
# It: 3000, Loss: 1.432e+04, Y0: 6.516, Time: 39.41, Total Time: 1195.55, Learning Rate: 1.000e-03
# It: 3100, Loss: 9.967e+03, Y0: 6.824, Time: 39.32, Total Time: 1234.88, Learning Rate: 1.000e-03
# It: 3200, Loss: 8.426e+03, Y0: 7.149, Time: 39.60, Total Time: 1274.48, Learning Rate: 1.000e-03
# It: 3300, Loss: 1.197e+04, Y0: 7.459, Time: 38.25, Total Time: 1312.73, Learning Rate: 1.000e-03
# It: 3400, Loss: 7.284e+03, Y0: 7.760, Time: 38.24, Total Time: 1350.97, Learning Rate: 1.000e-03
# It: 3500, Loss: 9.979e+03, Y0: 8.085, Time: 38.34, Total Time: 1389.31, Learning Rate: 1.000e-03
# It: 3600, Loss: 7.465e+03, Y0: 8.417, Time: 38.19, Total Time: 1427.50, Learning Rate: 1.000e-03
# It: 3700, Loss: 9.693e+03, Y0: 8.727, Time: 39.33, Total Time: 1466.83, Learning Rate: 1.000e-03
# It: 3800, Loss: 8.001e+03, Y0: 9.048, Time: 39.18, Total Time: 1506.01, Learning Rate: 1.000e-03
# It: 3900, Loss: 7.267e+03, Y0: 9.333, Time: 39.64, Total Time: 1545.66, Learning Rate: 1.000e-03
# It: 4000, Loss: 7.862e+03, Y0: 9.536, Time: 39.37, Total Time: 1585.02, Learning Rate: 1.000e-03
# It: 4100, Loss: 7.647e+03, Y0: 9.778, Time: 39.64, Total Time: 1624.66, Learning Rate: 1.000e-03
# It: 4200, Loss: 1.366e+04, Y0: 10.077, Time: 38.96, Total Time: 1663.62, Learning Rate: 1.000e-03
# It: 4300, Loss: 7.794e+03, Y0: 10.276, Time: 38.12, Total Time: 1701.74, Learning Rate: 1.000e-03
# It: 4400, Loss: 1.039e+04, Y0: 10.466, Time: 38.94, Total Time: 1740.69, Learning Rate: 1.000e-03
# It: 4500, Loss: 6.339e+03, Y0: 10.684, Time: 39.30, Total Time: 1779.99, Learning Rate: 1.000e-03
# It: 4600, Loss: 6.385e+03, Y0: 10.928, Time: 39.78, Total Time: 1819.77, Learning Rate: 1.000e-03
# It: 4700, Loss: 6.519e+03, Y0: 11.081, Time: 38.60, Total Time: 1858.37, Learning Rate: 1.000e-03
# It: 4800, Loss: 6.074e+03, Y0: 11.251, Time: 38.19, Total Time: 1896.56, Learning Rate: 1.000e-03
# It: 4900, Loss: 6.376e+03, Y0: 11.437, Time: 38.21, Total Time: 1934.77, Learning Rate: 1.000e-03
# It: 5000, Loss: 7.435e+03, Y0: 11.569, Time: 38.10, Total Time: 1972.87, Learning Rate: 1.000e-03
# It: 5100, Loss: 5.922e+03, Y0: 11.731, Time: 38.19, Total Time: 2011.06, Learning Rate: 1.000e-03
# It: 5200, Loss: 1.468e+04, Y0: 11.887, Time: 38.11, Total Time: 2049.17, Learning Rate: 1.000e-03
# It: 5300, Loss: 1.185e+04, Y0: 11.937, Time: 38.38, Total Time: 2087.55, Learning Rate: 1.000e-03
# It: 5400, Loss: 4.176e+03, Y0: 12.036, Time: 38.26, Total Time: 2125.81, Learning Rate: 1.000e-03
# It: 5500, Loss: 8.140e+03, Y0: 12.152, Time: 38.68, Total Time: 2164.49, Learning Rate: 1.000e-03
# It: 5600, Loss: 9.929e+03, Y0: 12.258, Time: 39.65, Total Time: 2204.14, Learning Rate: 1.000e-03
# It: 5700, Loss: 4.970e+03, Y0: 12.358, Time: 39.56, Total Time: 2243.70, Learning Rate: 1.000e-03
# It: 5800, Loss: 4.300e+03, Y0: 12.492, Time: 39.68, Total Time: 2283.38, Learning Rate: 1.000e-03
# It: 5900, Loss: 5.811e+03, Y0: 12.590, Time: 39.47, Total Time: 2322.85, Learning Rate: 1.000e-03
# It: 6000, Loss: 5.024e+03, Y0: 12.630, Time: 38.41, Total Time: 2361.26, Learning Rate: 1.000e-03
# It: 6100, Loss: 6.051e+03, Y0: 12.685, Time: 39.61, Total Time: 2400.87, Learning Rate: 1.000e-03
# It: 6200, Loss: 7.248e+03, Y0: 12.736, Time: 39.65, Total Time: 2440.52, Learning Rate: 1.000e-03
# It: 6300, Loss: 1.086e+04, Y0: 12.735, Time: 39.51, Total Time: 2480.03, Learning Rate: 1.000e-03
# It: 6400, Loss: 5.470e+03, Y0: 12.774, Time: 39.37, Total Time: 2519.40, Learning Rate: 1.000e-03
# It: 6500, Loss: 3.233e+03, Y0: 12.820, Time: 39.03, Total Time: 2558.42, Learning Rate: 1.000e-03
# It: 6600, Loss: 6.759e+03, Y0: 12.848, Time: 38.52, Total Time: 2596.94, Learning Rate: 1.000e-03
# It: 6700, Loss: 7.728e+03, Y0: 12.960, Time: 38.35, Total Time: 2635.30, Learning Rate: 1.000e-03
# It: 6800, Loss: 7.930e+03, Y0: 12.986, Time: 38.15, Total Time: 2673.45, Learning Rate: 1.000e-03
# It: 6900, Loss: 1.207e+08, Y0: 9.944, Time: 38.23, Total Time: 2711.68, Learning Rate: 1.000e-03
# It: 7000, Loss: 1.478e+07, Y0: 2.918, Time: 37.98, Total Time: 2749.66, Learning Rate: 1.000e-03
# It: 7100, Loss: 7.112e+06, Y0: 4.026, Time: 38.14, Total Time: 2787.80, Learning Rate: 1.000e-03
# It: 7200, Loss: 1.272e+06, Y0: 6.487, Time: 38.13, Total Time: 2825.93, Learning Rate: 1.000e-03
# It: 7300, Loss: 1.365e+05, Y0: 5.912, Time: 38.28, Total Time: 2864.21, Learning Rate: 1.000e-03
# It: 7400, Loss: 1.179e+05, Y0: 5.750, Time: 38.16, Total Time: 2902.37, Learning Rate: 1.000e-03
# It: 7500, Loss: 7.287e+04, Y0: 5.983, Time: 38.26, Total Time: 2940.63, Learning Rate: 1.000e-03
# It: 7600, Loss: 7.361e+04, Y0: 5.957, Time: 38.92, Total Time: 2979.55, Learning Rate: 1.000e-03
# It: 7700, Loss: 5.025e+04, Y0: 6.142, Time: 39.53, Total Time: 3019.08, Learning Rate: 1.000e-03
# It: 7800, Loss: 5.862e+04, Y0: 6.263, Time: 39.37, Total Time: 3058.45, Learning Rate: 1.000e-03
# It: 7900, Loss: 4.141e+04, Y0: 6.345, Time: 38.31, Total Time: 3096.76, Learning Rate: 1.000e-03
# It: 8000, Loss: 5.243e+04, Y0: 6.518, Time: 38.91, Total Time: 3135.67, Learning Rate: 1.000e-03
# It: 8100, Loss: 5.712e+04, Y0: 6.556, Time: 39.07, Total Time: 3174.74, Learning Rate: 1.000e-03
# It: 8200, Loss: 5.796e+04, Y0: 6.695, Time: 38.26, Total Time: 3213.00, Learning Rate: 1.000e-03
# It: 8300, Loss: 4.759e+04, Y0: 6.752, Time: 39.45, Total Time: 3252.45, Learning Rate: 1.000e-03
# It: 8400, Loss: 3.482e+04, Y0: 6.918, Time: 39.28, Total Time: 3291.73, Learning Rate: 1.000e-03
# It: 8500, Loss: 4.873e+04, Y0: 7.003, Time: 39.50, Total Time: 3331.23, Learning Rate: 1.000e-03
# It: 8600, Loss: 2.878e+04, Y0: 7.080, Time: 39.30, Total Time: 3370.54, Learning Rate: 1.000e-03
# It: 8700, Loss: 3.836e+04, Y0: 7.251, Time: 39.44, Total Time: 3409.97, Learning Rate: 1.000e-03
# It: 8800, Loss: 3.444e+04, Y0: 7.309, Time: 38.54, Total Time: 3448.51, Learning Rate: 1.000e-03
# It: 8900, Loss: 3.674e+04, Y0: 7.294, Time: 38.27, Total Time: 3486.78, Learning Rate: 1.000e-03
# It: 9000, Loss: 2.704e+04, Y0: 7.426, Time: 38.15, Total Time: 3524.93, Learning Rate: 1.000e-03
# It: 9100, Loss: 4.373e+04, Y0: 7.539, Time: 38.41, Total Time: 3563.34, Learning Rate: 1.000e-03
# It: 9200, Loss: 3.941e+04, Y0: 7.603, Time: 39.82, Total Time: 3603.16, Learning Rate: 1.000e-03
# It: 9300, Loss: 4.443e+04, Y0: 7.898, Time: 39.38, Total Time: 3642.55, Learning Rate: 1.000e-03
# It: 9400, Loss: 3.667e+04, Y0: 7.812, Time: 39.50, Total Time: 3682.05, Learning Rate: 1.000e-03
# It: 9500, Loss: 3.590e+04, Y0: 7.876, Time: 39.47, Total Time: 3721.52, Learning Rate: 1.000e-03
# It: 9600, Loss: 4.004e+04, Y0: 8.011, Time: 38.71, Total Time: 3760.23, Learning Rate: 1.000e-03
# It: 9700, Loss: 4.536e+04, Y0: 8.062, Time: 38.76, Total Time: 3798.99, Learning Rate: 1.000e-03
# It: 9800, Loss: 5.027e+04, Y0: 8.106, Time: 39.22, Total Time: 3838.22, Learning Rate: 1.000e-03
# It: 9900, Loss: 2.681e+04, Y0: 8.281, Time: 39.35, Total Time: 3877.57, Learning Rate: 1.000e-03
# It: 10000, Loss: 2.644e+04, Y0: 8.345, Time: 39.71, Total Time: 3917.28, Learning Rate: 1.000e-03
# It: 10100, Loss: 3.050e+04, Y0: 8.465, Time: 38.89, Total Time: 3956.17, Learning Rate: 1.000e-03
# It: 10200, Loss: 4.522e+04, Y0: 8.462, Time: 38.11, Total Time: 3994.28, Learning Rate: 1.000e-03
# It: 10300, Loss: 3.813e+04, Y0: 8.600, Time: 38.25, Total Time: 4032.53, Learning Rate: 1.000e-03
# It: 10400, Loss: 3.754e+04, Y0: 8.653, Time: 38.33, Total Time: 4070.86, Learning Rate: 1.000e-03
# It: 10500, Loss: 2.916e+04, Y0: 8.769, Time: 38.39, Total Time: 4109.25, Learning Rate: 1.000e-03
# It: 10600, Loss: 3.181e+04, Y0: 8.754, Time: 38.28, Total Time: 4147.52, Learning Rate: 1.000e-03
# It: 10700, Loss: 2.023e+04, Y0: 8.948, Time: 38.71, Total Time: 4186.23, Learning Rate: 1.000e-03
# It: 10800, Loss: 3.842e+04, Y0: 9.042, Time: 39.38, Total Time: 4225.61, Learning Rate: 1.000e-03
# It: 10900, Loss: 4.970e+04, Y0: 9.101, Time: 38.34, Total Time: 4263.95, Learning Rate: 1.000e-03
# It: 11000, Loss: 5.612e+04, Y0: 9.113, Time: 38.35, Total Time: 4302.30, Learning Rate: 1.000e-03
# It: 11100, Loss: 1.447e+04, Y0: 9.151, Time: 38.12, Total Time: 4340.41, Learning Rate: 1.000e-03
# It: 11200, Loss: 2.597e+04, Y0: 9.278, Time: 38.58, Total Time: 4378.99, Learning Rate: 1.000e-03
# It: 11300, Loss: 3.626e+04, Y0: 9.394, Time: 39.78, Total Time: 4418.77, Learning Rate: 1.000e-03
# It: 11400, Loss: 3.627e+04, Y0: 9.378, Time: 39.57, Total Time: 4458.34, Learning Rate: 1.000e-03
# It: 11500, Loss: 2.531e+04, Y0: 9.546, Time: 39.56, Total Time: 4497.90, Learning Rate: 1.000e-03
# It: 11600, Loss: 6.051e+04, Y0: 9.728, Time: 39.62, Total Time: 4537.52, Learning Rate: 1.000e-03
# It: 11700, Loss: 1.078e+07, Y0: 8.387, Time: 38.51, Total Time: 4576.03, Learning Rate: 1.000e-03
# It: 11800, Loss: 6.355e+06, Y0: 10.651, Time: 37.98, Total Time: 4614.01, Learning Rate: 1.000e-03
# It: 11900, Loss: 2.684e+06, Y0: 10.619, Time: 38.16, Total Time: 4652.17, Learning Rate: 1.000e-03
# It: 12000, Loss: 3.854e+06, Y0: 8.886, Time: 39.50, Total Time: 4691.67, Learning Rate: 1.000e-03
# It: 12100, Loss: 1.187e+05, Y0: 10.003, Time: 39.73, Total Time: 4731.40, Learning Rate: 1.000e-03
# It: 12200, Loss: 6.756e+04, Y0: 10.154, Time: 39.32, Total Time: 4770.73, Learning Rate: 1.000e-03
# It: 12300, Loss: 6.488e+04, Y0: 10.357, Time: 39.22, Total Time: 4809.95, Learning Rate: 1.000e-03
# It: 12400, Loss: 5.256e+04, Y0: 10.466, Time: 39.33, Total Time: 4849.28, Learning Rate: 1.000e-03
# It: 12500, Loss: 3.710e+04, Y0: 10.582, Time: 38.31, Total Time: 4887.59, Learning Rate: 1.000e-03
# It: 12600, Loss: 4.571e+04, Y0: 10.670, Time: 38.09, Total Time: 4925.69, Learning Rate: 1.000e-03
# It: 12700, Loss: 5.384e+04, Y0: 10.775, Time: 39.00, Total Time: 4964.69, Learning Rate: 1.000e-03
# It: 12800, Loss: 3.985e+04, Y0: 10.906, Time: 38.13, Total Time: 5002.82, Learning Rate: 1.000e-03
# It: 12900, Loss: 4.264e+04, Y0: 10.945, Time: 39.98, Total Time: 5042.79, Learning Rate: 1.000e-03
# It: 13000, Loss: 5.096e+04, Y0: 11.020, Time: 39.60, Total Time: 5082.39, Learning Rate: 1.000e-03
# It: 13100, Loss: 3.893e+04, Y0: 11.125, Time: 38.70, Total Time: 5121.09, Learning Rate: 1.000e-03
# It: 13200, Loss: 3.449e+04, Y0: 11.235, Time: 38.18, Total Time: 5159.27, Learning Rate: 1.000e-03
# It: 13300, Loss: 4.407e+04, Y0: 11.275, Time: 38.34, Total Time: 5197.61, Learning Rate: 1.000e-03
# It: 13400, Loss: 3.581e+04, Y0: 11.344, Time: 38.14, Total Time: 5235.75, Learning Rate: 1.000e-03
# It: 13500, Loss: 4.088e+04, Y0: 11.426, Time: 38.45, Total Time: 5274.20, Learning Rate: 1.000e-03
# It: 13600, Loss: 4.575e+04, Y0: 11.500, Time: 38.28, Total Time: 5312.48, Learning Rate: 1.000e-03
# It: 13700, Loss: 3.660e+04, Y0: 11.573, Time: 38.54, Total Time: 5351.02, Learning Rate: 1.000e-03
# It: 13800, Loss: 2.756e+04, Y0: 11.656, Time: 38.41, Total Time: 5389.43, Learning Rate: 1.000e-03
# It: 13900, Loss: 3.683e+04, Y0: 11.704, Time: 38.18, Total Time: 5427.61, Learning Rate: 1.000e-03
# It: 14000, Loss: 5.197e+04, Y0: 11.767, Time: 38.17, Total Time: 5465.78, Learning Rate: 1.000e-03
# It: 14100, Loss: 4.267e+04, Y0: 11.828, Time: 38.94, Total Time: 5504.72, Learning Rate: 1.000e-03
# It: 14200, Loss: 2.898e+04, Y0: 11.896, Time: 39.66, Total Time: 5544.38, Learning Rate: 1.000e-03
# It: 14300, Loss: 2.941e+04, Y0: 11.993, Time: 39.41, Total Time: 5583.79, Learning Rate: 1.000e-03
# It: 14400, Loss: 3.624e+04, Y0: 12.063, Time: 38.30, Total Time: 5622.09, Learning Rate: 1.000e-03
# It: 14500, Loss: 3.399e+04, Y0: 12.140, Time: 38.13, Total Time: 5660.22, Learning Rate: 1.000e-03
# It: 14600, Loss: 3.822e+04, Y0: 12.244, Time: 38.38, Total Time: 5698.60, Learning Rate: 1.000e-03
# It: 14700, Loss: 3.860e+04, Y0: 12.294, Time: 38.13, Total Time: 5736.73, Learning Rate: 1.000e-03
# It: 14800, Loss: 4.548e+04, Y0: 12.353, Time: 38.16, Total Time: 5774.89, Learning Rate: 1.000e-03
# It: 14900, Loss: 3.795e+04, Y0: 12.455, Time: 38.62, Total Time: 5813.51, Learning Rate: 1.000e-03
# It: 15000, Loss: 3.688e+04, Y0: 12.479, Time: 39.61, Total Time: 5853.12, Learning Rate: 1.000e-03
# It: 15100, Loss: 3.755e+04, Y0: 12.560, Time: 39.58, Total Time: 5892.70, Learning Rate: 1.000e-03
# It: 15200, Loss: 2.854e+04, Y0: 12.709, Time: 38.59, Total Time: 5931.30, Learning Rate: 1.000e-03
# It: 15300, Loss: 3.785e+04, Y0: 12.758, Time: 39.62, Total Time: 5970.92, Learning Rate: 1.000e-03
# It: 15400, Loss: 2.890e+04, Y0: 12.839, Time: 38.50, Total Time: 6009.43, Learning Rate: 1.000e-03
# It: 15500, Loss: 2.943e+04, Y0: 12.954, Time: 39.39, Total Time: 6048.81, Learning Rate: 1.000e-03
# It: 15600, Loss: 3.974e+04, Y0: 13.012, Time: 38.36, Total Time: 6087.17, Learning Rate: 1.000e-03
# It: 15700, Loss: 2.035e+06, Y0: 12.790, Time: 38.24, Total Time: 6125.41, Learning Rate: 1.000e-03
# It: 15800, Loss: 6.352e+06, Y0: 12.698, Time: 39.31, Total Time: 6164.72, Learning Rate: 1.000e-03
# It: 15900, Loss: 8.448e+06, Y0: 13.215, Time: 39.66, Total Time: 6204.38, Learning Rate: 1.000e-03
# It: 16000, Loss: 1.365e+08, Y0: 13.921, Time: 39.38, Total Time: 6243.76, Learning Rate: 1.000e-03
# It: 16100, Loss: 2.257e+08, Y0: 12.208, Time: 39.66, Total Time: 6283.42, Learning Rate: 1.000e-03
# It: 16200, Loss: 9.110e+07, Y0: 13.252, Time: 39.85, Total Time: 6323.27, Learning Rate: 1.000e-03
# It: 16300, Loss: 1.007e+08, Y0: 13.443, Time: 39.23, Total Time: 6362.50, Learning Rate: 1.000e-03
# It: 16400, Loss: 1.275e+08, Y0: 13.007, Time: 39.15, Total Time: 6401.66, Learning Rate: 1.000e-03
# It: 16500, Loss: 9.107e+07, Y0: 13.767, Time: 39.78, Total Time: 6441.43, Learning Rate: 1.000e-03
# It: 16600, Loss: 3.259e+07, Y0: 13.244, Time: 39.67, Total Time: 6481.10, Learning Rate: 1.000e-03
# It: 16700, Loss: 9.882e+06, Y0: 13.074, Time: 39.35, Total Time: 6520.45, Learning Rate: 1.000e-03
# It: 16800, Loss: 4.758e+06, Y0: 13.309, Time: 38.56, Total Time: 6559.01, Learning Rate: 1.000e-03
# It: 16900, Loss: 1.567e+06, Y0: 13.334, Time: 38.34, Total Time: 6597.35, Learning Rate: 1.000e-03
# It: 17000, Loss: 1.384e+06, Y0: 13.368, Time: 38.83, Total Time: 6636.17, Learning Rate: 1.000e-03
# It: 17100, Loss: 6.740e+05, Y0: 13.403, Time: 38.21, Total Time: 6674.39, Learning Rate: 1.000e-03
# It: 17200, Loss: 5.275e+05, Y0: 13.433, Time: 39.87, Total Time: 6714.26, Learning Rate: 1.000e-03
# It: 17300, Loss: 3.886e+05, Y0: 13.471, Time: 38.39, Total Time: 6752.64, Learning Rate: 1.000e-03
# It: 17400, Loss: 3.332e+05, Y0: 13.511, Time: 38.38, Total Time: 6791.03, Learning Rate: 1.000e-03
# It: 17500, Loss: 2.281e+05, Y0: 13.545, Time: 38.16, Total Time: 6829.19, Learning Rate: 1.000e-03
# It: 17600, Loss: 1.752e+05, Y0: 13.579, Time: 38.64, Total Time: 6867.82, Learning Rate: 1.000e-03
# It: 17700, Loss: 1.176e+05, Y0: 13.613, Time: 39.84, Total Time: 6907.67, Learning Rate: 1.000e-03
# It: 17800, Loss: 1.155e+05, Y0: 13.644, Time: 39.77, Total Time: 6947.43, Learning Rate: 1.000e-03
# It: 17900, Loss: 1.028e+05, Y0: 13.680, Time: 39.45, Total Time: 6986.88, Learning Rate: 1.000e-03
# It: 18000, Loss: 8.583e+04, Y0: 13.714, Time: 39.44, Total Time: 7026.32, Learning Rate: 1.000e-03
# It: 18100, Loss: 8.679e+04, Y0: 13.753, Time: 39.42, Total Time: 7065.74, Learning Rate: 1.000e-03
# It: 18200, Loss: 8.393e+04, Y0: 13.787, Time: 38.88, Total Time: 7104.62, Learning Rate: 1.000e-03
# It: 18300, Loss: 6.292e+04, Y0: 13.823, Time: 39.56, Total Time: 7144.19, Learning Rate: 1.000e-03
# It: 18400, Loss: 6.171e+04, Y0: 13.856, Time: 39.43, Total Time: 7183.61, Learning Rate: 1.000e-03
# It: 18500, Loss: 6.799e+04, Y0: 13.886, Time: 38.37, Total Time: 7221.99, Learning Rate: 1.000e-03
# It: 18600, Loss: 7.556e+04, Y0: 13.921, Time: 38.08, Total Time: 7260.06, Learning Rate: 1.000e-03
# It: 18700, Loss: 6.209e+04, Y0: 13.959, Time: 38.24, Total Time: 7298.30, Learning Rate: 1.000e-03
# It: 18800, Loss: 6.886e+04, Y0: 13.993, Time: 38.50, Total Time: 7336.80, Learning Rate: 1.000e-03
# It: 18900, Loss: 5.610e+04, Y0: 14.021, Time: 38.30, Total Time: 7375.11, Learning Rate: 1.000e-03
# It: 19000, Loss: 6.496e+04, Y0: 14.055, Time: 38.20, Total Time: 7413.31, Learning Rate: 1.000e-03
# It: 19100, Loss: 6.083e+04, Y0: 14.089, Time: 38.18, Total Time: 7451.49, Learning Rate: 1.000e-03
# It: 19200, Loss: 6.117e+04, Y0: 14.122, Time: 38.27, Total Time: 7489.76, Learning Rate: 1.000e-03
# It: 19300, Loss: 5.915e+04, Y0: 14.150, Time: 38.42, Total Time: 7528.19, Learning Rate: 1.000e-03
# It: 19400, Loss: 5.295e+04, Y0: 14.183, Time: 38.45, Total Time: 7566.64, Learning Rate: 1.000e-03
# It: 19500, Loss: 5.071e+04, Y0: 14.210, Time: 38.25, Total Time: 7604.89, Learning Rate: 1.000e-03
# It: 19600, Loss: 5.718e+04, Y0: 14.240, Time: 38.19, Total Time: 7643.08, Learning Rate: 1.000e-03
# It: 19700, Loss: 5.141e+04, Y0: 14.264, Time: 38.14, Total Time: 7681.21, Learning Rate: 1.000e-03
# It: 19800, Loss: 5.073e+04, Y0: 14.293, Time: 38.31, Total Time: 7719.53, Learning Rate: 1.000e-03
# It: 19900, Loss: 4.892e+04, Y0: 14.318, Time: 38.52, Total Time: 7758.05, Learning Rate: 1.000e-03

# %%
np.random.seed(42)
t_test, B_test = model.fetch_minibatch()
W_test, Var_test = model.variance()

X_pred, Y_pred, delta_pred = model.predict(Xi, t_test, W_test, B_test, Var_test)
#Y0_test = 4.9550

# %%
D = 20
plt.figure()
plt.plot(graph[0], graph[1])
plt.xlabel('Iterations')
plt.ylabel('Value')
plt.yscale("log")
plt.title('Evolution of the training loss')
plt.savefig(str(D) + 'train-loss' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(Y0_iter[0], Y0_iter[1], label='Learned $Y_0$')
#plt.axhline(Y0_test, color='r', label='Exact $Y_0$')
plt.xlabel('Iterations')
plt.ylabel('Y Initial Value')
#plt.yscale("log")
plt.title('Evolution of the Y Initial')
plt.savefig(str(D) + ' Initial' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(delta_iter[0], delta_iter[1], label='Learned $Delta_T$')
plt.xlabel('Iterations')
plt.ylabel('Delta Value')
#plt.yscale("log")
plt.title('Evolution of the Delta')
plt.savefig(str(D) + 'Delta' + 'RoughBergomiModel')

# %%
tf.experimental.numpy.experimental_enable_numpy_behavior()

# %%
samples = 5
plt.figure()
plt.plot(t_test[0:1, :, 0].T, Y_pred[0:1, :, 0].T, 'b', label='Learned $u(t,X_t)$')

plt.plot(t_test[1:samples, :, 0].T, Y_pred[1:samples, :, 0].T, 'b')

plt.xlabel('$t$')
plt.ylabel('$Y_t = u(t,X_t)$')
plt.title(str(D) + '-dimensional RoughBergomiModel')
plt.legend()
plt.savefig(str(D) +'-dimensional RoughBergomiModel' + 'traces')

# %%
# !pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0

# %%
#. Monte Carlo Simulation
T_mc = 1.0  # terminal time
M_mc = 10000  # number of trajectories
N_mc = 50  # number of time snapshots
D_mc = 20  # number of dimensions
H_mc = 0.07  # Hurst exponent (0,1)
eta_mc = 1.9  # parameter for control volatility
pho_mc = -0.9  # correlation betwen two independent Wiener process
r_mc = 0.05  # interest rate

layers_mc = [D_mc+1] + 4 * [256] + [1] + [D_mc]

Xi_mc = np.array([np.log(100.0), np.log(50.0)] * int(D_mc/2) )[None, :]
model_mc = RoughBergomiModel(Xi_mc, T_mc, M_mc, N_mc, D_mc, H_mc, eta_mc, pho_mc, r_mc, layers_mc)

np.random.seed(42)
t_mc_test, B_mc_test = model_mc.fetch_minibatch()
W_mc_test, Var_mc_test = model_mc.variance()

def MC_simulation(t, W, B, Var, Xi):

    X_list = []

    t0 = t[:, 0, :]
    W0 = W[:, 0, :]
    B0 = B[:, 0, :]
    Var0 = Var[:, 0, :]

    X0 = tf.tile(Xi, [M_mc, 1])  # M x D
    X_list.append(X0)

    for n in range(0, N_mc):
        t1 = t[:, n + 1, :]
        W1 = W[:, n + 1, :]
        B1 = B[:, n + 1, :]
        Var1 = Var[:, n + 1, :]

        BM = pho_mc * (W1 - W0) + np.sqrt(1 - np.square(pho_mc)) * (B1 - B0)
        X1 = X0 - Var0 * 0.5 * (t1 - t0)+ np.sqrt(Var0) * BM

        t0 = t1
        W0 = W1
        B0 = B1
        Var0 = Var1
        X0 = X1

        X_list.append(X0)

    X = tf.stack(X_list, axis=1)
    return X

X_mc = MC_simulation(t_mc_test, W_mc_test, B_mc_test, Var_mc_test, Xi_mc)
K_mc = np.tile(np.array([90.0], dtype=np.float32)[None, :], [M_mc, 1])
S_T_mc = np.mean(np.exp(X_mc[:, -1, :] + r_mc * T_mc), axis=1, keepdims = True)
put_option_mc = np.mean(np.maximum(K_mc - S_T_mc, 0.0), axis=0) * np.exp(-r_mc * T_mc)

# %%
Y_pred_mean = np.mean(Y_pred, axis=0)
Y_pred_std = np.std(Y_pred, axis=0)
error = Y_pred_mean[0, 0] - put_option_mc
#print('Y0_mean is: {}'.format(Y_pred_mean[0, 0]))
#print('Y0_exact is: {}'.format(Y0_test))
#print('Y0_std is: {}'.format(Y_pred_std[0, 0]))
#print('Relative Error is: {}'.format(error))

# %%
from tabulate import tabulate
table = {'reference value': put_option_mc, 'Y0_mean': Y_pred_mean[0, :].tolist(), 'Y0_std': Y_pred_std[0, :].tolist(), 'relative error': error}
print(tabulate(table, headers='keys', tablefmt='github'))
# Out:
# |   reference value |   Y0_mean |      Y0_std |   relative error |
# |-------------------|-----------|-------------|------------------|
# |           13.9343 |   14.3464 | 1.52588e-05 |         0.412048 |
