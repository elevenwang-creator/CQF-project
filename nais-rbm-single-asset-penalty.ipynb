# %%
# basic imports
import os, random
import numpy as np
import datetime as dt
import time
from scipy.fftpack import fft, ifft
from abc import ABC, abstractmethod
import matplotlib.pyplot as plt

# warnings
import warnings

warnings.filterwarnings('ignore')

# tensorflow
import tensorflow as tf

tf.keras.backend.clear_session()

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import Layer, Add

# %%
print(f" TensorFlow version is {tf.__version__}")
#print(f"Keras version is {tf.keras.__version__}")
print(tf.config.list_physical_devices())
# Out:
#  TensorFlow version is 2.15.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class Linear(Layer):
    """Define Linear layers"""

    def __init__(self, in_features, out_features):
        super(Linear, self).__init__()

        self.in_dims = in_features
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'
        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        return tf.matmul(inputs, self.w) + self.b


class StableLinear(Layer):
    """Define Stable Linear layers"""

    def __init__(self, in_features, out_features):
        super(StableLinear, self).__init__()

        self.epsilon = 0.01
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'

        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        w = self.weight_constraint(self.w)
        return tf.matmul(inputs, w) + self.b

    #@tf.function
    def weight_constraint(self, weight):
        delta = 1 - 2 * self.epsilon
        RtR = tf.matmul(tf.transpose(weight), weight)
        norm = tf.norm(RtR)

        #if norm > delta: RtR = delta ** (1 / 2) * RtR / (norm ** (1 / 2))
        RtR_new = tf.sqrt(delta) * RtR / tf.sqrt(norm)
        RtR_update = tf.minimum(RtR_new, RtR)
        #def f2(): return RtR
        #RtR = tf.cond(tf.greater(norm, delta), f1, f2)
        A = RtR_update + tf.eye(RtR.shape[0]) * self.epsilon
        return -A


class NaisNet(Model):
    """ Building NAIS_Net network using keras """

    def __init__(self, layers):
        super(NaisNet, self).__init__()

        self.layer1 = Linear(layers[0], layers[1])

        self.layer2 = StableLinear(layers[1], layers[2])
        self.layer2_input = Linear(layers[0], layers[2])

        self.layer3 = StableLinear(layers[2], layers[3])
        self.layer3_input = Linear(layers[0], layers[3])

        self.layer4 = StableLinear(layers[3], layers[4])
        self.layer4_input = Linear(layers[0], layers[4])

        self.layer5 = Linear(layers[4], layers[5])

    # Building block for the NAIS-Net
    #@tf.function
    def call(self, x):
        """Process stages in the block"""

        u = x

        output = self.layer1(u)  # layer 1
        output = tf.sin(output)

        X1 = output
        output = self.layer2(output)  # layer 2
        output = Add()([self.layer2_input(u), output])
        output = tf.sin(output)
        output = Add()([X1, output])

        X2 = output
        output = self.layer3(output)  # layer 3
        output = Add()([self.layer3_input(u), output])
        output = tf.sin(output)
        output = Add()([X2, output])

        X3 = output
        output = self.layer4(output)  # layer 4
        output = Add()([self.layer4_input(u), output])
        output = tf.sin(output)
        output = Add()([X3, output])

        output = self.layer5(output)  # layer 5

        return output


class FBSNN(ABC):
    """Forward-Backward SDEs using NAIS-Net """

    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):    # , layer_phi

        self.Xi = Xi  # initial point

        self.T = T  # terminal time
        self.M = M  # number of trajectories
        self.N = N  # number of time snapshots
        self.D = D  # number of dimensions
        self.H = H  # Hurst exponent (0,1)
        self.eta = eta  # parameter for control volatility
        self.pho = tf.Variable(pho, dtype=tf.float32) # correlation betwen two independent Wiener process
        self.epsilon_t = 0.09 # forward variance curve epsilon(t) - constant
        self.r = tf.Variable(r, dtype=tf.float32)  # interest rate
           
        # Initialize NN
        self.model = NaisNet(layers)
        #self.model_phi = NaisNet(layer_phi)

        # Record the loss
        self.training_loss = []
        self.iteration = []
        self.Y0_iter = []
        self.Du0_iter = []

    @tf.function
    def net_u(self, t, X):  # M x 1, M x D

        y = self.model(tf.concat([t, X], 1))  # M x [1+D]
        u = tf.expand_dims(y[:, 0], axis=-1)  # M x 1
        #phi = self.model_phi(tf.concat([t, X], 1)) # M x D
        phi = y[:, 1:] # M x D
        Du = tf.gradients(u, X)[0]  # M x D

        return u, phi, Du

    @tf.function
    def Dg_tf(self, X):  # M x D
        return tf.gradients(self.g_tf(X), X)[0]  # M x D

    #@tf.function
    def loss_function(self, t, W, B, Var, Xi):

        loss = 0
        X_list = []
        Y_list = []
        Tilde_Z_list = []
        Z_list = []
        Du_list = []


        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        B0 = B[:, 0, :]
        Var0 = Var[:, 0, :]

        X0 = tf.tile(Xi, [self.M, 1])  # M x D
        Y0, phi0, du0 = self.net_u(t0, X0)  # M x 1, M x D, M x D
        Z0 = self.Z_tf(Var0,du0) # M x D
        Tilde_Z0 = self.Z_tilde_tf(Var0, phi0, du0) # M x D

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)
        Tilde_Z_list.append(Tilde_Z0)
        Du_list.append(du0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]
            B1 = B[:, n + 1, :]
            Var1 = Var[:, n + 1, :]
            BM = self.pho * (W1 - W0) + tf.sqrt(1 - self.pho**2) * (B1 - B0)
            X1 = X0 +self.mu_tf(t0, X0, Y0, du0) * (t1 - t0)  - Var0 * 0.5 * (t1 - t0) + tf.sqrt(Var0) * BM

            Y1_tilde = Y0 + self.F_tf(t0, X0, Y0, Z0, Tilde_Z0) * (t1 - t0) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Z0, tf.expand_dims(B1 - B0, -1))), axis=1, 
                keepdims=True) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Tilde_Z0, tf.expand_dims(W1 - W0, -1))), axis=1, keepdims=True)
            
            Y1, phi1, du1 = self.net_u(t1, X1)
            Z1 = self.Z_tf(Var1,du1) # M x D
            Tilde_Z1 = self.Z_tilde_tf(Var1, phi1, du1) # M x D


            loss += tf.reduce_sum(tf.pow(Y1 - Y1_tilde, 2))

            t0 = t1
            W0 = W1
            B0 = B1
            Var0 = Var1
            du0 = du1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            Tilde_Z0 = Tilde_Z1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)
            Tilde_Z_list.append(Tilde_Z0)
            Du_list.append(du0)
        
        # 0.02 is the penalty parameters for the terminal conditions
        loss +=  0.02 * tf.reduce_sum(tf.pow(Y1 - self.g_tf(X1), 2))
        loss +=  0.02 * tf.reduce_sum(tf.pow(du1 - self.Dg_tf(X1), 2))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)
        Tilde_Z = tf.stack(Tilde_Z_list, axis=1)
        Du_t = tf.stack(Du_list, axis=1)
        Y0 = tf.reduce_mean(Y, axis=0)

        return loss, X, Y, Y0[0, 0], Du_t

    def Z_tf(self, Var, Du):  # M x D
        return tf.sqrt((1 - self.pho**2) * Var) * Du

    def Z_tilde_tf(self, Var, phi, Du): # M x D
        return self.pho * tf.sqrt(Var) * Du + phi

    # Volterra process Using hybrid scheme
    def volterra(self):
        T = self.T
        M = self.M
        N = self.N
        D = self.D
        delta_t = T / N
        alpha = self.H - 0.5
        
        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D
        Dt[:, 1:, :] = delta_t
        DW[:, 1:, :] = np.sqrt(delta_t) * np.random.normal(size=(M, N, D))
        
        t_series = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W_process = np.cumsum(DW, axis=1)  # M x (N+1) x D

        sigma = (2*alpha + 1)**0.5
        #kernal function
        def g_kernel(k):
            y = (k**(alpha+1) - (k-1)**(alpha+1)) / (alpha+1)
            b = np.power(y, 1/alpha)
            return np.power((b) * delta_t, alpha)

        #t_series, W_process = self.fetch_minibatch()

        tilde_X = np.zeros((M, N+1, D))
        tilde_X[:, 0 , :]= W_process[:, 0 , :]

        WN_tj_minus_1_1 = np.roll(W_process, shift=-1, axis=1) - W_process

        for m in range(M):
            for d in range(D):
                # first column for toeplitz matrix 
                WN_j = WN_tj_minus_1_1[m, :-1, d]
                sigma_col = np.zeros((N)) 
                sigma_col[0] = np.power(delta_t/2, alpha) * sigma
                # 
                for k in range(1, N):
                    g_b_star_k = g_kernel(k+1)
                    sigma_col[k] = sigma * g_b_star_k

                # FFT and dot
                WN_j_fft = fft(WN_j)
                sigma_fft = fft(sigma_col)
                convolved = ifft(WN_j_fft * sigma_fft) 

                # capture real value 
                tilde_X[m, 1:, d] = np.real(convolved)
        
        return t_series, W_process, tilde_X

    # Variace process
    def variance(self):

        t, W_s, D_hat_w = self.volterra()# M x (N+1) x D

        var = self.epsilon_t * np.exp(self.eta* D_hat_w -  0.5 * self.eta**2 * np.power(t, 2*self.H))

        return W_s, var

    #@tf.function
    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W = np.cumsum(DW, axis=1)  # M x (N+1) x D

        return t, W

    @tf.function
    def train_step(self, optimizers, t, w, b, var, Xi):
        # Optimizers
        optimizer = optimizers

        with tf.GradientTape() as tape:
            loss_value, X_pred, Y_pred, Y0_pred, Du0_pred = self.loss_function(t, w, b, var, Xi)

        grads = tape.gradient(loss_value, self.model.trainable_weights)
        #optimizer.apply(grads, self.model.trainable_weights)
        optimizer.apply_gradients(zip(grads, self.model.trainable_weights))


        return loss_value, Y0_pred, Du0_pred

    #@tf.function
    def train(self, N_Iter, learning_rate):

        loss_temp = np.array([])
        Y0_pred_temp = np.array([])
        Du0_pred_temp = np.array([])

        # Optimizers
        self.optimizer = Adam(learning_rate=learning_rate)

        start_time = time.time()
        ini_time = time.time()

        for it in range(N_Iter):

            t_batch, B_batch = self.fetch_minibatch()  # M x (N+1) x 1, M x (N+1) x D
            W_batch, Var_batch = self.variance() # M x (N+1) x D, M x (N+1) x D
            t_batch = tf.convert_to_tensor(t_batch, dtype=tf.float32)
            B_batch = tf.convert_to_tensor(B_batch, dtype=tf.float32)
            W_batch = tf.convert_to_tensor(W_batch, dtype=tf.float32)
            Var_batch = tf.convert_to_tensor(Var_batch, dtype=tf.float32)
            self.Xi = tf.convert_to_tensor(self.Xi, dtype=tf.float32)

            loss_value, Y0_pred, Du0_pred = self.train_step(self.optimizer, t_batch, W_batch, B_batch, Var_batch, self.Xi)

            if it % 100 == 0:
                elapsed = time.time() - start_time
                total_time = time.time() - ini_time
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Total Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_pred, elapsed, total_time, learning_rate))
                start_time = time.time()

            loss_temp = np.append(loss_temp, loss_value.numpy())
            Y0_pred_temp = np.append(Y0_pred_temp, Y0_pred.numpy())

            Du0 = tf.reduce_mean(Du0_pred, axis=0)
            Du0_pred_temp = np.append(Du0_pred_temp, Du0.numpy()[0, :])

            if it % 100 == 0:
                self.training_loss.append(loss_temp.mean())
                self.Y0_iter.append(Y0_pred_temp[-100:].mean())
                self.Du0_iter.append(Du0_pred_temp[-100:].mean())
                self.iteration.append(it)
  
            graph = np.stack((self.iteration, self.training_loss))
            Y0_iter = np.stack((self.iteration, self.Y0_iter))
            Du0_iter = np.stack((self.iteration, self.Du0_iter))

        return graph, Y0_iter, Du0_iter

    def predict(self, Xi_star, t_star, W_star, B_star, Var_star):
        t_star = tf.convert_to_tensor(t_star, dtype=tf.float32)
        W_star = tf.convert_to_tensor(W_star, dtype=tf.float32)
        Xi_star = tf.convert_to_tensor(Xi_star, dtype=tf.float32)
        B_star = tf.convert_to_tensor(B_star, dtype=tf.float32)
        Var_star = tf.convert_to_tensor(Var_star, dtype=tf.float32)        

        loss, X_star, Y_star, Y0_pred, delta_star = self.loss_function(t_star, W_star, B_star, Var_star, Xi_star)

        return X_star, Y_star, delta_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        pass  # M x1

    @abstractmethod
    def g_tf(self, X):  # M x D
        pass  # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return tf.zeros([M, D])  # M x D
    ###########################################################################

# %%
class RoughBergomiModel(FBSNN):
    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):
        super().__init__(Xi, T, M, N, D, H, eta, pho, r, layers)

    def g_tf(self, X):  # M x D
        K = tf.tile(np.array([90.0], dtype=np.float32)[None, :], [self.M, 1])
        X = tf.reduce_mean(tf.exp(X + self.r * self.T), axis=1, keepdims = True)
        return tf.maximum(K - X, 0) # M x 1  

    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        return super().mu_tf(t, X, Y, Du)  # M x D

    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        return self.r * Y # M x1

    ###########################################################################

# %%
T = 1.0  # terminal time
M = 100  # number of trajectories
N = 50  # number of time snapshots
D = 1  # number of dimensions
H = 0.07  # Hurst exponent (0,1)
eta = 1.9  # parameter for control volatility
pho = -0.9  # correlation betwen two independent Wiener process
r = 0.05  # interest rate

Xi = np.array([np.log(100.0)])[None, :]

layers = [D+1] + 4 * [256] + [1+D]

model = RoughBergomiModel(Xi, T, M, N, D, H, eta, pho, r, layers)
graph, Y0_iter, delta_iter = model.train(2*10**4, 1e-3)
# Out:
# It: 0, Loss: 2.986e+06, Y0: 2.110, Time: 27.44, Total Time: 27.44, Learning Rate: 1.000e-03
# It: 100, Loss: 3.149e+03, Y0: 0.151, Time: 12.67, Total Time: 40.11, Learning Rate: 1.000e-03
# It: 200, Loss: 3.287e+03, Y0: -0.095, Time: 12.61, Total Time: 52.71, Learning Rate: 1.000e-03
# It: 300, Loss: 4.237e+03, Y0: -0.185, Time: 12.70, Total Time: 65.41, Learning Rate: 1.000e-03
# It: 400, Loss: 2.253e+03, Y0: -0.152, Time: 12.66, Total Time: 78.08, Learning Rate: 1.000e-03
# It: 500, Loss: 2.423e+03, Y0: -0.062, Time: 12.58, Total Time: 90.66, Learning Rate: 1.000e-03
# It: 600, Loss: 3.617e+03, Y0: 0.050, Time: 12.75, Total Time: 103.41, Learning Rate: 1.000e-03
# It: 700, Loss: 3.361e+03, Y0: 0.166, Time: 12.65, Total Time: 116.06, Learning Rate: 1.000e-03
# It: 800, Loss: 1.712e+03, Y0: 0.361, Time: 12.76, Total Time: 128.81, Learning Rate: 1.000e-03
# It: 900, Loss: 3.496e+03, Y0: 0.520, Time: 12.61, Total Time: 141.42, Learning Rate: 1.000e-03
# It: 1000, Loss: 3.033e+03, Y0: 0.621, Time: 12.74, Total Time: 154.16, Learning Rate: 1.000e-03
# It: 1100, Loss: 2.608e+03, Y0: 0.753, Time: 12.79, Total Time: 166.95, Learning Rate: 1.000e-03
# It: 1200, Loss: 3.499e+03, Y0: 0.918, Time: 12.69, Total Time: 179.64, Learning Rate: 1.000e-03
# It: 1300, Loss: 3.411e+03, Y0: 1.138, Time: 12.87, Total Time: 192.51, Learning Rate: 1.000e-03
# It: 1400, Loss: 3.450e+03, Y0: 1.263, Time: 12.69, Total Time: 205.19, Learning Rate: 1.000e-03
# It: 1500, Loss: 2.614e+03, Y0: 1.431, Time: 12.96, Total Time: 218.16, Learning Rate: 1.000e-03
# It: 1600, Loss: 3.052e+03, Y0: 1.555, Time: 13.00, Total Time: 231.16, Learning Rate: 1.000e-03
# It: 1700, Loss: 3.379e+03, Y0: 1.696, Time: 12.82, Total Time: 243.98, Learning Rate: 1.000e-03
# It: 1800, Loss: 2.885e+03, Y0: 1.841, Time: 12.95, Total Time: 256.93, Learning Rate: 1.000e-03
# It: 1900, Loss: 3.820e+03, Y0: 2.001, Time: 12.93, Total Time: 269.86, Learning Rate: 1.000e-03
# It: 2000, Loss: 2.377e+03, Y0: 2.155, Time: 13.04, Total Time: 282.90, Learning Rate: 1.000e-03
# It: 2100, Loss: 3.043e+03, Y0: 2.260, Time: 12.85, Total Time: 295.76, Learning Rate: 1.000e-03
# It: 2200, Loss: 2.924e+03, Y0: 2.350, Time: 12.80, Total Time: 308.56, Learning Rate: 1.000e-03
# It: 2300, Loss: 3.952e+03, Y0: 2.490, Time: 12.70, Total Time: 321.26, Learning Rate: 1.000e-03
# It: 2400, Loss: 2.476e+03, Y0: 2.522, Time: 12.55, Total Time: 333.80, Learning Rate: 1.000e-03
# It: 2500, Loss: 2.092e+03, Y0: 2.643, Time: 12.74, Total Time: 346.54, Learning Rate: 1.000e-03
# It: 2600, Loss: 2.875e+03, Y0: 2.746, Time: 12.60, Total Time: 359.14, Learning Rate: 1.000e-03
# It: 2700, Loss: 3.492e+03, Y0: 2.867, Time: 12.56, Total Time: 371.70, Learning Rate: 1.000e-03
# It: 2800, Loss: 3.367e+03, Y0: 3.022, Time: 12.71, Total Time: 384.41, Learning Rate: 1.000e-03
# It: 2900, Loss: 3.333e+03, Y0: 3.075, Time: 12.62, Total Time: 397.03, Learning Rate: 1.000e-03
# It: 3000, Loss: 6.591e+03, Y0: 3.223, Time: 12.69, Total Time: 409.73, Learning Rate: 1.000e-03
# It: 3100, Loss: 2.855e+03, Y0: 3.457, Time: 12.55, Total Time: 422.28, Learning Rate: 1.000e-03
# It: 3200, Loss: 1.330e+04, Y0: 3.334, Time: 12.55, Total Time: 434.82, Learning Rate: 1.000e-03
# It: 3300, Loss: 2.240e+03, Y0: 3.406, Time: 12.64, Total Time: 447.46, Learning Rate: 1.000e-03
# It: 3400, Loss: 4.461e+03, Y0: 3.344, Time: 12.56, Total Time: 460.02, Learning Rate: 1.000e-03
# It: 3500, Loss: 3.034e+03, Y0: 3.539, Time: 12.68, Total Time: 472.70, Learning Rate: 1.000e-03
# It: 3600, Loss: 3.131e+03, Y0: 3.649, Time: 12.51, Total Time: 485.21, Learning Rate: 1.000e-03
# It: 3700, Loss: 2.564e+03, Y0: 3.626, Time: 12.58, Total Time: 497.80, Learning Rate: 1.000e-03
# It: 3800, Loss: 2.632e+03, Y0: 3.704, Time: 12.64, Total Time: 510.43, Learning Rate: 1.000e-03
# It: 3900, Loss: 3.019e+03, Y0: 3.748, Time: 12.54, Total Time: 522.97, Learning Rate: 1.000e-03
# It: 4000, Loss: 2.867e+03, Y0: 3.555, Time: 12.68, Total Time: 535.65, Learning Rate: 1.000e-03
# It: 4100, Loss: 3.425e+03, Y0: 3.482, Time: 12.54, Total Time: 548.20, Learning Rate: 1.000e-03
# It: 4200, Loss: 6.105e+05, Y0: 4.573, Time: 12.52, Total Time: 560.71, Learning Rate: 1.000e-03
# It: 4300, Loss: 9.138e+03, Y0: 2.459, Time: 12.62, Total Time: 573.34, Learning Rate: 1.000e-03
# It: 4400, Loss: 2.976e+03, Y0: 2.577, Time: 12.69, Total Time: 586.02, Learning Rate: 1.000e-03
# It: 4500, Loss: 3.193e+03, Y0: 2.771, Time: 12.69, Total Time: 598.71, Learning Rate: 1.000e-03
# It: 4600, Loss: 4.486e+03, Y0: 2.882, Time: 12.75, Total Time: 611.46, Learning Rate: 1.000e-03
# It: 4700, Loss: 3.761e+03, Y0: 2.939, Time: 12.76, Total Time: 624.22, Learning Rate: 1.000e-03
# It: 4800, Loss: 6.791e+03, Y0: 2.945, Time: 12.93, Total Time: 637.15, Learning Rate: 1.000e-03
# It: 4900, Loss: 4.447e+03, Y0: 3.153, Time: 12.59, Total Time: 649.74, Learning Rate: 1.000e-03
# It: 5000, Loss: 2.354e+03, Y0: 3.187, Time: 12.68, Total Time: 662.42, Learning Rate: 1.000e-03
# It: 5100, Loss: 3.580e+03, Y0: 3.342, Time: 12.56, Total Time: 674.98, Learning Rate: 1.000e-03
# It: 5200, Loss: 3.422e+03, Y0: 3.401, Time: 12.58, Total Time: 687.55, Learning Rate: 1.000e-03
# It: 5300, Loss: 2.469e+03, Y0: 3.445, Time: 12.60, Total Time: 700.16, Learning Rate: 1.000e-03
# It: 5400, Loss: 3.522e+03, Y0: 3.497, Time: 12.46, Total Time: 712.62, Learning Rate: 1.000e-03
# It: 5500, Loss: 3.217e+03, Y0: 3.636, Time: 12.15, Total Time: 724.77, Learning Rate: 1.000e-03
# It: 5600, Loss: 4.069e+03, Y0: 3.655, Time: 12.07, Total Time: 736.84, Learning Rate: 1.000e-03
# It: 5700, Loss: 2.237e+03, Y0: 3.654, Time: 12.09, Total Time: 748.93, Learning Rate: 1.000e-03
# It: 5800, Loss: 3.439e+03, Y0: 3.769, Time: 12.18, Total Time: 761.11, Learning Rate: 1.000e-03
# It: 5900, Loss: 2.385e+03, Y0: 3.809, Time: 12.18, Total Time: 773.29, Learning Rate: 1.000e-03
# It: 6000, Loss: 6.239e+03, Y0: 3.875, Time: 12.29, Total Time: 785.58, Learning Rate: 1.000e-03
# It: 6100, Loss: 2.968e+03, Y0: 4.017, Time: 12.04, Total Time: 797.62, Learning Rate: 1.000e-03
# It: 6200, Loss: 4.631e+03, Y0: 3.991, Time: 12.13, Total Time: 809.75, Learning Rate: 1.000e-03
# It: 6300, Loss: 2.937e+03, Y0: 4.060, Time: 12.07, Total Time: 821.81, Learning Rate: 1.000e-03
# It: 6400, Loss: 7.290e+03, Y0: 4.136, Time: 12.08, Total Time: 833.89, Learning Rate: 1.000e-03
# It: 6500, Loss: 2.676e+05, Y0: 3.972, Time: 12.16, Total Time: 846.05, Learning Rate: 1.000e-03
# It: 6600, Loss: 1.204e+04, Y0: 4.116, Time: 12.47, Total Time: 858.51, Learning Rate: 1.000e-03
# It: 6700, Loss: 9.268e+03, Y0: 4.743, Time: 12.52, Total Time: 871.04, Learning Rate: 1.000e-03
# It: 6800, Loss: 8.568e+03, Y0: 4.885, Time: 12.34, Total Time: 883.38, Learning Rate: 1.000e-03
# It: 6900, Loss: 5.208e+03, Y0: 5.111, Time: 12.29, Total Time: 895.66, Learning Rate: 1.000e-03
# It: 7000, Loss: 5.619e+03, Y0: 5.169, Time: 12.19, Total Time: 907.85, Learning Rate: 1.000e-03
# It: 7100, Loss: 2.955e+03, Y0: 5.169, Time: 12.14, Total Time: 920.00, Learning Rate: 1.000e-03
# It: 7200, Loss: 4.017e+03, Y0: 5.314, Time: 12.10, Total Time: 932.09, Learning Rate: 1.000e-03
# It: 7300, Loss: 6.211e+03, Y0: 5.320, Time: 12.29, Total Time: 944.38, Learning Rate: 1.000e-03
# It: 7400, Loss: 3.108e+03, Y0: 5.407, Time: 12.17, Total Time: 956.56, Learning Rate: 1.000e-03
# It: 7500, Loss: 3.511e+03, Y0: 5.468, Time: 12.09, Total Time: 968.65, Learning Rate: 1.000e-03
# It: 7600, Loss: 3.424e+03, Y0: 5.450, Time: 12.15, Total Time: 980.80, Learning Rate: 1.000e-03
# It: 7700, Loss: 2.779e+03, Y0: 5.527, Time: 12.11, Total Time: 992.91, Learning Rate: 1.000e-03
# It: 7800, Loss: 3.302e+03, Y0: 5.511, Time: 12.61, Total Time: 1005.52, Learning Rate: 1.000e-03
# It: 7900, Loss: 2.924e+03, Y0: 5.645, Time: 12.57, Total Time: 1018.09, Learning Rate: 1.000e-03
# It: 8000, Loss: 3.290e+03, Y0: 5.698, Time: 12.62, Total Time: 1030.71, Learning Rate: 1.000e-03
# It: 8100, Loss: 3.256e+03, Y0: 5.780, Time: 12.30, Total Time: 1043.01, Learning Rate: 1.000e-03
# It: 8200, Loss: 2.559e+03, Y0: 5.663, Time: 12.15, Total Time: 1055.16, Learning Rate: 1.000e-03
# It: 8300, Loss: 5.559e+03, Y0: 5.793, Time: 12.31, Total Time: 1067.47, Learning Rate: 1.000e-03
# It: 8400, Loss: 3.205e+03, Y0: 5.690, Time: 12.05, Total Time: 1079.52, Learning Rate: 1.000e-03
# It: 8500, Loss: 8.055e+03, Y0: 5.615, Time: 12.07, Total Time: 1091.59, Learning Rate: 1.000e-03
# It: 8600, Loss: 2.571e+03, Y0: 5.646, Time: 12.25, Total Time: 1103.84, Learning Rate: 1.000e-03
# It: 8700, Loss: 2.205e+03, Y0: 5.604, Time: 12.54, Total Time: 1116.38, Learning Rate: 1.000e-03
# It: 8800, Loss: 4.216e+03, Y0: 5.612, Time: 12.52, Total Time: 1128.90, Learning Rate: 1.000e-03
# It: 8900, Loss: 3.201e+03, Y0: 5.660, Time: 12.05, Total Time: 1140.95, Learning Rate: 1.000e-03
# It: 9000, Loss: 2.875e+03, Y0: 5.717, Time: 12.06, Total Time: 1153.01, Learning Rate: 1.000e-03
# It: 9100, Loss: 2.706e+03, Y0: 5.645, Time: 12.07, Total Time: 1165.07, Learning Rate: 1.000e-03
# It: 9200, Loss: 2.191e+03, Y0: 5.770, Time: 12.03, Total Time: 1177.11, Learning Rate: 1.000e-03
# It: 9300, Loss: 2.952e+03, Y0: 5.835, Time: 12.14, Total Time: 1189.25, Learning Rate: 1.000e-03
# It: 9400, Loss: 4.625e+03, Y0: 5.701, Time: 12.30, Total Time: 1201.55, Learning Rate: 1.000e-03
# It: 9500, Loss: 4.590e+03, Y0: 5.639, Time: 12.05, Total Time: 1213.60, Learning Rate: 1.000e-03
# It: 9600, Loss: 7.324e+03, Y0: 5.571, Time: 12.06, Total Time: 1225.66, Learning Rate: 1.000e-03
# It: 9700, Loss: 3.676e+03, Y0: 5.515, Time: 12.02, Total Time: 1237.68, Learning Rate: 1.000e-03
# It: 9800, Loss: 3.217e+03, Y0: 5.564, Time: 11.97, Total Time: 1249.64, Learning Rate: 1.000e-03
# It: 9900, Loss: 3.756e+03, Y0: 5.582, Time: 12.01, Total Time: 1261.66, Learning Rate: 1.000e-03
# It: 10000, Loss: 4.262e+03, Y0: 5.535, Time: 11.97, Total Time: 1273.63, Learning Rate: 1.000e-03
# It: 10100, Loss: 8.954e+03, Y0: 5.772, Time: 12.05, Total Time: 1285.68, Learning Rate: 1.000e-03
# It: 10200, Loss: 3.331e+03, Y0: 5.613, Time: 12.00, Total Time: 1297.68, Learning Rate: 1.000e-03
# It: 10300, Loss: 3.443e+03, Y0: 5.556, Time: 11.93, Total Time: 1309.61, Learning Rate: 1.000e-03
# It: 10400, Loss: 3.134e+03, Y0: 5.544, Time: 12.05, Total Time: 1321.66, Learning Rate: 1.000e-03
# It: 10500, Loss: 5.804e+05, Y0: 5.501, Time: 12.03, Total Time: 1333.69, Learning Rate: 1.000e-03
# It: 10600, Loss: 4.463e+05, Y0: 4.150, Time: 11.99, Total Time: 1345.68, Learning Rate: 1.000e-03
# It: 10700, Loss: 3.867e+03, Y0: 4.594, Time: 12.06, Total Time: 1357.75, Learning Rate: 1.000e-03
# It: 10800, Loss: 4.827e+03, Y0: 4.579, Time: 12.08, Total Time: 1369.83, Learning Rate: 1.000e-03
# It: 10900, Loss: 3.091e+03, Y0: 4.541, Time: 12.11, Total Time: 1381.94, Learning Rate: 1.000e-03
# It: 11000, Loss: 2.147e+03, Y0: 4.451, Time: 11.93, Total Time: 1393.87, Learning Rate: 1.000e-03
# It: 11100, Loss: 3.165e+03, Y0: 4.341, Time: 11.98, Total Time: 1405.85, Learning Rate: 1.000e-03
# It: 11200, Loss: 3.962e+03, Y0: 4.372, Time: 12.05, Total Time: 1417.90, Learning Rate: 1.000e-03
# It: 11300, Loss: 2.444e+03, Y0: 4.308, Time: 12.24, Total Time: 1430.14, Learning Rate: 1.000e-03
# It: 11400, Loss: 2.473e+03, Y0: 4.301, Time: 12.20, Total Time: 1442.34, Learning Rate: 1.000e-03
# It: 11500, Loss: 3.616e+03, Y0: 4.285, Time: 11.93, Total Time: 1454.27, Learning Rate: 1.000e-03
# It: 11600, Loss: 3.329e+03, Y0: 4.262, Time: 12.02, Total Time: 1466.28, Learning Rate: 1.000e-03
# It: 11700, Loss: 2.946e+03, Y0: 4.242, Time: 12.20, Total Time: 1478.48, Learning Rate: 1.000e-03
# It: 11800, Loss: 2.671e+03, Y0: 4.229, Time: 12.40, Total Time: 1490.89, Learning Rate: 1.000e-03
# It: 11900, Loss: 5.501e+03, Y0: 4.229, Time: 12.38, Total Time: 1503.26, Learning Rate: 1.000e-03
# It: 12000, Loss: 2.527e+03, Y0: 4.256, Time: 12.59, Total Time: 1515.85, Learning Rate: 1.000e-03
# It: 12100, Loss: 2.979e+03, Y0: 4.198, Time: 12.34, Total Time: 1528.19, Learning Rate: 1.000e-03
# It: 12200, Loss: 3.526e+03, Y0: 4.214, Time: 12.23, Total Time: 1540.42, Learning Rate: 1.000e-03
# It: 12300, Loss: 2.624e+03, Y0: 4.215, Time: 12.11, Total Time: 1552.54, Learning Rate: 1.000e-03
# It: 12400, Loss: 2.587e+03, Y0: 4.190, Time: 12.18, Total Time: 1564.71, Learning Rate: 1.000e-03
# It: 12500, Loss: 3.365e+03, Y0: 4.181, Time: 12.28, Total Time: 1576.99, Learning Rate: 1.000e-03
# It: 12600, Loss: 3.537e+03, Y0: 4.074, Time: 12.16, Total Time: 1589.15, Learning Rate: 1.000e-03
# It: 12700, Loss: 3.084e+03, Y0: 4.145, Time: 12.32, Total Time: 1601.47, Learning Rate: 1.000e-03
# It: 12800, Loss: 4.356e+03, Y0: 4.113, Time: 12.17, Total Time: 1613.64, Learning Rate: 1.000e-03
# It: 12900, Loss: 2.821e+03, Y0: 4.187, Time: 12.22, Total Time: 1625.87, Learning Rate: 1.000e-03
# It: 13000, Loss: 3.205e+03, Y0: 4.141, Time: 12.23, Total Time: 1638.10, Learning Rate: 1.000e-03
# It: 13100, Loss: 3.989e+03, Y0: 4.196, Time: 12.17, Total Time: 1650.26, Learning Rate: 1.000e-03
# It: 13200, Loss: 3.263e+03, Y0: 4.235, Time: 12.29, Total Time: 1662.56, Learning Rate: 1.000e-03
# It: 13300, Loss: 2.639e+03, Y0: 4.284, Time: 12.14, Total Time: 1674.69, Learning Rate: 1.000e-03
# It: 13400, Loss: 3.053e+03, Y0: 4.318, Time: 12.22, Total Time: 1686.91, Learning Rate: 1.000e-03
# It: 13500, Loss: 2.302e+03, Y0: 4.260, Time: 12.19, Total Time: 1699.10, Learning Rate: 1.000e-03
# It: 13600, Loss: 2.364e+03, Y0: 4.313, Time: 12.21, Total Time: 1711.31, Learning Rate: 1.000e-03
# It: 13700, Loss: 2.590e+03, Y0: 4.302, Time: 12.27, Total Time: 1723.58, Learning Rate: 1.000e-03
# It: 13800, Loss: 4.486e+03, Y0: 4.400, Time: 12.18, Total Time: 1735.76, Learning Rate: 1.000e-03
# It: 13900, Loss: 2.380e+03, Y0: 4.408, Time: 12.20, Total Time: 1747.96, Learning Rate: 1.000e-03
# It: 14000, Loss: 2.284e+03, Y0: 4.466, Time: 12.21, Total Time: 1760.17, Learning Rate: 1.000e-03
# It: 14100, Loss: 2.178e+03, Y0: 4.510, Time: 12.18, Total Time: 1772.35, Learning Rate: 1.000e-03
# It: 14200, Loss: 2.787e+03, Y0: 4.498, Time: 12.15, Total Time: 1784.49, Learning Rate: 1.000e-03
# It: 14300, Loss: 2.953e+03, Y0: 4.463, Time: 12.32, Total Time: 1796.81, Learning Rate: 1.000e-03
# It: 14400, Loss: 1.970e+03, Y0: 4.606, Time: 12.16, Total Time: 1808.97, Learning Rate: 1.000e-03
# It: 14500, Loss: 2.932e+03, Y0: 4.646, Time: 12.34, Total Time: 1821.31, Learning Rate: 1.000e-03
# It: 14600, Loss: 2.848e+03, Y0: 4.613, Time: 12.27, Total Time: 1833.59, Learning Rate: 1.000e-03
# It: 14700, Loss: 3.792e+03, Y0: 4.570, Time: 12.19, Total Time: 1845.78, Learning Rate: 1.000e-03
# It: 14800, Loss: 3.605e+03, Y0: 4.489, Time: 12.32, Total Time: 1858.10, Learning Rate: 1.000e-03
# It: 14900, Loss: 1.712e+04, Y0: 4.439, Time: 12.15, Total Time: 1870.25, Learning Rate: 1.000e-03
# It: 15000, Loss: 2.879e+03, Y0: 5.335, Time: 12.18, Total Time: 1882.44, Learning Rate: 1.000e-03
# It: 15100, Loss: 2.300e+03, Y0: 5.359, Time: 12.20, Total Time: 1894.63, Learning Rate: 1.000e-03
# It: 15200, Loss: 3.129e+03, Y0: 5.328, Time: 12.18, Total Time: 1906.81, Learning Rate: 1.000e-03
# It: 15300, Loss: 2.368e+03, Y0: 5.327, Time: 12.27, Total Time: 1919.08, Learning Rate: 1.000e-03
# It: 15400, Loss: 2.470e+03, Y0: 5.349, Time: 12.24, Total Time: 1931.32, Learning Rate: 1.000e-03
# It: 15500, Loss: 2.591e+03, Y0: 5.317, Time: 12.24, Total Time: 1943.57, Learning Rate: 1.000e-03
# It: 15600, Loss: 2.539e+03, Y0: 5.286, Time: 12.26, Total Time: 1955.83, Learning Rate: 1.000e-03
# It: 15700, Loss: 2.775e+03, Y0: 5.268, Time: 12.33, Total Time: 1968.15, Learning Rate: 1.000e-03
# It: 15800, Loss: 1.976e+03, Y0: 5.249, Time: 12.45, Total Time: 1980.61, Learning Rate: 1.000e-03
# It: 15900, Loss: 2.858e+03, Y0: 5.230, Time: 12.42, Total Time: 1993.03, Learning Rate: 1.000e-03
# It: 16000, Loss: 2.445e+03, Y0: 5.221, Time: 12.42, Total Time: 2005.45, Learning Rate: 1.000e-03
# It: 16100, Loss: 2.999e+03, Y0: 5.203, Time: 12.43, Total Time: 2017.88, Learning Rate: 1.000e-03
# It: 16200, Loss: 2.511e+03, Y0: 5.206, Time: 12.40, Total Time: 2030.28, Learning Rate: 1.000e-03
# It: 16300, Loss: 2.357e+03, Y0: 5.155, Time: 12.54, Total Time: 2042.82, Learning Rate: 1.000e-03
# It: 16400, Loss: 2.330e+03, Y0: 5.141, Time: 12.46, Total Time: 2055.28, Learning Rate: 1.000e-03
# It: 16500, Loss: 2.090e+03, Y0: 5.132, Time: 12.50, Total Time: 2067.78, Learning Rate: 1.000e-03
# It: 16600, Loss: 2.979e+03, Y0: 5.165, Time: 12.47, Total Time: 2080.26, Learning Rate: 1.000e-03
# It: 16700, Loss: 2.129e+03, Y0: 5.182, Time: 12.41, Total Time: 2092.67, Learning Rate: 1.000e-03
# It: 16800, Loss: 2.232e+03, Y0: 5.157, Time: 12.24, Total Time: 2104.91, Learning Rate: 1.000e-03
# It: 16900, Loss: 3.284e+03, Y0: 5.156, Time: 12.20, Total Time: 2117.10, Learning Rate: 1.000e-03
# It: 17000, Loss: 2.570e+03, Y0: 5.168, Time: 12.31, Total Time: 2129.41, Learning Rate: 1.000e-03
# It: 17100, Loss: 2.483e+03, Y0: 5.183, Time: 12.35, Total Time: 2141.76, Learning Rate: 1.000e-03
# It: 17200, Loss: 1.934e+03, Y0: 5.173, Time: 12.30, Total Time: 2154.06, Learning Rate: 1.000e-03
# It: 17300, Loss: 2.960e+03, Y0: 5.148, Time: 12.36, Total Time: 2166.42, Learning Rate: 1.000e-03
# It: 17400, Loss: 3.297e+03, Y0: 5.175, Time: 12.38, Total Time: 2178.80, Learning Rate: 1.000e-03
# It: 17500, Loss: 2.339e+03, Y0: 5.179, Time: 12.19, Total Time: 2190.99, Learning Rate: 1.000e-03
# It: 17600, Loss: 2.192e+03, Y0: 5.186, Time: 12.38, Total Time: 2203.37, Learning Rate: 1.000e-03
# It: 17700, Loss: 2.688e+03, Y0: 5.185, Time: 12.35, Total Time: 2215.72, Learning Rate: 1.000e-03
# It: 17800, Loss: 2.439e+03, Y0: 5.165, Time: 12.41, Total Time: 2228.13, Learning Rate: 1.000e-03
# It: 17900, Loss: 2.074e+03, Y0: 5.224, Time: 12.32, Total Time: 2240.45, Learning Rate: 1.000e-03
# It: 18000, Loss: 3.893e+04, Y0: 5.247, Time: 12.28, Total Time: 2252.73, Learning Rate: 1.000e-03
# It: 18100, Loss: 3.303e+03, Y0: 5.304, Time: 12.35, Total Time: 2265.08, Learning Rate: 1.000e-03
# It: 18200, Loss: 2.024e+03, Y0: 5.319, Time: 12.46, Total Time: 2277.54, Learning Rate: 1.000e-03
# It: 18300, Loss: 2.717e+03, Y0: 5.252, Time: 12.61, Total Time: 2290.14, Learning Rate: 1.000e-03
# It: 18400, Loss: 2.835e+03, Y0: 5.213, Time: 12.23, Total Time: 2302.37, Learning Rate: 1.000e-03
# It: 18500, Loss: 1.805e+03, Y0: 5.179, Time: 12.19, Total Time: 2314.56, Learning Rate: 1.000e-03
# It: 18600, Loss: 2.188e+03, Y0: 5.126, Time: 12.28, Total Time: 2326.85, Learning Rate: 1.000e-03
# It: 18700, Loss: 3.142e+03, Y0: 5.094, Time: 12.23, Total Time: 2339.07, Learning Rate: 1.000e-03
# It: 18800, Loss: 2.061e+03, Y0: 5.055, Time: 12.34, Total Time: 2351.42, Learning Rate: 1.000e-03
# It: 18900, Loss: 2.926e+03, Y0: 4.998, Time: 12.36, Total Time: 2363.78, Learning Rate: 1.000e-03
# It: 19000, Loss: 2.255e+03, Y0: 4.968, Time: 12.31, Total Time: 2376.08, Learning Rate: 1.000e-03
# It: 19100, Loss: 3.172e+03, Y0: 4.925, Time: 12.40, Total Time: 2388.48, Learning Rate: 1.000e-03
# It: 19200, Loss: 2.530e+03, Y0: 4.931, Time: 12.22, Total Time: 2400.70, Learning Rate: 1.000e-03
# It: 19300, Loss: 2.723e+03, Y0: 4.887, Time: 12.35, Total Time: 2413.05, Learning Rate: 1.000e-03
# It: 19400, Loss: 1.834e+03, Y0: 4.932, Time: 12.26, Total Time: 2425.31, Learning Rate: 1.000e-03
# It: 19500, Loss: 3.361e+03, Y0: 4.916, Time: 12.36, Total Time: 2437.67, Learning Rate: 1.000e-03
# It: 19600, Loss: 2.861e+03, Y0: 4.869, Time: 12.43, Total Time: 2450.10, Learning Rate: 1.000e-03
# It: 19700, Loss: 1.692e+03, Y0: 4.884, Time: 12.27, Total Time: 2462.37, Learning Rate: 1.000e-03
# It: 19800, Loss: 2.983e+03, Y0: 4.831, Time: 12.20, Total Time: 2474.57, Learning Rate: 1.000e-03
# It: 19900, Loss: 2.015e+03, Y0: 4.918, Time: 12.28, Total Time: 2486.85, Learning Rate: 1.000e-03

# %%
np.random.seed(42)
t_test, B_test = model.fetch_minibatch()
W_test, Var_test = model.variance()

X_pred, Y_pred, delta_pred = model.predict(Xi, t_test, W_test, B_test, Var_test)
Y0_test = 4.9550

# %%
plt.figure()
plt.plot(graph[0], graph[1])
plt.xlabel('Iterations')
plt.ylabel('Value')
plt.yscale("log")
plt.title('Evolution of the training loss')
plt.savefig(str(D) + 'train-loss' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(Y0_iter[0], Y0_iter[1], label='Learned $Y_0$')
plt.axhline(Y0_test, color='r', label='Exact $Y_0$')
plt.xlabel('Iterations')
plt.ylabel('Y Initial Value')
#plt.yscale("log")
plt.title('Evolution of the Y Initial')
plt.savefig(str(D) + ' Initial' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(delta_iter[0], delta_iter[1], label='Learned $Delta_T$')
plt.xlabel('Iterations')
plt.ylabel('Delta Value')
#plt.yscale("log")
plt.title('Evolution of the Delta')
plt.savefig(str(D) + 'Delta' + 'RoughBergomiModel')

# %%
tf.experimental.numpy.experimental_enable_numpy_behavior()

# %%
#. Monte Carlo Simulation 
T_mc = 1.0  # terminal time
M_mc = 200000 # number of trajectories
N_mc = 50  # number of time snapshots
D_mc = 1  # number of dimensions
H_mc = 0.07  # Hurst exponent (0,1)
eta_mc = 1.9  # parameter for control volatility
pho_mc = -0.9  # correlation betwen two independent Wiener process
r_mc = 0.05  # interest rate

layers_mc = [D_mc+1] + 4 * [256] + [1+D_mc]

Xi_mc = np.array([np.log(100.0)])[None, :]
model_mc = RoughBergomiModel(Xi_mc, T_mc, M_mc, N_mc, D_mc, H_mc, eta_mc, pho_mc, r_mc, layers_mc)

np.random.seed(42)
t_mc_test, B_mc_test = model_mc.fetch_minibatch()
W_mc_test, Var_mc_test = model_mc.variance()

def MC_simulation(t, W, B, Var, Xi):

    X_list = []

    t0 = t[:, 0, :]
    W0 = W[:, 0, :]
    B0 = B[:, 0, :]
    Var0 = Var[:, 0, :]

    X0 = tf.tile(Xi, [M_mc, 1])  # M x D
    X_list.append(X0)

    for n in range(0, N_mc):
        t1 = t[:, n + 1, :]
        W1 = W[:, n + 1, :]
        B1 = B[:, n + 1, :]
        Var1 = Var[:, n + 1, :]

        BM = pho_mc * (W1 - W0) + np.sqrt(1 - np.square(pho_mc)) * (B1 - B0)
        X1 = X0 - Var0 * 0.5 * (t1 - t0)+ np.sqrt(Var0) * BM

        t0 = t1
        W0 = W1
        B0 = B1
        Var0 = Var1
        X0 = X1
        
        X_list.append(X0)
       
    X = tf.stack(X_list, axis=1)
    return X

X_mc = MC_simulation(t_mc_test, W_mc_test, B_mc_test, Var_mc_test, Xi_mc)
K_mc = np.tile(np.array([90.0], dtype=np.float32)[None, :], [M_mc, 1])
S_T_mc = np.exp(X_mc[:, -1, :] + r_mc * T_mc)
put_option_mc = np.mean(np.maximum(K_mc - S_T_mc, 0.0), axis=0) * np.exp(-r_mc * T_mc)

# %%
Y_pred_mean = np.mean(Y_pred, axis=0)
Y_pred_std = np.std(Y_pred, axis=0)
error = Y_pred_mean[0, 0] - Y0_test
mc_error = Y_pred_mean[0, 0] - put_option_mc
#print('Y0_mean is: {}'.format(Y_pred_mean[0, 0]))
#print('Y0_exact is: {}'.format(Y0_test))
#print('Y0_std is: {}'.format(Y_pred_std[0, 0]))
#print('Relative Error is: {}'.format(error))

# %%
from tabulate import tabulate
Y0_test = np.array(Y0_test)
table = {'reference value': Y0_test, 'MC reference value': put_option_mc,
         'Y0_mean': Y_pred_mean[0, :].tolist(), 'Y0_std': Y_pred_std[0, :].tolist(), 
         'relative error': error, 'MC relative error': mc_error}
print(tabulate(table, headers='keys', tablefmt='github'))
# Out:
# |   reference value |   MC reference value |   Y0_mean |      Y0_std |   relative error |   MC relative error |
# |-------------------|----------------------|-----------|-------------|------------------|---------------------|
# |             4.955 |              4.62474 |    4.9617 | 1.43051e-06 |       0.00670092 |            0.336957 |
