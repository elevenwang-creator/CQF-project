# %%
# basic imports
import os, random
import numpy as np
import datetime as dt
import time
from scipy.fftpack import fft, ifft
from abc import ABC, abstractmethod
import matplotlib.pyplot as plt

# warnings
import warnings

warnings.filterwarnings('ignore')

# tensorflow
import tensorflow as tf

tf.keras.backend.clear_session()

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import Layer, Add

# %%
print(f" TensorFlow version is {tf.__version__}")
#print(f"Keras version is {tf.keras.__version__}")
print(tf.config.list_physical_devices())
# Out:
#  TensorFlow version is 2.15.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class Linear(Layer):
    """Define Linear layers"""

    def __init__(self, in_features, out_features):
        super(Linear, self).__init__()

        self.in_dims = in_features
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'
        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        return tf.matmul(inputs, self.w) + self.b


class StableLinear(Layer):
    """Define Stable Linear layers"""

    def __init__(self, in_features, out_features):
        super(StableLinear, self).__init__()

        self.epsilon = 0.01
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'

        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        w = self.weight_constraint(self.w)
        return tf.matmul(inputs, w) + self.b

    #@tf.function
    def weight_constraint(self, weight):
        delta = 1 - 2 * self.epsilon
        RtR = tf.matmul(tf.transpose(weight), weight)
        norm = tf.norm(RtR)

        #if norm > delta: RtR = delta ** (1 / 2) * RtR / (norm ** (1 / 2))
        RtR_new = tf.sqrt(delta) * RtR / tf.sqrt(norm)
        RtR_update = tf.minimum(RtR_new, RtR)
        #def f2(): return RtR
        #RtR = tf.cond(tf.greater(norm, delta), f1, f2)
        A = RtR_update + tf.eye(RtR.shape[0]) * self.epsilon
        return -A


class NaisNet(Model):
    """ Building NAIS_Net network using keras """

    def __init__(self, layers):
        super(NaisNet, self).__init__()

        self.layer1 = Linear(layers[0], layers[1])

        self.layer2 = StableLinear(layers[1], layers[2])
        self.layer2_input = Linear(layers[0], layers[2])

        self.layer3 = StableLinear(layers[2], layers[3])
        self.layer3_input = Linear(layers[0], layers[3])

        self.layer4 = StableLinear(layers[3], layers[4])
        self.layer4_input = Linear(layers[0], layers[4])

        self.layer5 = Linear(layers[4], layers[5])

    # Building block for the NAIS-Net
    #@tf.function
    def call(self, x):
        """Process stages in the block"""

        u = x

        output = self.layer1(u)  # layer 1
        output = tf.sin(output)

        X1 = output
        output = self.layer2(output)  # layer 2
        output = Add()([self.layer2_input(u), output])
        output = tf.sin(output)
        output = Add()([X1, output])

        X2 = output
        output = self.layer3(output)  # layer 3
        output = Add()([self.layer3_input(u), output])
        output = tf.sin(output)
        output = Add()([X2, output])

        X3 = output
        output = self.layer4(output)  # layer 4
        output = Add()([self.layer4_input(u), output])
        output = tf.sin(output)
        output = Add()([X3, output])

        output = self.layer5(output)  # layer 5

        return output


class FBSNN(ABC):
    """Forward-Backward SDEs using NAIS-Net """

    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):    # , layer_phi

        self.Xi = Xi  # initial point

        self.T = T  # terminal time
        self.M = M  # number of trajectories
        self.N = N  # number of time snapshots
        self.D = D  # number of dimensions
        self.H = H  # Hurst exponent (0,1)
        self.eta = eta  # parameter for control volatility
        self.pho = tf.Variable(pho, dtype=tf.float32) # correlation betwen two independent Wiener process
        self.epsilon_t = 0.09 # forward variance curve epsilon(t) - constant
        self.r = tf.Variable(r, dtype=tf.float32)  # interest rate
           
        # Initialize NN
        self.model = NaisNet(layers)
        #self.model_phi = NaisNet(layer_phi)

        # Record the loss
        self.training_loss = []
        self.iteration = []
        self.Y0_iter = []
        self.Du0_iter = []

    @tf.function
    def net_u(self, t, X):  # M x 1, M x D

        y = self.model(tf.concat([t, X], 1))  # M x [1+D]
        u = tf.expand_dims(y[:, 0], axis=-1)  # M x 1
        #phi = self.model_phi(tf.concat([t, X], 1)) # M x D
        phi = y[:, 1:] # M x D
        Du = tf.gradients(u, X)[0]  # M x D

        return u, phi, Du

    @tf.function
    def Dg_tf(self, X):  # M x D
        return tf.gradients(self.g_tf(X), X)[0]  # M x D

    #@tf.function
    def loss_function(self, t, W, B, Var, Xi):

        loss = 0
        X_list = []
        Y_list = []
        Tilde_Z_list = []
        Z_list = []
        Du_list = []


        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        B0 = B[:, 0, :]
        Var0 = Var[:, 0, :]

        X0 = tf.tile(Xi, [self.M, 1])  # M x D
        Y0, phi0, du0 = self.net_u(t0, X0)  # M x 1, M x D, M x D
        Z0 = self.Z_tf(Var0,du0) # M x D
        Tilde_Z0 = self.Z_tilde_tf(Var0, phi0, du0) # M x D

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)
        Tilde_Z_list.append(Tilde_Z0)
        Du_list.append(du0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]
            B1 = B[:, n + 1, :]
            Var1 = Var[:, n + 1, :]
            BM = self.pho * (W1 - W0) + tf.sqrt(1 - self.pho**2) * (B1 - B0)
            X1 = X0 +self.mu_tf(t0, X0, Y0, du0) * (t1 - t0)  - Var0 * 0.5 * (t1 - t0) + tf.sqrt(Var0) * BM

            Y1_tilde = Y0 + self.F_tf(t0, X0, Y0, Z0, Tilde_Z0) * (t1 - t0) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Z0, tf.expand_dims(B1 - B0, -1))), axis=1, 
                keepdims=True) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Tilde_Z0, tf.expand_dims(W1 - W0, -1))), axis=1, keepdims=True)
            
            Y1, phi1, du1 = self.net_u(t1, X1)
            Z1 = self.Z_tf(Var1,du1) # M x D
            Tilde_Z1 = self.Z_tilde_tf(Var1, phi1, du1) # M x D


            loss += tf.reduce_sum(tf.pow(Y1 - Y1_tilde, 2))

            t0 = t1
            W0 = W1
            B0 = B1
            Var0 = Var1
            du0 = du1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            Tilde_Z0 = Tilde_Z1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)
            Tilde_Z_list.append(Tilde_Z0)
            Du_list.append(du0)
        
        # 0.02 is the penalty parameters for the terminal conditions
        loss +=  tf.reduce_sum(tf.pow(Y1 - self.g_tf(X1), 2))
        loss +=  tf.reduce_sum(tf.pow(du1 - self.Dg_tf(X1), 2))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)
        Tilde_Z = tf.stack(Tilde_Z_list, axis=1)
        Du_t = tf.stack(Du_list, axis=1)
        Y0 = tf.reduce_mean(Y, axis=0)

        return loss, X, Y, Y0[0, 0], Du_t

    def Z_tf(self, Var, Du):  # M x D
        return tf.sqrt((1 - self.pho**2) * Var) * Du

    def Z_tilde_tf(self, Var, phi, Du): # M x D
        return self.pho * tf.sqrt(Var) * Du + phi

    # Volterra process Using hybrid scheme
    def volterra(self):
        T = self.T
        M = self.M
        N = self.N
        D = self.D
        delta_t = T / N
        alpha = self.H - 0.5
        
        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D
        Dt[:, 1:, :] = delta_t
        DW[:, 1:, :] = np.sqrt(delta_t) * np.random.normal(size=(M, N, D))
        
        t_series = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W_process = np.cumsum(DW, axis=1)  # M x (N+1) x D

        sigma = (2*alpha + 1)**0.5
        #kernal function
        def g_kernel(k):
            y = (k**(alpha+1) - (k-1)**(alpha+1)) / (alpha+1)
            b = np.power(y, 1/alpha)
            return np.power((b) * delta_t, alpha)

        #t_series, W_process = self.fetch_minibatch()

        tilde_X = np.zeros((M, N+1, D))
        tilde_X[:, 0 , :]= W_process[:, 0 , :]

        WN_tj_minus_1_1 = np.roll(W_process, shift=-1, axis=1) - W_process

        for m in range(M):
            for d in range(D):
                # first column for toeplitz matrix 
                WN_j = WN_tj_minus_1_1[m, :-1, d]
                sigma_col = np.zeros((N)) 
                sigma_col[0] = np.power(delta_t/2, alpha) * sigma
                # 
                for k in range(1, N):
                    g_b_star_k = g_kernel(k+1)
                    sigma_col[k] = sigma * g_b_star_k

                # FFT and dot
                WN_j_fft = fft(WN_j)
                sigma_fft = fft(sigma_col)
                convolved = ifft(WN_j_fft * sigma_fft) 

                # capture real value 
                tilde_X[m, 1:, d] = np.real(convolved)
        
        return t_series, W_process, tilde_X

    # Variace process
    def variance(self):

        t, W_s, D_hat_w = self.volterra()# M x (N+1) x D

        var = self.epsilon_t * np.exp(self.eta* D_hat_w -  0.5 * self.eta**2 * np.power(t, 2*self.H))

        return W_s, var

    #@tf.function
    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W = np.cumsum(DW, axis=1)  # M x (N+1) x D

        return t, W

    @tf.function
    def train_step(self, optimizers, t, w, b, var, Xi):
        # Optimizers
        optimizer = optimizers

        with tf.GradientTape() as tape:
            loss_value, X_pred, Y_pred, Y0_pred, Du0_pred = self.loss_function(t, w, b, var, Xi)

        grads = tape.gradient(loss_value, self.model.trainable_weights)
        #optimizer.apply(grads, self.model.trainable_weights)
        optimizer.apply_gradients(zip(grads, self.model.trainable_weights))


        return loss_value, Y0_pred, Du0_pred

    #@tf.function
    def train(self, N_Iter, learning_rate):

        loss_temp = np.array([])
        Y0_pred_temp = np.array([])
        Du0_pred_temp = np.array([])

        # Optimizers
        self.optimizer = Adam(learning_rate=learning_rate)

        start_time = time.time()
        ini_time = time.time()

        for it in range(N_Iter):

            t_batch, B_batch = self.fetch_minibatch()  # M x (N+1) x 1, M x (N+1) x D
            W_batch, Var_batch = self.variance() # M x (N+1) x D, M x (N+1) x D
            t_batch = tf.convert_to_tensor(t_batch, dtype=tf.float32)
            B_batch = tf.convert_to_tensor(B_batch, dtype=tf.float32)
            W_batch = tf.convert_to_tensor(W_batch, dtype=tf.float32)
            Var_batch = tf.convert_to_tensor(Var_batch, dtype=tf.float32)
            self.Xi = tf.convert_to_tensor(self.Xi, dtype=tf.float32)

            loss_value, Y0_pred, Du0_pred = self.train_step(self.optimizer, t_batch, W_batch, B_batch, Var_batch, self.Xi)

            if it % 100 == 0:
                elapsed = time.time() - start_time
                total_time = time.time() - ini_time
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Total Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_pred, elapsed, total_time, learning_rate))
                start_time = time.time()

            loss_temp = np.append(loss_temp, loss_value.numpy())
            Y0_pred_temp = np.append(Y0_pred_temp, Y0_pred.numpy())

            Du0 = tf.reduce_mean(Du0_pred, axis=0)
            Du0_pred_temp = np.append(Du0_pred_temp, Du0.numpy()[0, :])

            if it % 100 == 0:
                self.training_loss.append(loss_temp.mean())
                self.Y0_iter.append(Y0_pred_temp[-100:].mean())
                self.Du0_iter.append(Du0_pred_temp[-100:].mean())
                self.iteration.append(it)
  
            graph = np.stack((self.iteration, self.training_loss))
            Y0_iter = np.stack((self.iteration, self.Y0_iter))
            Du0_iter = np.stack((self.iteration, self.Du0_iter))

        return graph,Y0_iter, Du0_iter

    def predict(self, Xi_star, t_star, W_star, B_star, Var_star):
        t_star = tf.convert_to_tensor(t_star, dtype=tf.float32)
        W_star = tf.convert_to_tensor(W_star, dtype=tf.float32)
        Xi_star = tf.convert_to_tensor(Xi_star, dtype=tf.float32)
        B_star = tf.convert_to_tensor(B_star, dtype=tf.float32)
        Var_star = tf.convert_to_tensor(Var_star, dtype=tf.float32)        

        loss, X_star, Y_star, Y0_pred, delta_star = self.loss_function(t_star, W_star, B_star, Var_star, Xi_star)

        return X_star, Y_star, delta_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        pass  # M x1

    @abstractmethod
    def g_tf(self, X):  # M x D
        pass  # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return tf.zeros([M, D])  # M x D
    ###########################################################################

# %%
class RoughBergomiModel(FBSNN):
    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):
        super().__init__(Xi, T, M, N, D, H, eta, pho, r, layers)

    def g_tf(self, X):  # M x D
        K = tf.tile(np.array([90.0], dtype=np.float32)[None, :], [self.M, 1])
        X = tf.reduce_mean(tf.exp(X + self.r * self.T), axis=1, keepdims = True)
        return tf.maximum(K - X, 0) # M x 1  

    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        return super().mu_tf(t, X, Y, Du)  # M x D

    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        return self.r * Y # M x1

    ###########################################################################

# %%
T = 1.0  # terminal time
M = 100  # number of trajectories
N = 50  # number of time snapshots
D = 1  # number of dimensions
H = 0.07  # Hurst exponent (0,1)
eta = 1.9  # parameter for control volatility
pho = -0.9  # correlation betwen two independent Wiener process
r = 0.05  # interest rate

Xi = np.array([np.log(100.0)])[None, :]

layers = [D+1] + 4 * [256] + [1+D]

model = RoughBergomiModel(Xi, T, M, N, D, H, eta, pho, r, layers)
graph, Y0_iter, delta_iter = model.train(2*10**4, 1e-3)
# Out:
# It: 0, Loss: 3.722e+06, Y0: 1.397, Time: 27.87, Total Time: 27.87, Learning Rate: 1.000e-03
# It: 100, Loss: 1.453e+05, Y0: 1.857, Time: 12.37, Total Time: 40.25, Learning Rate: 1.000e-03
# It: 200, Loss: 1.081e+05, Y0: 3.166, Time: 12.21, Total Time: 52.46, Learning Rate: 1.000e-03
# It: 300, Loss: 1.613e+05, Y0: 4.001, Time: 12.28, Total Time: 64.74, Learning Rate: 1.000e-03
# It: 400, Loss: 9.469e+04, Y0: 4.267, Time: 12.20, Total Time: 76.94, Learning Rate: 1.000e-03
# It: 500, Loss: 1.681e+05, Y0: 4.342, Time: 12.26, Total Time: 89.20, Learning Rate: 1.000e-03
# It: 600, Loss: 1.102e+05, Y0: 4.550, Time: 12.35, Total Time: 101.55, Learning Rate: 1.000e-03
# It: 700, Loss: 1.340e+05, Y0: 4.531, Time: 12.27, Total Time: 113.82, Learning Rate: 1.000e-03
# It: 800, Loss: 1.318e+05, Y0: 4.600, Time: 12.28, Total Time: 126.09, Learning Rate: 1.000e-03
# It: 900, Loss: 1.395e+05, Y0: 4.434, Time: 12.22, Total Time: 138.31, Learning Rate: 1.000e-03
# It: 1000, Loss: 1.469e+05, Y0: 4.572, Time: 12.24, Total Time: 150.55, Learning Rate: 1.000e-03
# It: 1100, Loss: 6.370e+04, Y0: 4.617, Time: 12.52, Total Time: 163.07, Learning Rate: 1.000e-03
# It: 1200, Loss: 1.112e+05, Y0: 4.871, Time: 12.35, Total Time: 175.43, Learning Rate: 1.000e-03
# It: 1300, Loss: 1.342e+05, Y0: 4.989, Time: 12.20, Total Time: 187.63, Learning Rate: 1.000e-03
# It: 1400, Loss: 1.622e+05, Y0: 4.884, Time: 12.27, Total Time: 199.90, Learning Rate: 1.000e-03
# It: 1500, Loss: 1.039e+05, Y0: 5.083, Time: 12.26, Total Time: 212.16, Learning Rate: 1.000e-03
# It: 1600, Loss: 1.324e+05, Y0: 4.913, Time: 12.44, Total Time: 224.61, Learning Rate: 1.000e-03
# It: 1700, Loss: 1.412e+05, Y0: 5.074, Time: 12.28, Total Time: 236.88, Learning Rate: 1.000e-03
# It: 1800, Loss: 1.014e+05, Y0: 5.268, Time: 12.25, Total Time: 249.13, Learning Rate: 1.000e-03
# It: 1900, Loss: 1.062e+05, Y0: 5.253, Time: 12.45, Total Time: 261.59, Learning Rate: 1.000e-03
# It: 2000, Loss: 1.292e+05, Y0: 5.395, Time: 12.45, Total Time: 274.03, Learning Rate: 1.000e-03
# It: 2100, Loss: 1.341e+05, Y0: 5.485, Time: 12.39, Total Time: 286.43, Learning Rate: 1.000e-03
# It: 2200, Loss: 1.199e+05, Y0: 5.875, Time: 12.43, Total Time: 298.86, Learning Rate: 1.000e-03
# It: 2300, Loss: 1.601e+05, Y0: 5.597, Time: 12.22, Total Time: 311.08, Learning Rate: 1.000e-03
# It: 2400, Loss: 1.055e+05, Y0: 5.959, Time: 12.39, Total Time: 323.46, Learning Rate: 1.000e-03
# It: 2500, Loss: 1.293e+05, Y0: 6.050, Time: 12.34, Total Time: 335.80, Learning Rate: 1.000e-03
# It: 2600, Loss: 1.422e+05, Y0: 5.955, Time: 12.46, Total Time: 348.26, Learning Rate: 1.000e-03
# It: 2700, Loss: 8.706e+04, Y0: 5.489, Time: 12.36, Total Time: 360.62, Learning Rate: 1.000e-03
# It: 2800, Loss: 8.864e+04, Y0: 5.771, Time: 12.57, Total Time: 373.19, Learning Rate: 1.000e-03
# It: 2900, Loss: 1.620e+05, Y0: 6.181, Time: 12.70, Total Time: 385.89, Learning Rate: 1.000e-03
# It: 3000, Loss: 1.354e+05, Y0: 5.727, Time: 12.55, Total Time: 398.45, Learning Rate: 1.000e-03
# It: 3100, Loss: 9.632e+04, Y0: 5.440, Time: 12.47, Total Time: 410.91, Learning Rate: 1.000e-03
# It: 3200, Loss: 1.648e+05, Y0: 4.896, Time: 12.41, Total Time: 423.33, Learning Rate: 1.000e-03
# It: 3300, Loss: 1.282e+05, Y0: 4.789, Time: 12.29, Total Time: 435.61, Learning Rate: 1.000e-03
# It: 3400, Loss: 1.347e+05, Y0: 4.755, Time: 12.34, Total Time: 447.95, Learning Rate: 1.000e-03
# It: 3500, Loss: 1.131e+05, Y0: 5.006, Time: 12.33, Total Time: 460.28, Learning Rate: 1.000e-03
# It: 3600, Loss: 9.919e+04, Y0: 4.824, Time: 12.51, Total Time: 472.79, Learning Rate: 1.000e-03
# It: 3700, Loss: 1.100e+05, Y0: 4.254, Time: 12.33, Total Time: 485.11, Learning Rate: 1.000e-03
# It: 3800, Loss: 4.404e+06, Y0: 1.806, Time: 12.26, Total Time: 497.37, Learning Rate: 1.000e-03
# It: 3900, Loss: 1.630e+05, Y0: -1.209, Time: 12.39, Total Time: 509.76, Learning Rate: 1.000e-03
# It: 4000, Loss: 1.024e+05, Y0: -0.256, Time: 12.25, Total Time: 522.01, Learning Rate: 1.000e-03
# It: 4100, Loss: 1.521e+05, Y0: 0.765, Time: 12.44, Total Time: 534.45, Learning Rate: 1.000e-03
# It: 4200, Loss: 1.214e+05, Y0: 1.140, Time: 12.22, Total Time: 546.68, Learning Rate: 1.000e-03
# It: 4300, Loss: 1.742e+05, Y0: 0.915, Time: 12.18, Total Time: 558.85, Learning Rate: 1.000e-03
# It: 4400, Loss: 9.471e+04, Y0: 1.514, Time: 12.35, Total Time: 571.20, Learning Rate: 1.000e-03
# It: 4500, Loss: 6.847e+04, Y0: 2.144, Time: 12.41, Total Time: 583.61, Learning Rate: 1.000e-03
# It: 4600, Loss: 1.194e+05, Y0: 2.271, Time: 12.46, Total Time: 596.07, Learning Rate: 1.000e-03
# It: 4700, Loss: 8.932e+04, Y0: 1.896, Time: 12.35, Total Time: 608.41, Learning Rate: 1.000e-03
# It: 4800, Loss: 8.439e+04, Y0: 2.002, Time: 12.23, Total Time: 620.64, Learning Rate: 1.000e-03
# It: 4900, Loss: 8.902e+04, Y0: 1.948, Time: 12.47, Total Time: 633.12, Learning Rate: 1.000e-03
# It: 5000, Loss: 1.119e+05, Y0: 2.512, Time: 12.38, Total Time: 645.50, Learning Rate: 1.000e-03
# It: 5100, Loss: 7.529e+04, Y0: 2.755, Time: 12.44, Total Time: 657.94, Learning Rate: 1.000e-03
# It: 5200, Loss: 7.918e+04, Y0: 3.103, Time: 12.42, Total Time: 670.36, Learning Rate: 1.000e-03
# It: 5300, Loss: 6.018e+04, Y0: 3.373, Time: 12.41, Total Time: 682.77, Learning Rate: 1.000e-03
# It: 5400, Loss: 9.545e+04, Y0: 3.402, Time: 12.52, Total Time: 695.30, Learning Rate: 1.000e-03
# It: 5500, Loss: 7.389e+04, Y0: 3.839, Time: 12.48, Total Time: 707.78, Learning Rate: 1.000e-03
# It: 5600, Loss: 8.535e+04, Y0: 4.031, Time: 12.33, Total Time: 720.11, Learning Rate: 1.000e-03
# It: 5700, Loss: 7.893e+04, Y0: 4.062, Time: 12.55, Total Time: 732.66, Learning Rate: 1.000e-03
# It: 5800, Loss: 1.028e+05, Y0: 4.515, Time: 12.42, Total Time: 745.08, Learning Rate: 1.000e-03
# It: 5900, Loss: 5.751e+04, Y0: 4.398, Time: 12.35, Total Time: 757.42, Learning Rate: 1.000e-03
# It: 6000, Loss: 5.222e+04, Y0: 4.303, Time: 12.26, Total Time: 769.69, Learning Rate: 1.000e-03
# It: 6100, Loss: 1.150e+05, Y0: 4.466, Time: 12.15, Total Time: 781.84, Learning Rate: 1.000e-03
# It: 6200, Loss: 7.519e+04, Y0: 4.548, Time: 12.31, Total Time: 794.15, Learning Rate: 1.000e-03
# It: 6300, Loss: 5.993e+04, Y0: 5.061, Time: 12.14, Total Time: 806.29, Learning Rate: 1.000e-03
# It: 6400, Loss: 5.361e+04, Y0: 4.703, Time: 12.32, Total Time: 818.61, Learning Rate: 1.000e-03
# It: 6500, Loss: 4.651e+04, Y0: 5.165, Time: 12.24, Total Time: 830.85, Learning Rate: 1.000e-03
# It: 6600, Loss: 7.697e+04, Y0: 4.967, Time: 12.20, Total Time: 843.06, Learning Rate: 1.000e-03
# It: 6700, Loss: 8.929e+04, Y0: 4.914, Time: 12.22, Total Time: 855.28, Learning Rate: 1.000e-03
# It: 6800, Loss: 6.550e+04, Y0: 5.017, Time: 12.14, Total Time: 867.43, Learning Rate: 1.000e-03
# It: 6900, Loss: 8.248e+04, Y0: 5.135, Time: 12.24, Total Time: 879.67, Learning Rate: 1.000e-03
# It: 7000, Loss: 5.269e+04, Y0: 5.507, Time: 12.21, Total Time: 891.88, Learning Rate: 1.000e-03
# It: 7100, Loss: 9.447e+04, Y0: 5.100, Time: 12.21, Total Time: 904.09, Learning Rate: 1.000e-03
# It: 7200, Loss: 1.029e+05, Y0: 5.371, Time: 12.39, Total Time: 916.48, Learning Rate: 1.000e-03
# It: 7300, Loss: 4.268e+04, Y0: 5.510, Time: 12.32, Total Time: 928.80, Learning Rate: 1.000e-03
# It: 7400, Loss: 7.662e+04, Y0: 5.674, Time: 12.62, Total Time: 941.42, Learning Rate: 1.000e-03
# It: 7500, Loss: 5.939e+04, Y0: 5.783, Time: 12.68, Total Time: 954.11, Learning Rate: 1.000e-03
# It: 7600, Loss: 4.558e+04, Y0: 5.638, Time: 12.36, Total Time: 966.46, Learning Rate: 1.000e-03
# It: 7700, Loss: 5.837e+04, Y0: 5.546, Time: 12.60, Total Time: 979.07, Learning Rate: 1.000e-03
# It: 7800, Loss: 7.436e+04, Y0: 5.157, Time: 12.43, Total Time: 991.50, Learning Rate: 1.000e-03
# It: 7900, Loss: 9.311e+04, Y0: 6.129, Time: 12.72, Total Time: 1004.22, Learning Rate: 1.000e-03
# It: 8000, Loss: 8.514e+04, Y0: 5.605, Time: 12.42, Total Time: 1016.64, Learning Rate: 1.000e-03
# It: 8100, Loss: 5.896e+04, Y0: 5.244, Time: 12.48, Total Time: 1029.12, Learning Rate: 1.000e-03
# It: 8200, Loss: 6.761e+04, Y0: 5.146, Time: 12.67, Total Time: 1041.79, Learning Rate: 1.000e-03
# It: 8300, Loss: 5.532e+04, Y0: 5.326, Time: 12.59, Total Time: 1054.38, Learning Rate: 1.000e-03
# It: 8400, Loss: 3.804e+04, Y0: 5.425, Time: 12.49, Total Time: 1066.87, Learning Rate: 1.000e-03
# It: 8500, Loss: 7.334e+04, Y0: 5.560, Time: 12.19, Total Time: 1079.06, Learning Rate: 1.000e-03
# It: 8600, Loss: 4.477e+04, Y0: 5.593, Time: 12.21, Total Time: 1091.27, Learning Rate: 1.000e-03
# It: 8700, Loss: 3.282e+04, Y0: 5.581, Time: 12.32, Total Time: 1103.58, Learning Rate: 1.000e-03
# It: 8800, Loss: 9.501e+04, Y0: 5.486, Time: 12.24, Total Time: 1115.82, Learning Rate: 1.000e-03
# It: 8900, Loss: 9.110e+04, Y0: 5.244, Time: 12.32, Total Time: 1128.14, Learning Rate: 1.000e-03
# It: 9000, Loss: 6.151e+04, Y0: 5.407, Time: 12.21, Total Time: 1140.35, Learning Rate: 1.000e-03
# It: 9100, Loss: 4.083e+04, Y0: 5.258, Time: 12.22, Total Time: 1152.58, Learning Rate: 1.000e-03
# It: 9200, Loss: 1.244e+05, Y0: 5.051, Time: 12.34, Total Time: 1164.92, Learning Rate: 1.000e-03
# It: 9300, Loss: 6.690e+04, Y0: 5.811, Time: 12.14, Total Time: 1177.06, Learning Rate: 1.000e-03
# It: 9400, Loss: 3.449e+04, Y0: 5.885, Time: 12.23, Total Time: 1189.29, Learning Rate: 1.000e-03
# It: 9500, Loss: 3.932e+04, Y0: 5.313, Time: 12.26, Total Time: 1201.55, Learning Rate: 1.000e-03
# It: 9600, Loss: 3.062e+04, Y0: 5.447, Time: 12.24, Total Time: 1213.79, Learning Rate: 1.000e-03
# It: 9700, Loss: 4.301e+04, Y0: 6.204, Time: 12.41, Total Time: 1226.20, Learning Rate: 1.000e-03
# It: 9800, Loss: 4.410e+04, Y0: 6.342, Time: 12.27, Total Time: 1238.47, Learning Rate: 1.000e-03
# It: 9900, Loss: 3.070e+04, Y0: 5.923, Time: 12.33, Total Time: 1250.80, Learning Rate: 1.000e-03
# It: 10000, Loss: 4.994e+04, Y0: 5.603, Time: 12.35, Total Time: 1263.15, Learning Rate: 1.000e-03
# It: 10100, Loss: 4.687e+04, Y0: 5.832, Time: 12.21, Total Time: 1275.36, Learning Rate: 1.000e-03
# It: 10200, Loss: 7.584e+04, Y0: 5.991, Time: 12.33, Total Time: 1287.69, Learning Rate: 1.000e-03
# It: 10300, Loss: 6.036e+04, Y0: 5.895, Time: 12.21, Total Time: 1299.90, Learning Rate: 1.000e-03
# It: 10400, Loss: 5.172e+04, Y0: 6.375, Time: 12.40, Total Time: 1312.30, Learning Rate: 1.000e-03
# It: 10500, Loss: 4.881e+04, Y0: 5.859, Time: 12.36, Total Time: 1324.66, Learning Rate: 1.000e-03
# It: 10600, Loss: 6.265e+04, Y0: 5.417, Time: 12.23, Total Time: 1336.89, Learning Rate: 1.000e-03
# It: 10700, Loss: 2.335e+04, Y0: 5.429, Time: 12.41, Total Time: 1349.29, Learning Rate: 1.000e-03
# It: 10800, Loss: 3.202e+04, Y0: 5.800, Time: 12.36, Total Time: 1361.65, Learning Rate: 1.000e-03
# It: 10900, Loss: 4.601e+04, Y0: 6.306, Time: 12.33, Total Time: 1373.99, Learning Rate: 1.000e-03
# It: 11000, Loss: 4.495e+04, Y0: 5.885, Time: 12.39, Total Time: 1386.38, Learning Rate: 1.000e-03
# It: 11100, Loss: 1.963e+04, Y0: 5.832, Time: 12.24, Total Time: 1398.62, Learning Rate: 1.000e-03
# It: 11200, Loss: 3.974e+04, Y0: 6.038, Time: 12.25, Total Time: 1410.87, Learning Rate: 1.000e-03
# It: 11300, Loss: 3.967e+04, Y0: 5.361, Time: 12.26, Total Time: 1423.13, Learning Rate: 1.000e-03
# It: 11400, Loss: 1.376e+05, Y0: 5.242, Time: 12.20, Total Time: 1435.32, Learning Rate: 1.000e-03
# It: 11500, Loss: 4.981e+04, Y0: 6.320, Time: 12.29, Total Time: 1447.61, Learning Rate: 1.000e-03
# It: 11600, Loss: 4.912e+04, Y0: 6.305, Time: 12.20, Total Time: 1459.81, Learning Rate: 1.000e-03
# It: 11700, Loss: 3.687e+04, Y0: 6.164, Time: 12.31, Total Time: 1472.12, Learning Rate: 1.000e-03
# It: 11800, Loss: 1.058e+05, Y0: 5.854, Time: 12.29, Total Time: 1484.41, Learning Rate: 1.000e-03
# It: 11900, Loss: 1.105e+05, Y0: 5.388, Time: 12.20, Total Time: 1496.62, Learning Rate: 1.000e-03
# It: 12000, Loss: 7.138e+04, Y0: 6.274, Time: 12.36, Total Time: 1508.97, Learning Rate: 1.000e-03
# It: 12100, Loss: 5.624e+04, Y0: 5.962, Time: 12.20, Total Time: 1521.17, Learning Rate: 1.000e-03
# It: 12200, Loss: 5.713e+04, Y0: 5.930, Time: 12.43, Total Time: 1533.60, Learning Rate: 1.000e-03
# It: 12300, Loss: 4.515e+04, Y0: 5.962, Time: 12.45, Total Time: 1546.05, Learning Rate: 1.000e-03
# It: 12400, Loss: 2.514e+04, Y0: 5.847, Time: 12.25, Total Time: 1558.30, Learning Rate: 1.000e-03
# It: 12500, Loss: 5.213e+04, Y0: 5.827, Time: 12.32, Total Time: 1570.62, Learning Rate: 1.000e-03
# It: 12600, Loss: 2.356e+04, Y0: 6.213, Time: 12.27, Total Time: 1582.89, Learning Rate: 1.000e-03
# It: 12700, Loss: 2.993e+04, Y0: 6.265, Time: 12.22, Total Time: 1595.11, Learning Rate: 1.000e-03
# It: 12800, Loss: 6.301e+04, Y0: 5.421, Time: 12.40, Total Time: 1607.50, Learning Rate: 1.000e-03
# It: 12900, Loss: 6.144e+04, Y0: 5.353, Time: 12.24, Total Time: 1619.74, Learning Rate: 1.000e-03
# It: 13000, Loss: 1.680e+04, Y0: 5.303, Time: 12.34, Total Time: 1632.08, Learning Rate: 1.000e-03
# It: 13100, Loss: 6.081e+04, Y0: 5.505, Time: 12.32, Total Time: 1644.40, Learning Rate: 1.000e-03
# It: 13200, Loss: 4.120e+04, Y0: 5.466, Time: 12.22, Total Time: 1656.62, Learning Rate: 1.000e-03
# It: 13300, Loss: 5.038e+04, Y0: 4.720, Time: 12.35, Total Time: 1668.98, Learning Rate: 1.000e-03
# It: 13400, Loss: 3.169e+04, Y0: 4.997, Time: 12.22, Total Time: 1681.20, Learning Rate: 1.000e-03
# It: 13500, Loss: 7.880e+04, Y0: 4.681, Time: 12.34, Total Time: 1693.54, Learning Rate: 1.000e-03
# It: 13600, Loss: 3.254e+04, Y0: 5.006, Time: 12.28, Total Time: 1705.81, Learning Rate: 1.000e-03
# It: 13700, Loss: 7.206e+04, Y0: 5.274, Time: 12.30, Total Time: 1718.11, Learning Rate: 1.000e-03
# It: 13800, Loss: 5.072e+04, Y0: 5.491, Time: 12.36, Total Time: 1730.47, Learning Rate: 1.000e-03
# It: 13900, Loss: 6.872e+04, Y0: 5.058, Time: 12.30, Total Time: 1742.77, Learning Rate: 1.000e-03
# It: 14000, Loss: 5.619e+04, Y0: 4.809, Time: 12.52, Total Time: 1755.29, Learning Rate: 1.000e-03
# It: 14100, Loss: 5.630e+04, Y0: 4.461, Time: 12.41, Total Time: 1767.70, Learning Rate: 1.000e-03
# It: 14200, Loss: 1.039e+05, Y0: 4.870, Time: 12.51, Total Time: 1780.21, Learning Rate: 1.000e-03
# It: 14300, Loss: 4.015e+04, Y0: 4.921, Time: 12.55, Total Time: 1792.76, Learning Rate: 1.000e-03
# It: 14400, Loss: 5.315e+04, Y0: 5.062, Time: 12.41, Total Time: 1805.17, Learning Rate: 1.000e-03
# It: 14500, Loss: 3.340e+04, Y0: 4.968, Time: 12.49, Total Time: 1817.66, Learning Rate: 1.000e-03
# It: 14600, Loss: 3.802e+04, Y0: 4.743, Time: 12.37, Total Time: 1830.03, Learning Rate: 1.000e-03
# It: 14700, Loss: 3.654e+04, Y0: 4.862, Time: 12.47, Total Time: 1842.50, Learning Rate: 1.000e-03
# It: 14800, Loss: 3.520e+04, Y0: 4.847, Time: 12.47, Total Time: 1854.97, Learning Rate: 1.000e-03
# It: 14900, Loss: 5.977e+04, Y0: 4.796, Time: 12.23, Total Time: 1867.21, Learning Rate: 1.000e-03
# It: 15000, Loss: 3.702e+04, Y0: 5.272, Time: 12.33, Total Time: 1879.54, Learning Rate: 1.000e-03
# It: 15100, Loss: 6.245e+04, Y0: 5.202, Time: 12.28, Total Time: 1891.82, Learning Rate: 1.000e-03
# It: 15200, Loss: 6.184e+04, Y0: 5.508, Time: 12.34, Total Time: 1904.16, Learning Rate: 1.000e-03
# It: 15300, Loss: 2.848e+04, Y0: 5.383, Time: 12.34, Total Time: 1916.50, Learning Rate: 1.000e-03
# It: 15400, Loss: 2.600e+04, Y0: 5.333, Time: 12.27, Total Time: 1928.77, Learning Rate: 1.000e-03
# It: 15500, Loss: 3.425e+04, Y0: 5.070, Time: 12.26, Total Time: 1941.03, Learning Rate: 1.000e-03
# It: 15600, Loss: 3.073e+04, Y0: 5.217, Time: 12.37, Total Time: 1953.40, Learning Rate: 1.000e-03
# It: 15700, Loss: 5.052e+04, Y0: 5.049, Time: 12.26, Total Time: 1965.66, Learning Rate: 1.000e-03
# It: 15800, Loss: 5.625e+04, Y0: 4.838, Time: 12.35, Total Time: 1978.01, Learning Rate: 1.000e-03
# It: 15900, Loss: 4.104e+04, Y0: 4.954, Time: 12.22, Total Time: 1990.23, Learning Rate: 1.000e-03
# It: 16000, Loss: 3.063e+04, Y0: 5.316, Time: 12.28, Total Time: 2002.51, Learning Rate: 1.000e-03
# It: 16100, Loss: 1.946e+04, Y0: 5.840, Time: 12.37, Total Time: 2014.88, Learning Rate: 1.000e-03
# It: 16200, Loss: 8.098e+04, Y0: 4.872, Time: 12.26, Total Time: 2027.14, Learning Rate: 1.000e-03
# It: 16300, Loss: 8.058e+04, Y0: 5.060, Time: 12.37, Total Time: 2039.52, Learning Rate: 1.000e-03
# It: 16400, Loss: 4.118e+04, Y0: 4.776, Time: 12.26, Total Time: 2051.78, Learning Rate: 1.000e-03
# It: 16500, Loss: 3.378e+04, Y0: 5.413, Time: 12.30, Total Time: 2064.08, Learning Rate: 1.000e-03
# It: 16600, Loss: 2.466e+04, Y0: 5.280, Time: 12.32, Total Time: 2076.40, Learning Rate: 1.000e-03
# It: 16700, Loss: 4.014e+04, Y0: 5.318, Time: 12.31, Total Time: 2088.72, Learning Rate: 1.000e-03
# It: 16800, Loss: 7.040e+04, Y0: 4.930, Time: 12.40, Total Time: 2101.12, Learning Rate: 1.000e-03
# It: 16900, Loss: 4.673e+04, Y0: 5.097, Time: 12.24, Total Time: 2113.36, Learning Rate: 1.000e-03
# It: 17000, Loss: 3.397e+04, Y0: 4.940, Time: 12.28, Total Time: 2125.64, Learning Rate: 1.000e-03
# It: 17100, Loss: 6.018e+04, Y0: 4.205, Time: 12.35, Total Time: 2137.99, Learning Rate: 1.000e-03
# It: 17200, Loss: 4.299e+04, Y0: 4.565, Time: 12.35, Total Time: 2150.34, Learning Rate: 1.000e-03
# It: 17300, Loss: 2.738e+04, Y0: 5.124, Time: 12.62, Total Time: 2162.96, Learning Rate: 1.000e-03
# It: 17400, Loss: 2.397e+04, Y0: 4.706, Time: 12.48, Total Time: 2175.44, Learning Rate: 1.000e-03
# It: 17500, Loss: 2.408e+04, Y0: 4.597, Time: 12.56, Total Time: 2188.00, Learning Rate: 1.000e-03
# It: 17600, Loss: 2.735e+04, Y0: 5.225, Time: 12.52, Total Time: 2200.52, Learning Rate: 1.000e-03
# It: 17700, Loss: 3.336e+04, Y0: 5.153, Time: 12.51, Total Time: 2213.04, Learning Rate: 1.000e-03
# It: 17800, Loss: 5.088e+04, Y0: 5.347, Time: 12.57, Total Time: 2225.60, Learning Rate: 1.000e-03
# It: 17900, Loss: 7.199e+04, Y0: 5.383, Time: 12.42, Total Time: 2238.02, Learning Rate: 1.000e-03
# It: 18000, Loss: 4.517e+04, Y0: 5.900, Time: 12.48, Total Time: 2250.50, Learning Rate: 1.000e-03
# It: 18100, Loss: 5.015e+04, Y0: 4.977, Time: 12.63, Total Time: 2263.14, Learning Rate: 1.000e-03
# It: 18200, Loss: 2.837e+04, Y0: 5.537, Time: 12.45, Total Time: 2275.59, Learning Rate: 1.000e-03
# It: 18300, Loss: 3.030e+04, Y0: 5.302, Time: 12.56, Total Time: 2288.15, Learning Rate: 1.000e-03
# It: 18400, Loss: 3.627e+04, Y0: 5.054, Time: 12.42, Total Time: 2300.57, Learning Rate: 1.000e-03
# It: 18500, Loss: 2.914e+04, Y0: 5.286, Time: 12.38, Total Time: 2312.95, Learning Rate: 1.000e-03
# It: 18600, Loss: 5.369e+04, Y0: 5.572, Time: 12.51, Total Time: 2325.46, Learning Rate: 1.000e-03
# It: 18700, Loss: 5.594e+04, Y0: 5.668, Time: 12.43, Total Time: 2337.89, Learning Rate: 1.000e-03
# It: 18800, Loss: 3.460e+04, Y0: 5.854, Time: 12.38, Total Time: 2350.27, Learning Rate: 1.000e-03
# It: 18900, Loss: 6.898e+04, Y0: 6.107, Time: 12.33, Total Time: 2362.60, Learning Rate: 1.000e-03
# It: 19000, Loss: 2.804e+04, Y0: 6.332, Time: 12.37, Total Time: 2374.97, Learning Rate: 1.000e-03
# It: 19100, Loss: 3.099e+04, Y0: 5.603, Time: 12.48, Total Time: 2387.46, Learning Rate: 1.000e-03
# It: 19200, Loss: 3.440e+04, Y0: 5.948, Time: 12.33, Total Time: 2399.79, Learning Rate: 1.000e-03
# It: 19300, Loss: 6.695e+04, Y0: 5.589, Time: 12.33, Total Time: 2412.12, Learning Rate: 1.000e-03
# It: 19400, Loss: 5.915e+04, Y0: 6.038, Time: 12.29, Total Time: 2424.41, Learning Rate: 1.000e-03
# It: 19500, Loss: 7.882e+04, Y0: 6.156, Time: 12.28, Total Time: 2436.69, Learning Rate: 1.000e-03
# It: 19600, Loss: 3.702e+04, Y0: 5.569, Time: 12.41, Total Time: 2449.10, Learning Rate: 1.000e-03
# It: 19700, Loss: 4.634e+04, Y0: 5.741, Time: 12.44, Total Time: 2461.54, Learning Rate: 1.000e-03
# It: 19800, Loss: 3.467e+04, Y0: 5.746, Time: 12.59, Total Time: 2474.13, Learning Rate: 1.000e-03
# It: 19900, Loss: 6.067e+04, Y0: 5.809, Time: 12.30, Total Time: 2486.44, Learning Rate: 1.000e-03

# %%
np.random.seed(42)
t_test, B_test = model.fetch_minibatch()
W_test, Var_test = model.variance()

X_pred, Y_pred, delta_pred = model.predict(Xi, t_test, W_test, B_test, Var_test)
Y0_test = 4.9550

# %%
plt.figure()
plt.plot(graph[0], graph[1])
plt.xlabel('Iterations')
plt.ylabel('Value')
plt.yscale("log")
plt.title('Evolution of the training loss')
plt.savefig(str(D) + 'train-loss' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(Y0_iter[0], Y0_iter[1], label='Learned $Y_0$')
plt.axhline(Y0_test, color='r', label='Exact $Y_0$')
plt.xlabel('Iterations')
plt.ylabel('Y Initial Value')
#plt.yscale("log")
plt.title('Evolution of the Y Initial')
plt.savefig(str(D) + ' Initial' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(delta_iter[0], delta_iter[1], label='Learned $Delta_T$')
plt.xlabel('Iterations')
plt.ylabel('Delta Value')
#plt.yscale("log")
plt.title('Evolution of the Delta')
plt.savefig(str(D) + 'Delta' + 'RoughBergomiModel')

# %%
Y_pred_mean = np.mean(Y_pred, axis=0)
Y_pred_std = np.std(Y_pred, axis=0)
error = Y_pred_mean[0, 0] - Y0_test
print('Y0_mean is: {}'.format(Y_pred_mean[0, 0]))
print('Y0_exact is: {}'.format(Y0_test))
print('Y0_std is: {}'.format(Y_pred_std[0, 0]))
print('Relative Error is: {}'.format(error))
# Out:
# Y0_mean is: 5.716024398803711
# Y0_exact is: 4.955
# Y0_std is: 2.86102294921875e-06
# Relative Error is: 0.7610243988037109
