# %%
# basic imports
import os, random
import numpy as np
import datetime as dt
import time
from scipy.fftpack import fft, ifft
from abc import ABC, abstractmethod
import matplotlib.pyplot as plt

# warnings
import warnings

warnings.filterwarnings('ignore')

# tensorflow
import tensorflow as tf

tf.keras.backend.clear_session()

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam, AdamW, RMSprop
from tensorflow.keras.layers import Layer, Add

# %%
print(f" TensorFlow version is {tf.__version__}")
#print(f"Keras version is {tf.keras.__version__}")
print(tf.config.list_physical_devices())
# Out:
#  TensorFlow version is 2.15.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:TPU_SYSTEM:0', device_type='TPU_SYSTEM'), PhysicalDevice(name='/physical_device:TPU:0', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:1', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:2', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:3', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:4', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:5', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:6', device_type='TPU'), PhysicalDevice(name='/physical_device:TPU:7', device_type='TPU')]

# %%
class Linear(Layer):
    """Define Linear layers"""

    def __init__(self, in_features, out_features):
        super(Linear, self).__init__()

        self.in_dims = in_features
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'
        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        return tf.matmul(inputs, self.w) + self.b


class StableLinear(Layer):
    """Define Stable Linear layers"""

    def __init__(self, in_features, out_features):
        super(StableLinear, self).__init__()

        self.epsilon = 0.01
        self.w = self.add_weight(
            shape=(in_features, out_features),
            initializer='glorot_uniform',
            trainable=True
        )  # weights_initializer='glorot normal'

        self.b = self.add_weight(
            shape=(out_features,), initializer='zeros', trainable=True
        )  # bias_initializer='zeros'

    #@tf.function
    def call(self, inputs):
        w = self.weight_constraint(self.w)
        return tf.matmul(inputs, w) + self.b

    #@tf.function
    def weight_constraint(self, weight):
        delta = 1 - 2 * self.epsilon
        RtR = tf.matmul(tf.transpose(weight), weight)
        norm = tf.norm(RtR)

        #if norm > delta: RtR = delta ** (1 / 2) * RtR / (norm ** (1 / 2))
        RtR_new = tf.sqrt(delta) * RtR / tf.sqrt(norm)
        RtR_update = tf.minimum(RtR_new, RtR)
        #def f2(): return RtR
        #RtR = tf.cond(tf.greater(norm, delta), f1, f2)
        A = RtR_update + tf.eye(RtR.shape[0]) * self.epsilon
        return -A


class NaisNet(Model):
    """ Building NAIS_Net network using keras """

    def __init__(self, layers):
        super(NaisNet, self).__init__()

        self.layer1 = Linear(layers[0], layers[1])

        self.layer2 = StableLinear(layers[1], layers[2])
        self.layer2_input = Linear(layers[0], layers[2])

        self.layer3 = StableLinear(layers[2], layers[3])
        self.layer3_input = Linear(layers[0], layers[3])

        self.layer4 = StableLinear(layers[3], layers[4])
        self.layer4_input = Linear(layers[0], layers[4])

        self.layer5 = Linear(layers[4], layers[5])

    # Building block for the NAIS-Net
    #@tf.function
    def call(self, x):
        """Process stages in the block"""

        u = x

        output = self.layer1(u)  # layer 1
        output = tf.sin(output)

        X1 = output
        output = self.layer2(output)  # layer 2
        output = Add()([self.layer2_input(u), output])
        output = tf.sin(output)
        output = Add()([X1, output])

        X2 = output
        output = self.layer3(output)  # layer 3
        output = Add()([self.layer3_input(u), output])
        output = tf.sin(output)
        output = Add()([X2, output])

        X3 = output
        output = self.layer4(output)  # layer 4
        output = Add()([self.layer4_input(u), output])
        output = tf.sin(output)
        output = Add()([X3, output])

        output = self.layer5(output)  # layer 5

        return output


class FBSNN(ABC):
    """Forward-Backward SDEs using NAIS-Net """

    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):    # , layer_phi

        self.Xi = Xi  # initial point

        self.T = T  # terminal time
        self.M = M  # number of trajectories
        self.N = N  # number of time snapshots
        self.D = D  # number of dimensions
        self.H = H  # Hurst exponent (0,1)
        self.eta = eta  # parameter for control volatility
        self.pho = tf.cast(pho, dtype=tf.float32) # correlation betwen two independent Wiener process
        self.epsilon_t = 0.09 # forward variance curve epsilon(t) - constant
        self.r = tf.cast(r, dtype=tf.float32)  # interest rate

        # Initialize NN
        self.phi_input_shape = tf.cast(layers[0], dtype=tf.int32)
        self.phi_output_shape= tf.cast(self.D, dtype=tf.int32)
        self.phi_weight, self.phi_bias = self.init_wb([self.phi_input_shape, self.phi_output_shape])
        self.model = NaisNet(layers)
        #self.model_phi = NaisNet(layer_phi)

        # Record the loss
        self.training_loss = []
        self.iteration = []
        self.Y0_iter = []
        self.Du0_iter = []

    def init_wb(self,size):
        xavier_stddev = tf.cast(tf.sqrt(tf.divide(2, tf.add(size[0], size[1]))),dtype=tf.float32)
        weight = tf.Variable(tf.random.truncated_normal([self.phi_input_shape, self.phi_output_shape],
                                               stddev=xavier_stddev), trainable=True, dtype=tf.float32)
        #weitht = self.xavier_init([self.phi_input_shape, self.phi_output_shape])
        bias = tf.Variable(tf.zeros([1, self.phi_output_shape]), dtype=tf.float32)
        return  weight, bias

    def phi_tf(self,inputs):
        return tf.matmul(inputs, self.phi_weight) + self.phi_bias

    @tf.function
    def net_u(self, t, X):  # M x 1, M x D

        u = self.model(tf.concat([t, X], 1))  # M x [1+D]
        #u = tf.expand_dims(y[:, 0], axis=-1)  # M x 1
        #phi = self.model_phi(tf.concat([t, X], 1)) # M x D
        phi = self.phi_tf(tf.concat([t,X], 1))
        #phi = y[:, 1:] # M x D
        Du = tf.gradients(u, X)[0]  # M x D

        return u, phi, Du

    @tf.function
    def Dg_tf(self, X):  # M x D
        return tf.gradients(self.g_tf(X), X)[0]  # M x D

    #@tf.function
    def loss_function(self, t, W, B, Var, Xi):

        loss = 0
        X_list = []
        Y_list = []
        Tilde_Z_list = []
        Z_list = []
        Du_list = []


        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        B0 = B[:, 0, :]
        Var0 = Var[:, 0, :]

        X0 = tf.tile(Xi, [self.M, 1])  # M x D
        Y0, phi0, du0 = self.net_u(t0, X0)  # M x 1, M x D, M x D
        Z0 = self.Z_tf(Var0,du0) # M x D
        Tilde_Z0 = self.Z_tilde_tf(Var0, phi0, du0) # M x D

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)
        Tilde_Z_list.append(Tilde_Z0)
        Du_list.append(du0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]
            B1 = B[:, n + 1, :]
            Var1 = Var[:, n + 1, :]
            BM = self.pho * (W1 - W0) + tf.sqrt(1 - self.pho**2) * (B1 - B0)
            X1 = X0 +self.mu_tf(t0, X0, Y0, du0) * (t1 - t0)  - Var0 * 0.5 * (t1 - t0) + tf.sqrt(Var0) * BM

            Y1_tilde = Y0 + self.F_tf(t0, X0, Y0, Z0, Tilde_Z0) * (t1 - t0) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Z0, tf.expand_dims(B1 - B0, -1))), axis=1,
                keepdims=True) + tf.reduce_sum(
                tf.squeeze(tf.matmul(Tilde_Z0, tf.expand_dims(W1 - W0, -1))), axis=1, keepdims=True)

            Y1, phi1, du1 = self.net_u(t1, X1)
            Z1 = self.Z_tf(Var1,du1) # M x D
            Tilde_Z1 = self.Z_tilde_tf(Var1, phi1, du1) # M x D


            loss += tf.reduce_sum(tf.pow(Y1 - Y1_tilde, 2))

            t0 = t1
            W0 = W1
            B0 = B1
            Var0 = Var1
            du0 = du1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            Tilde_Z0 = Tilde_Z1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)
            Tilde_Z_list.append(Tilde_Z0)
            Du_list.append(du0)

        # 0.02 is the penalty parameters for the terminal conditions
        loss += 0.02 * tf.reduce_sum(tf.pow(Y1 - self.g_tf(X1), 2))
        loss += 0.02 * tf.reduce_sum(tf.pow(du1 - self.Dg_tf(X1), 2))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)
        Tilde_Z = tf.stack(Tilde_Z_list, axis=1)
        Du_t = tf.stack(Du_list, axis=1)
        #Y0 = tf.reduce_mean(Y, axis=0)

        return loss, X, Y, Y[0, 0, 0], Du_t

    def Z_tf(self, Var, Du):  # M x D
        return tf.sqrt((1 - self.pho**2) * Var) * Du

    def Z_tilde_tf(self, Var, phi, Du): # M x D
        return self.pho * tf.sqrt(Var) * Du + phi

    # Volterra process Using hybrid scheme
    def volterra(self):
        T = self.T
        M = self.M
        N = self.N
        D = self.D
        delta_t = T / N
        alpha = self.H - 0.5

        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D
        Dt[:, 1:, :] = delta_t
        DW[:, 1:, :] = np.sqrt(delta_t) * np.random.normal(size=(M, N, D))

        t_series = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W_process = np.cumsum(DW, axis=1)  # M x (N+1) x D

        sigma = (2*alpha + 1)**0.5
        #kernal function
        def g_kernel(k):
            y = (k**(alpha+1) - (k-1)**(alpha+1)) / (alpha+1)
            b = np.power(y, 1/alpha)
            return np.power((b) * delta_t, alpha)

        #t_series, W_process = self.fetch_minibatch()

        tilde_X = np.zeros((M, N+1, D))
        tilde_X[:, 0 , :]= W_process[:, 0 , :]

        WN_tj_minus_1_1 = np.roll(W_process, shift=-1, axis=1) - W_process

        for m in range(M):
            for d in range(D):
                # first column for toeplitz matrix
                WN_j = WN_tj_minus_1_1[m, :-1, d]
                sigma_col = np.zeros((N))
                sigma_col[0] = np.power(delta_t/2, alpha) * sigma
                #
                for k in range(1, N):
                    g_b_star_k = g_kernel(k+1)
                    sigma_col[k] = sigma * g_b_star_k

                # FFT and dot
                WN_j_fft = fft(WN_j)
                sigma_fft = fft(sigma_col)
                convolved = ifft(WN_j_fft * sigma_fft)

                # capture real value
                tilde_X[m, 1:, d] = np.real(convolved)

        return t_series, W_process, tilde_X

    # Variace process
    def variance(self):

        t, W_s, D_hat_w = self.volterra()# M x (N+1) x D

        var = self.epsilon_t * np.exp(self.eta* D_hat_w -  0.5 * self.eta**2 * np.power(t, 2*self.H))

        return W_s, var

    #@tf.function
    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1))  # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D))  # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1)  # M x (N+1) x 1
        W = np.cumsum(DW, axis=1)  # M x (N+1) x D

        return t, W

    @tf.function
    def train_step(self, optimizers, t, w, b, var, Xi):
        # Optimizers
        optimizer = optimizers

        with tf.GradientTape() as tape:
            loss_value, X_pred, Y_pred, Y0_pred, Du0_pred = self.loss_function(t, w, b, var, Xi)

        grads = tape.gradient(loss_value, self.model.trainable_weights)
        #optimizer.apply(grads, self.model.trainable_weights)
        optimizer.apply_gradients(zip(grads, self.model.trainable_weights))


        return loss_value, Y0_pred, Du0_pred

    #@tf.function
    def train(self, N_Iter, learning_rate):

        loss_temp = np.array([])
        Y0_pred_temp = np.array([])
        Du0_pred_temp = np.array([])

        # Optimizers
        #self.optimizer = AdamW(learning_rate=learning_rate, weight_decay=0.001)
        self.optimizer = Adam(learning_rate=learning_rate)

        start_time = time.time()
        ini_time = time.time()

        for it in range(N_Iter):

            t_batch, B_batch = self.fetch_minibatch()  # M x (N+1) x 1, M x (N+1) x D
            W_batch, Var_batch = self.variance() # M x (N+1) x D, M x (N+1) x D
            t_batch = tf.convert_to_tensor(t_batch, dtype=tf.float32)
            B_batch = tf.convert_to_tensor(B_batch, dtype=tf.float32)
            W_batch = tf.convert_to_tensor(W_batch, dtype=tf.float32)
            Var_batch = tf.convert_to_tensor(Var_batch, dtype=tf.float32)
            self.Xi = tf.convert_to_tensor(self.Xi, dtype=tf.float32)

            loss_value, Y0_pred, Du0_pred = self.train_step(self.optimizer, t_batch, W_batch, B_batch, Var_batch, self.Xi)

            if it % 100 == 0:
                elapsed = time.time() - start_time
                total_time = time.time() - ini_time
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Total Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_pred, elapsed, total_time, learning_rate))
                start_time = time.time()

            loss_temp = np.append(loss_temp, loss_value.numpy())
            Y0_pred_temp = np.append(Y0_pred_temp, Y0_pred.numpy())

            Du0 = tf.reduce_mean(Du0_pred, axis=0)
            Du0_pred_temp = np.append(Du0_pred_temp, Du0.numpy()[0, 0])

            if it % 100 == 0:
                self.training_loss.append(loss_temp.mean())
                self.Y0_iter.append(Y0_pred_temp[-100:].mean())
                self.Du0_iter.append(Du0_pred_temp[-100:].mean())
                self.iteration.append(it)

            graph = np.stack((self.iteration, self.training_loss))
            Y0_iter = np.stack((self.iteration, self.Y0_iter))
            Du0_iter = np.stack((self.iteration, self.Du0_iter))

        return graph,Y0_iter, Du0_iter

    def predict(self, Xi_star, t_star, W_star, B_star, Var_star):
        t_star = tf.convert_to_tensor(t_star, dtype=tf.float32)
        W_star = tf.convert_to_tensor(W_star, dtype=tf.float32)
        Xi_star = tf.convert_to_tensor(Xi_star, dtype=tf.float32)
        B_star = tf.convert_to_tensor(B_star, dtype=tf.float32)
        Var_star = tf.convert_to_tensor(Var_star, dtype=tf.float32)

        loss, X_star, Y_star, Y0_pred, delta_star = self.loss_function(t_star, W_star, B_star, Var_star, Xi_star)

        return X_star, Y_star, delta_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        pass  # M x1

    @abstractmethod
    def g_tf(self, X):  # M x D
        pass  # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return tf.zeros([M, D])  # M x D
    ###########################################################################

# %%
class RoughBergomiModel(FBSNN):
    def __init__(self, Xi, T, M, N, D, H, eta, pho, r, layers):
        super().__init__(Xi, T, M, N, D, H, eta, pho, r, layers)

    def g_tf(self, X):  # M x D
        K = tf.tile(np.array([90.0], dtype=np.float32)[None, :], [self.M, 1])
        X = tf.reduce_mean(tf.exp(X + self.r * self.T), axis=1, keepdims = True)
        return tf.maximum(K - X, 0) # M x 1

    def mu_tf(self, t, X, Y, Du):  # M x 1, M x D, M x 1, M x D
        return super().mu_tf(t, X, Y, Du)  # M x D

    def F_tf(self, t, X, Y, Z, Tilde_Z):  # M x 1, M x D, M x 1, M x D, M x D
        return self.r * Y # M x1

    ###########################################################################

# %%
T = 1.0  # terminal time
M = 100  # number of trajectories
N = 50  # number of time snapshots
D = 20  # number of dimensions
H = 0.07  # Hurst exponent (0,1)
eta = 1.9  # parameter for control volatility
pho = -0.9  # correlation betwen two independent Wiener process
r = 0.05  # interest rate

Xi = np.array([np.log(100.0), np.log(50.0)] * int(D / 2))[None, :]

layers = [D+1] + 4 * [256] + [1]

model = RoughBergomiModel(Xi, T, M, N, D, H, eta, pho, r, layers)
graph, Y0_iter, delta_iter = model.train(2*10**4, 1e-3)
# Out:
# It: 0, Loss: 2.120e+08, Y0: 0.170, Time: 28.60, Total Time: 28.60, Learning Rate: 1.000e-03
# It: 100, Loss: 4.435e+07, Y0: 1.050, Time: 39.74, Total Time: 68.34, Learning Rate: 1.000e-03
# It: 200, Loss: 4.654e+07, Y0: 8.236, Time: 43.11, Total Time: 111.45, Learning Rate: 1.000e-03
# It: 300, Loss: 4.235e+07, Y0: 7.186, Time: 43.28, Total Time: 154.73, Learning Rate: 1.000e-03
# It: 400, Loss: 4.348e+07, Y0: 3.059, Time: 40.23, Total Time: 194.96, Learning Rate: 1.000e-03
# It: 500, Loss: 4.487e+07, Y0: 11.923, Time: 41.16, Total Time: 236.12, Learning Rate: 1.000e-03
# It: 600, Loss: 4.379e+07, Y0: 3.588, Time: 40.57, Total Time: 276.69, Learning Rate: 1.000e-03
# It: 700, Loss: 4.308e+07, Y0: -0.031, Time: 39.55, Total Time: 316.24, Learning Rate: 1.000e-03
# It: 800, Loss: 4.388e+07, Y0: 4.055, Time: 38.64, Total Time: 354.88, Learning Rate: 1.000e-03
# It: 900, Loss: 4.370e+07, Y0: 8.526, Time: 38.35, Total Time: 393.23, Learning Rate: 1.000e-03
# It: 1000, Loss: 4.135e+07, Y0: -1.858, Time: 40.18, Total Time: 433.41, Learning Rate: 1.000e-03
# It: 1100, Loss: 4.306e+07, Y0: 10.666, Time: 38.25, Total Time: 471.66, Learning Rate: 1.000e-03
# It: 1200, Loss: 4.270e+07, Y0: -0.709, Time: 38.30, Total Time: 509.96, Learning Rate: 1.000e-03
# It: 1300, Loss: 4.359e+07, Y0: 8.168, Time: 39.27, Total Time: 549.23, Learning Rate: 1.000e-03
# It: 1400, Loss: 4.446e+07, Y0: 0.277, Time: 39.83, Total Time: 589.06, Learning Rate: 1.000e-03
# It: 1500, Loss: 4.455e+07, Y0: -5.854, Time: 39.72, Total Time: 628.78, Learning Rate: 1.000e-03
# It: 1600, Loss: 4.325e+07, Y0: 2.362, Time: 39.65, Total Time: 668.43, Learning Rate: 1.000e-03
# It: 1700, Loss: 4.347e+07, Y0: -6.585, Time: 40.07, Total Time: 708.50, Learning Rate: 1.000e-03
# It: 1800, Loss: 4.487e+07, Y0: 10.245, Time: 39.55, Total Time: 748.05, Learning Rate: 1.000e-03
# It: 1900, Loss: 4.546e+07, Y0: 19.377, Time: 39.79, Total Time: 787.85, Learning Rate: 1.000e-03
# It: 2000, Loss: 4.315e+07, Y0: 6.592, Time: 38.62, Total Time: 826.47, Learning Rate: 1.000e-03
# It: 2100, Loss: 4.321e+07, Y0: 8.753, Time: 39.46, Total Time: 865.93, Learning Rate: 1.000e-03
# It: 2200, Loss: 4.528e+07, Y0: -8.759, Time: 40.41, Total Time: 906.34, Learning Rate: 1.000e-03
# It: 2300, Loss: 4.280e+07, Y0: -2.256, Time: 40.09, Total Time: 946.42, Learning Rate: 1.000e-03
# It: 2400, Loss: 4.434e+07, Y0: -3.905, Time: 39.68, Total Time: 986.11, Learning Rate: 1.000e-03
# It: 2500, Loss: 4.381e+07, Y0: -9.705, Time: 39.96, Total Time: 1026.07, Learning Rate: 1.000e-03
# It: 2600, Loss: 4.365e+07, Y0: -3.700, Time: 40.05, Total Time: 1066.12, Learning Rate: 1.000e-03
# It: 2700, Loss: 4.443e+07, Y0: -0.511, Time: 38.65, Total Time: 1104.77, Learning Rate: 1.000e-03
# It: 2800, Loss: 4.314e+07, Y0: 1.148, Time: 38.30, Total Time: 1143.08, Learning Rate: 1.000e-03
# It: 2900, Loss: 4.400e+07, Y0: 8.170, Time: 38.41, Total Time: 1181.48, Learning Rate: 1.000e-03
# It: 3000, Loss: 4.417e+07, Y0: 1.017, Time: 38.70, Total Time: 1220.18, Learning Rate: 1.000e-03
# It: 3100, Loss: 4.551e+07, Y0: 1.479, Time: 38.14, Total Time: 1258.33, Learning Rate: 1.000e-03
# It: 3200, Loss: 4.503e+07, Y0: 9.730, Time: 38.36, Total Time: 1296.68, Learning Rate: 1.000e-03
# It: 3300, Loss: 4.263e+07, Y0: -4.279, Time: 38.30, Total Time: 1334.99, Learning Rate: 1.000e-03
# It: 3400, Loss: 4.426e+07, Y0: -2.444, Time: 38.41, Total Time: 1373.40, Learning Rate: 1.000e-03
# It: 3500, Loss: 4.139e+07, Y0: -2.825, Time: 38.98, Total Time: 1412.38, Learning Rate: 1.000e-03
# It: 3600, Loss: 4.356e+07, Y0: -4.499, Time: 39.50, Total Time: 1451.88, Learning Rate: 1.000e-03
# It: 3700, Loss: 4.409e+07, Y0: 2.705, Time: 38.21, Total Time: 1490.09, Learning Rate: 1.000e-03
# It: 3800, Loss: 4.383e+07, Y0: 2.445, Time: 38.18, Total Time: 1528.27, Learning Rate: 1.000e-03
# It: 3900, Loss: 4.576e+07, Y0: -6.691, Time: 38.40, Total Time: 1566.67, Learning Rate: 1.000e-03
# It: 4000, Loss: 4.487e+07, Y0: -2.060, Time: 38.53, Total Time: 1605.19, Learning Rate: 1.000e-03
# It: 4100, Loss: 4.557e+07, Y0: -4.931, Time: 38.84, Total Time: 1644.03, Learning Rate: 1.000e-03
# It: 4200, Loss: 4.459e+07, Y0: 2.802, Time: 39.68, Total Time: 1683.71, Learning Rate: 1.000e-03
# It: 4300, Loss: 4.396e+07, Y0: 7.817, Time: 39.91, Total Time: 1723.61, Learning Rate: 1.000e-03
# It: 4400, Loss: 4.483e+07, Y0: -6.765, Time: 39.74, Total Time: 1763.35, Learning Rate: 1.000e-03
# It: 4500, Loss: 4.237e+07, Y0: 6.610, Time: 38.97, Total Time: 1802.32, Learning Rate: 1.000e-03
# It: 4600, Loss: 4.374e+07, Y0: -1.421, Time: 39.85, Total Time: 1842.17, Learning Rate: 1.000e-03
# It: 4700, Loss: 4.412e+07, Y0: -1.965, Time: 39.87, Total Time: 1882.04, Learning Rate: 1.000e-03
# It: 4800, Loss: 4.258e+07, Y0: -1.461, Time: 39.82, Total Time: 1921.86, Learning Rate: 1.000e-03
# It: 4900, Loss: 4.364e+07, Y0: 6.343, Time: 40.41, Total Time: 1962.27, Learning Rate: 1.000e-03
# It: 5000, Loss: 4.327e+07, Y0: -1.694, Time: 39.95, Total Time: 2002.22, Learning Rate: 1.000e-03
# It: 5100, Loss: 4.237e+07, Y0: 3.122, Time: 39.47, Total Time: 2041.69, Learning Rate: 1.000e-03
# It: 5200, Loss: 4.154e+07, Y0: 6.853, Time: 39.99, Total Time: 2081.68, Learning Rate: 1.000e-03
# It: 5300, Loss: 4.250e+07, Y0: -0.564, Time: 39.87, Total Time: 2121.55, Learning Rate: 1.000e-03
# It: 5400, Loss: 4.334e+07, Y0: 20.084, Time: 39.91, Total Time: 2161.45, Learning Rate: 1.000e-03
# It: 5500, Loss: 4.363e+07, Y0: -5.014, Time: 39.91, Total Time: 2201.36, Learning Rate: 1.000e-03
# It: 5600, Loss: 4.443e+07, Y0: 5.945, Time: 38.21, Total Time: 2239.57, Learning Rate: 1.000e-03
# It: 5700, Loss: 4.394e+07, Y0: -3.565, Time: 38.37, Total Time: 2277.94, Learning Rate: 1.000e-03
# It: 5800, Loss: 4.299e+07, Y0: 2.731, Time: 38.39, Total Time: 2316.33, Learning Rate: 1.000e-03
# It: 5900, Loss: 4.174e+07, Y0: 3.107, Time: 38.18, Total Time: 2354.52, Learning Rate: 1.000e-03
# It: 6000, Loss: 4.446e+07, Y0: -2.593, Time: 38.20, Total Time: 2392.72, Learning Rate: 1.000e-03
# It: 6100, Loss: 4.363e+07, Y0: 12.019, Time: 39.31, Total Time: 2432.03, Learning Rate: 1.000e-03
# It: 6200, Loss: 4.389e+07, Y0: 4.417, Time: 39.95, Total Time: 2471.99, Learning Rate: 1.000e-03
# It: 6300, Loss: 4.253e+07, Y0: 0.167, Time: 39.16, Total Time: 2511.15, Learning Rate: 1.000e-03
# It: 6400, Loss: 4.355e+07, Y0: -10.695, Time: 38.44, Total Time: 2549.59, Learning Rate: 1.000e-03
# It: 6500, Loss: 4.395e+07, Y0: -4.013, Time: 38.31, Total Time: 2587.90, Learning Rate: 1.000e-03
# It: 6600, Loss: 4.440e+07, Y0: -6.816, Time: 38.30, Total Time: 2626.20, Learning Rate: 1.000e-03
# It: 6700, Loss: 4.491e+07, Y0: 10.249, Time: 39.64, Total Time: 2665.84, Learning Rate: 1.000e-03
# It: 6800, Loss: 4.515e+07, Y0: 8.810, Time: 40.28, Total Time: 2706.12, Learning Rate: 1.000e-03
# It: 6900, Loss: 4.309e+07, Y0: -5.623, Time: 40.20, Total Time: 2746.32, Learning Rate: 1.000e-03
# It: 7000, Loss: 4.279e+07, Y0: 7.066, Time: 39.69, Total Time: 2786.01, Learning Rate: 1.000e-03
# It: 7100, Loss: 4.340e+07, Y0: 4.625, Time: 39.97, Total Time: 2825.98, Learning Rate: 1.000e-03
# It: 7200, Loss: 4.370e+07, Y0: 11.662, Time: 39.88, Total Time: 2865.86, Learning Rate: 1.000e-03
# It: 7300, Loss: 4.259e+07, Y0: 0.662, Time: 39.69, Total Time: 2905.55, Learning Rate: 1.000e-03
# It: 7400, Loss: 4.515e+07, Y0: -5.837, Time: 38.76, Total Time: 2944.31, Learning Rate: 1.000e-03
# It: 7500, Loss: 4.244e+07, Y0: 0.040, Time: 39.92, Total Time: 2984.22, Learning Rate: 1.000e-03
# It: 7600, Loss: 4.267e+07, Y0: 6.366, Time: 39.84, Total Time: 3024.06, Learning Rate: 1.000e-03
# It: 7700, Loss: 4.428e+07, Y0: 7.649, Time: 40.11, Total Time: 3064.17, Learning Rate: 1.000e-03
# It: 7800, Loss: 4.353e+07, Y0: 7.873, Time: 38.79, Total Time: 3102.95, Learning Rate: 1.000e-03
# It: 7900, Loss: 4.203e+07, Y0: 8.893, Time: 38.39, Total Time: 3141.34, Learning Rate: 1.000e-03
# It: 8000, Loss: 4.285e+07, Y0: -2.006, Time: 38.44, Total Time: 3179.78, Learning Rate: 1.000e-03
# It: 8100, Loss: 4.316e+07, Y0: 14.448, Time: 38.35, Total Time: 3218.14, Learning Rate: 1.000e-03
# It: 8200, Loss: 4.285e+07, Y0: 5.481, Time: 38.85, Total Time: 3256.98, Learning Rate: 1.000e-03
# It: 8300, Loss: 4.332e+07, Y0: -6.326, Time: 39.65, Total Time: 3296.63, Learning Rate: 1.000e-03
# It: 8400, Loss: 4.307e+07, Y0: 10.008, Time: 39.71, Total Time: 3336.34, Learning Rate: 1.000e-03
# It: 8500, Loss: 4.243e+07, Y0: -4.123, Time: 39.91, Total Time: 3376.25, Learning Rate: 1.000e-03
# It: 8600, Loss: 4.257e+07, Y0: -1.034, Time: 39.86, Total Time: 3416.11, Learning Rate: 1.000e-03
# It: 8700, Loss: 4.394e+07, Y0: 0.858, Time: 40.02, Total Time: 3456.13, Learning Rate: 1.000e-03
# It: 8800, Loss: 4.425e+07, Y0: -0.190, Time: 39.46, Total Time: 3495.59, Learning Rate: 1.000e-03
# It: 8900, Loss: 4.304e+07, Y0: 12.301, Time: 38.85, Total Time: 3534.44, Learning Rate: 1.000e-03
# It: 9000, Loss: 4.318e+07, Y0: 15.678, Time: 38.37, Total Time: 3572.81, Learning Rate: 1.000e-03
# It: 9100, Loss: 4.301e+07, Y0: 2.382, Time: 38.25, Total Time: 3611.05, Learning Rate: 1.000e-03
# It: 9200, Loss: 4.377e+07, Y0: 11.648, Time: 38.48, Total Time: 3649.54, Learning Rate: 1.000e-03
# It: 9300, Loss: 4.215e+07, Y0: -3.613, Time: 38.21, Total Time: 3687.75, Learning Rate: 1.000e-03
# It: 9400, Loss: 4.321e+07, Y0: 10.266, Time: 38.50, Total Time: 3726.24, Learning Rate: 1.000e-03
# It: 9500, Loss: 4.539e+07, Y0: 8.048, Time: 40.07, Total Time: 3766.31, Learning Rate: 1.000e-03
# It: 9600, Loss: 4.242e+07, Y0: 9.659, Time: 40.28, Total Time: 3806.60, Learning Rate: 1.000e-03
# It: 9700, Loss: 4.125e+07, Y0: -1.285, Time: 40.18, Total Time: 3846.77, Learning Rate: 1.000e-03
# It: 9800, Loss: 4.457e+07, Y0: 8.943, Time: 39.90, Total Time: 3886.67, Learning Rate: 1.000e-03
# It: 9900, Loss: 4.307e+07, Y0: -1.215, Time: 38.44, Total Time: 3925.11, Learning Rate: 1.000e-03
# It: 10000, Loss: 4.357e+07, Y0: 7.251, Time: 38.21, Total Time: 3963.32, Learning Rate: 1.000e-03
# It: 10100, Loss: 4.181e+07, Y0: 2.429, Time: 38.32, Total Time: 4001.64, Learning Rate: 1.000e-03
# It: 10200, Loss: 4.171e+07, Y0: 10.032, Time: 38.28, Total Time: 4039.92, Learning Rate: 1.000e-03
# It: 10300, Loss: 4.289e+07, Y0: 2.305, Time: 38.79, Total Time: 4078.71, Learning Rate: 1.000e-03
# It: 10400, Loss: 4.357e+07, Y0: 0.731, Time: 38.38, Total Time: 4117.09, Learning Rate: 1.000e-03
# It: 10500, Loss: 4.462e+07, Y0: 11.598, Time: 38.47, Total Time: 4155.56, Learning Rate: 1.000e-03
# It: 10600, Loss: 4.478e+07, Y0: 5.856, Time: 38.52, Total Time: 4194.08, Learning Rate: 1.000e-03
# It: 10700, Loss: 4.419e+07, Y0: -4.512, Time: 38.27, Total Time: 4232.35, Learning Rate: 1.000e-03
# It: 10800, Loss: 4.423e+07, Y0: 2.037, Time: 38.85, Total Time: 4271.20, Learning Rate: 1.000e-03
# It: 10900, Loss: 4.362e+07, Y0: 4.233, Time: 38.41, Total Time: 4309.60, Learning Rate: 1.000e-03
# It: 11000, Loss: 4.240e+07, Y0: 2.775, Time: 38.32, Total Time: 4347.93, Learning Rate: 1.000e-03
# It: 11100, Loss: 4.327e+07, Y0: 5.332, Time: 38.46, Total Time: 4386.39, Learning Rate: 1.000e-03
# It: 11200, Loss: 4.263e+07, Y0: 7.814, Time: 38.38, Total Time: 4424.77, Learning Rate: 1.000e-03
# It: 11300, Loss: 4.454e+07, Y0: 7.517, Time: 38.43, Total Time: 4463.20, Learning Rate: 1.000e-03
# It: 11400, Loss: 4.296e+07, Y0: 0.443, Time: 39.89, Total Time: 4503.09, Learning Rate: 1.000e-03
# It: 11500, Loss: 4.451e+07, Y0: -2.799, Time: 39.44, Total Time: 4542.53, Learning Rate: 1.000e-03
# It: 11600, Loss: 4.431e+07, Y0: -13.135, Time: 38.27, Total Time: 4580.80, Learning Rate: 1.000e-03
# It: 11700, Loss: 4.362e+07, Y0: 18.029, Time: 38.41, Total Time: 4619.21, Learning Rate: 1.000e-03
# It: 11800, Loss: 4.560e+07, Y0: 4.999, Time: 38.48, Total Time: 4657.69, Learning Rate: 1.000e-03
# It: 11900, Loss: 4.339e+07, Y0: 6.945, Time: 38.28, Total Time: 4695.98, Learning Rate: 1.000e-03
# It: 12000, Loss: 4.531e+07, Y0: 5.719, Time: 38.30, Total Time: 4734.28, Learning Rate: 1.000e-03
# It: 12100, Loss: 4.443e+07, Y0: 5.080, Time: 39.50, Total Time: 4773.78, Learning Rate: 1.000e-03
# It: 12200, Loss: 4.195e+07, Y0: 6.679, Time: 39.11, Total Time: 4812.89, Learning Rate: 1.000e-03
# It: 12300, Loss: 4.339e+07, Y0: 28.193, Time: 39.96, Total Time: 4852.85, Learning Rate: 1.000e-03
# It: 12400, Loss: 4.304e+07, Y0: 11.259, Time: 39.55, Total Time: 4892.40, Learning Rate: 1.000e-03
# It: 12500, Loss: 4.615e+07, Y0: 12.415, Time: 39.91, Total Time: 4932.31, Learning Rate: 1.000e-03
# It: 12600, Loss: 4.376e+07, Y0: 9.082, Time: 38.90, Total Time: 4971.21, Learning Rate: 1.000e-03
# It: 12700, Loss: 4.273e+07, Y0: 7.845, Time: 39.63, Total Time: 5010.83, Learning Rate: 1.000e-03
# It: 12800, Loss: 4.356e+07, Y0: 7.297, Time: 39.96, Total Time: 5050.79, Learning Rate: 1.000e-03
# It: 12900, Loss: 4.202e+07, Y0: 8.767, Time: 39.61, Total Time: 5090.41, Learning Rate: 1.000e-03
# It: 13000, Loss: 4.238e+07, Y0: 0.533, Time: 40.10, Total Time: 5130.51, Learning Rate: 1.000e-03
# It: 13100, Loss: 4.132e+07, Y0: 15.010, Time: 39.99, Total Time: 5170.50, Learning Rate: 1.000e-03
# It: 13200, Loss: 4.379e+07, Y0: 8.977, Time: 39.95, Total Time: 5210.45, Learning Rate: 1.000e-03
# It: 13300, Loss: 4.327e+07, Y0: 10.565, Time: 40.02, Total Time: 5250.47, Learning Rate: 1.000e-03
# It: 13400, Loss: 4.455e+07, Y0: 5.602, Time: 39.85, Total Time: 5290.32, Learning Rate: 1.000e-03
# It: 13500, Loss: 4.338e+07, Y0: 4.903, Time: 39.90, Total Time: 5330.22, Learning Rate: 1.000e-03
# It: 13600, Loss: 4.258e+07, Y0: 9.396, Time: 39.99, Total Time: 5370.21, Learning Rate: 1.000e-03
# It: 13700, Loss: 4.268e+07, Y0: 13.707, Time: 40.05, Total Time: 5410.27, Learning Rate: 1.000e-03
# It: 13800, Loss: 4.373e+07, Y0: -0.896, Time: 39.78, Total Time: 5450.05, Learning Rate: 1.000e-03
# It: 13900, Loss: 4.248e+07, Y0: 10.092, Time: 39.69, Total Time: 5489.74, Learning Rate: 1.000e-03
# It: 14000, Loss: 4.305e+07, Y0: 12.598, Time: 39.56, Total Time: 5529.30, Learning Rate: 1.000e-03
# It: 14100, Loss: 4.269e+07, Y0: 7.412, Time: 38.36, Total Time: 5567.65, Learning Rate: 1.000e-03
# It: 14200, Loss: 4.147e+07, Y0: 3.629, Time: 38.32, Total Time: 5605.97, Learning Rate: 1.000e-03
# It: 14300, Loss: 4.306e+07, Y0: 8.869, Time: 38.42, Total Time: 5644.39, Learning Rate: 1.000e-03
# It: 14400, Loss: 4.404e+07, Y0: 6.997, Time: 38.62, Total Time: 5683.01, Learning Rate: 1.000e-03
# It: 14500, Loss: 4.282e+07, Y0: 2.481, Time: 40.20, Total Time: 5723.21, Learning Rate: 1.000e-03
# It: 14600, Loss: 4.409e+07, Y0: 13.862, Time: 40.28, Total Time: 5763.49, Learning Rate: 1.000e-03
# It: 14700, Loss: 4.387e+07, Y0: 4.036, Time: 40.09, Total Time: 5803.59, Learning Rate: 1.000e-03
# It: 14800, Loss: 4.260e+07, Y0: 8.330, Time: 40.14, Total Time: 5843.72, Learning Rate: 1.000e-03
# It: 14900, Loss: 4.208e+07, Y0: 12.565, Time: 39.89, Total Time: 5883.61, Learning Rate: 1.000e-03
# It: 15000, Loss: 4.359e+07, Y0: 14.395, Time: 38.93, Total Time: 5922.55, Learning Rate: 1.000e-03
# It: 15100, Loss: 4.260e+07, Y0: 7.107, Time: 38.30, Total Time: 5960.85, Learning Rate: 1.000e-03
# It: 15200, Loss: 4.442e+07, Y0: 18.269, Time: 38.85, Total Time: 5999.70, Learning Rate: 1.000e-03
# It: 15300, Loss: 4.281e+07, Y0: 8.278, Time: 40.08, Total Time: 6039.78, Learning Rate: 1.000e-03
# It: 15400, Loss: 4.647e+07, Y0: 5.380, Time: 39.96, Total Time: 6079.74, Learning Rate: 1.000e-03
# It: 15500, Loss: 4.360e+07, Y0: 5.991, Time: 38.69, Total Time: 6118.43, Learning Rate: 1.000e-03
# It: 15600, Loss: 4.286e+07, Y0: 10.108, Time: 39.35, Total Time: 6157.78, Learning Rate: 1.000e-03
# It: 15700, Loss: 4.366e+07, Y0: 9.126, Time: 38.84, Total Time: 6196.62, Learning Rate: 1.000e-03
# It: 15800, Loss: 4.309e+07, Y0: 10.002, Time: 40.10, Total Time: 6236.72, Learning Rate: 1.000e-03
# It: 15900, Loss: 4.415e+07, Y0: 9.668, Time: 38.53, Total Time: 6275.25, Learning Rate: 1.000e-03
# It: 16000, Loss: 4.257e+07, Y0: 1.786, Time: 38.44, Total Time: 6313.69, Learning Rate: 1.000e-03
# It: 16100, Loss: 4.293e+07, Y0: 6.874, Time: 38.39, Total Time: 6352.08, Learning Rate: 1.000e-03
# It: 16200, Loss: 4.388e+07, Y0: -0.462, Time: 38.34, Total Time: 6390.43, Learning Rate: 1.000e-03
# It: 16300, Loss: 4.215e+07, Y0: 2.436, Time: 39.05, Total Time: 6429.48, Learning Rate: 1.000e-03
# It: 16400, Loss: 4.380e+07, Y0: 5.968, Time: 39.69, Total Time: 6469.17, Learning Rate: 1.000e-03
# It: 16500, Loss: 4.278e+07, Y0: 7.186, Time: 38.78, Total Time: 6507.95, Learning Rate: 1.000e-03
# It: 16600, Loss: 4.135e+07, Y0: 9.470, Time: 38.49, Total Time: 6546.44, Learning Rate: 1.000e-03
# It: 16700, Loss: 4.350e+07, Y0: 8.289, Time: 38.62, Total Time: 6585.06, Learning Rate: 1.000e-03
# It: 16800, Loss: 4.267e+07, Y0: 14.035, Time: 38.41, Total Time: 6623.48, Learning Rate: 1.000e-03
# It: 16900, Loss: 4.340e+07, Y0: 12.147, Time: 38.20, Total Time: 6661.67, Learning Rate: 1.000e-03
# It: 17000, Loss: 4.575e+07, Y0: 4.235, Time: 38.46, Total Time: 6700.14, Learning Rate: 1.000e-03
# It: 17100, Loss: 4.149e+07, Y0: 6.641, Time: 38.38, Total Time: 6738.52, Learning Rate: 1.000e-03
# It: 17200, Loss: 4.469e+07, Y0: 11.367, Time: 39.12, Total Time: 6777.64, Learning Rate: 1.000e-03
# It: 17300, Loss: 4.330e+07, Y0: 17.074, Time: 38.30, Total Time: 6815.93, Learning Rate: 1.000e-03
# It: 17400, Loss: 4.371e+07, Y0: 5.958, Time: 38.47, Total Time: 6854.41, Learning Rate: 1.000e-03
# It: 17500, Loss: 4.409e+07, Y0: 0.322, Time: 38.56, Total Time: 6892.97, Learning Rate: 1.000e-03
# It: 17600, Loss: 4.321e+07, Y0: 10.383, Time: 39.34, Total Time: 6932.30, Learning Rate: 1.000e-03
# It: 17700, Loss: 4.397e+07, Y0: 7.304, Time: 39.33, Total Time: 6971.64, Learning Rate: 1.000e-03
# It: 17800, Loss: 4.189e+07, Y0: 7.252, Time: 39.16, Total Time: 7010.80, Learning Rate: 1.000e-03
# It: 17900, Loss: 4.334e+07, Y0: 6.957, Time: 38.29, Total Time: 7049.09, Learning Rate: 1.000e-03
# It: 18000, Loss: 4.474e+07, Y0: 4.509, Time: 38.36, Total Time: 7087.45, Learning Rate: 1.000e-03
# It: 18100, Loss: 4.463e+07, Y0: 14.118, Time: 38.58, Total Time: 7126.02, Learning Rate: 1.000e-03
# It: 18200, Loss: 4.257e+07, Y0: 12.264, Time: 39.32, Total Time: 7165.35, Learning Rate: 1.000e-03
# It: 18300, Loss: 4.317e+07, Y0: 6.405, Time: 38.18, Total Time: 7203.53, Learning Rate: 1.000e-03
# It: 18400, Loss: 4.108e+07, Y0: -0.860, Time: 38.26, Total Time: 7241.79, Learning Rate: 1.000e-03
# It: 18500, Loss: 4.123e+07, Y0: 6.936, Time: 38.99, Total Time: 7280.78, Learning Rate: 1.000e-03
# It: 18600, Loss: 4.173e+07, Y0: 8.814, Time: 39.68, Total Time: 7320.46, Learning Rate: 1.000e-03
# It: 18700, Loss: 4.399e+07, Y0: 10.644, Time: 39.20, Total Time: 7359.66, Learning Rate: 1.000e-03
# It: 18800, Loss: 4.459e+07, Y0: 4.108, Time: 38.43, Total Time: 7398.09, Learning Rate: 1.000e-03
# It: 18900, Loss: 4.560e+07, Y0: 13.709, Time: 38.26, Total Time: 7436.35, Learning Rate: 1.000e-03
# It: 19000, Loss: 4.280e+07, Y0: 6.541, Time: 38.35, Total Time: 7474.70, Learning Rate: 1.000e-03
# It: 19100, Loss: 4.328e+07, Y0: 7.148, Time: 38.57, Total Time: 7513.28, Learning Rate: 1.000e-03
# It: 19200, Loss: 4.373e+07, Y0: 14.249, Time: 38.29, Total Time: 7551.57, Learning Rate: 1.000e-03
# It: 19300, Loss: 4.287e+07, Y0: 7.919, Time: 38.24, Total Time: 7589.81, Learning Rate: 1.000e-03
# It: 19400, Loss: 4.362e+07, Y0: 12.970, Time: 38.29, Total Time: 7628.10, Learning Rate: 1.000e-03
# It: 19500, Loss: 4.434e+07, Y0: 14.262, Time: 38.41, Total Time: 7666.51, Learning Rate: 1.000e-03
# It: 19600, Loss: 4.326e+07, Y0: 6.735, Time: 38.38, Total Time: 7704.89, Learning Rate: 1.000e-03
# It: 19700, Loss: 4.380e+07, Y0: 21.995, Time: 38.48, Total Time: 7743.37, Learning Rate: 1.000e-03
# It: 19800, Loss: 4.445e+07, Y0: 11.642, Time: 38.38, Total Time: 7781.75, Learning Rate: 1.000e-03
# It: 19900, Loss: 4.322e+07, Y0: 8.978, Time: 38.18, Total Time: 7819.93, Learning Rate: 1.000e-03

# %%
np.random.seed(42)
t_test, B_test = model.fetch_minibatch()
W_test, Var_test = model.variance()

X_pred, Y_pred, delta_pred = model.predict(Xi, t_test, W_test, B_test, Var_test)
#Y0_test = 4.9550

# %%
D = 20
plt.figure()
plt.plot(graph[0], graph[1])
plt.xlabel('Iterations')
plt.ylabel('Value')
plt.yscale("log")
plt.title('Evolution of the training loss')
plt.savefig(str(D) + 'train-loss' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(Y0_iter[0], Y0_iter[1], label='Learned $Y_0$')
#plt.axhline(Y0_test, color='r', label='Exact $Y_0$')
plt.xlabel('Iterations')
plt.ylabel('Y Initial Value')
#plt.yscale("log")
plt.title('Evolution of the Y Initial')
plt.savefig(str(D) + ' Initial' + 'RoughBergomiModel')

# %%
plt.figure()
plt.plot(delta_iter[0], delta_iter[1], label='Learned $Delta_T$')
plt.xlabel('Iterations')
plt.ylabel('Delta Value')
#plt.yscale("log")
plt.title('Evolution of the Delta')
plt.savefig(str(D) + 'Delta' + 'RoughBergomiModel')

# %%
tf.experimental.numpy.experimental_enable_numpy_behavior()

# %%
samples = 5
plt.figure()
plt.plot(t_test[0:1, :, 0].T, Y_pred[0:1, :, 0].T, 'b', label='Learned $u(t,X_t)$')

plt.plot(t_test[1:samples, :, 0].T, Y_pred[1:samples, :, 0].T, 'b')

plt.xlabel('$t$')
plt.ylabel('$Y_t = u(t,X_t)$')
plt.title(str(D) + '-dimensional RoughBergomiModel')
plt.legend()
plt.savefig(str(D) +'-dimensional RoughBergomiModel' + 'traces')

# %%
# !pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0

# %%
#. Monte Carlo Simulation
T_mc = 1.0  # terminal time
M_mc = 10000  # number of trajectories
N_mc = 50  # number of time snapshots
D_mc = 20  # number of dimensions
H_mc = 0.07  # Hurst exponent (0,1)
eta_mc = 1.9  # parameter for control volatility
pho_mc = -0.9  # correlation betwen two independent Wiener process
r_mc = 0.05  # interest rate

layers_mc = [D_mc+1] + 4 * [256] + [1+D_mc]

Xi_mc = np.array([np.log(100.0), np.log(50.0)] * int(D_mc/2) )[None, :]
model_mc = RoughBergomiModel(Xi_mc, T_mc, M_mc, N_mc, D_mc, H_mc, eta_mc, pho_mc, r_mc, layers_mc)

np.random.seed(42)
t_mc_test, B_mc_test = model_mc.fetch_minibatch()
W_mc_test, Var_mc_test = model_mc.variance()

def MC_simulation(t, W, B, Var, Xi):

    X_list = []

    t0 = t[:, 0, :]
    W0 = W[:, 0, :]
    B0 = B[:, 0, :]
    Var0 = Var[:, 0, :]

    X0 = tf.tile(Xi, [M_mc, 1])  # M x D
    X_list.append(X0)

    for n in range(0, N_mc):
        t1 = t[:, n + 1, :]
        W1 = W[:, n + 1, :]
        B1 = B[:, n + 1, :]
        Var1 = Var[:, n + 1, :]

        BM = pho_mc * (W1 - W0) + np.sqrt(1 - np.square(pho_mc)) * (B1 - B0)
        X1 = X0 - Var0 * 0.5 * (t1 - t0)+ np.sqrt(Var0) * BM

        t0 = t1
        W0 = W1
        B0 = B1
        Var0 = Var1
        X0 = X1

        X_list.append(X0)

    X = tf.stack(X_list, axis=1)
    return X

X_mc = MC_simulation(t_mc_test, W_mc_test, B_mc_test, Var_mc_test, Xi_mc)
K_mc = np.tile(np.array([90.0], dtype=np.float32)[None, :], [M_mc, 1])
S_T_mc = np.mean(np.exp(X_mc[:, -1, :] + r_mc * T_mc), axis=1, keepdims = True)
put_option_mc = np.mean(np.maximum(K_mc - S_T_mc, 0.0), axis=0) * np.exp(-r_mc * T_mc)

# %%
Y_pred_mean = np.mean(Y_pred, axis=0)
Y_pred_std = np.std(Y_pred, axis=0)
error = Y_pred_mean[0, 0] - put_option_mc
#print('Y0_mean is: {}'.format(Y_pred_mean[0, 0]))
#print('Y0_exact is: {}'.format(Y0_test))
#print('Y0_std is: {}'.format(Y_pred_std[0, 0]))
#print('Relative Error is: {}'.format(error))

# %%
from tabulate import tabulate
table = {'reference value': put_option_mc, 'Y0_mean': Y_pred_mean[0, :].tolist(), 'Y0_std': Y_pred_std[0, :].tolist(), 'relative error': error}
print(tabulate(table, headers='keys', tablefmt='github'))
# Out:
# |   reference value |   Y0_mean |      Y0_std |   relative error |
# |-------------------|-----------|-------------|------------------|
# |           13.9343 |   10.5977 | 1.14441e-05 |         -3.33664 |
